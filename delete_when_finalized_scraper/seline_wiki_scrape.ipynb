# %%
# Read in
import lxml.html
import httpx 
import pandas as pd
import re
import json
from lxml.cssselect import CSSSelector

# %%
def scrape_wikipedia_tables(url):
    """
    Scrape data about Chicago alderpersons from tables in a Wikipedia page.

    This function extracts information about alderpersons for each ward in 
    Chicago from tables in a given Wikipedia URL. It collects data including 
    the ward number, alderperson name, start and end dates of their term, party 
    affiliation, and any additional notes.

    Args:
        url (str): The URL of the Wikipedia page to scrape.

    Returns:
        list: A list of dictionaries, where each dictionary contains information about
        an alderperson. The keys in each dictionary are:
        - "Ward": The ward number
        - "Alderperson": The name of the alderperson
        - "Start Date": The start date of their term
        - "End Date": The end date of their term (or "Present" if still in office)
        - "Party": The political party affiliation of the alderperson
        - "Notes": Any additional notes about the alderperson or their term
    """

    response = httpx.get(url)
    root = lxml.html.fromstring(response.content)
    
    all_data = []

    # Find all tables with class "wikitable sortable"
    tables = root.cssselect('table.wikitable.sortable')

    for table in tables:
        # Try to find the preceding h3 element for ward information
        ward_header = table.xpath('./preceding::h3[1]')
        if ward_header:
            ward_text = ward_header[0].text_content().strip()
            ward_number = ward_text.split()[0]  
        else:
            continue  # Skip if no ward header found

        # Define specific CSS selectors for each column
        alderperson_selector = CSSSelector('th[scope="row"] a')
        term_selector = CSSSelector('td:nth-of-type(4)')
        party_selector = CSSSelector('td:nth-of-type(5) a')
        notes_selector = CSSSelector('td:nth-of-type(6)')

        # Extract rows from the table
        rows = table.cssselect('tr:nth-of-type(n+2)')

        # Iterate through each row
        for row in rows:
            # Extract data using the defined CSS selectors
            alderperson = alderperson_selector(row)
            if not alderperson:
                continue
            alderperson = alderperson[0].text_content().strip()
            
            term = term_selector(row)
            if term:
                term_text = ' '.join(term[0].xpath('.//text()')).strip().replace('\n', ' ')
                term_parts = term_text.split('–')
                start_date = term_parts[0].strip()  # Get the start date
                end_date = term_parts[1].strip() if len(term_parts) > 1 else "Present"  # Get the end date
            else:
                start_date = end_date = 'N/A'

            party = party_selector(row)
            party = party[0].text_content().strip() if party else 'N/A'
            
            notes = notes_selector(row)
            notes_text = ' '.join(notes[0].xpath('.//text()')).strip().replace('\n', ' ') if notes else 'N/A'

            row_data = {
                "Ward": ward_number,
                "Alderperson": alderperson,
                "Start Date": start_date,
                "End Date": end_date,
                "Party": party,
                "Notes": notes_text
            }

            # Append the data to the list
            all_data.append(row_data)

    # Save the data to a JSON file
    with open('getnet_data.json', 'w', encoding='utf-8') as f:
        json.dump(all_data, f, ensure_ascii=False, indent=4)

    return all_data

# Call the function and store the scraped data
#scraped_data = scrape_wikipedia_tables(url)

# %% [markdown]
# # Scraping Wikipedia: Bullet Points
#
# We broke up scraping into two tasks: scraping tables and scraping bullet points. This jupyter notebook walks you through Libby's bullet scraping process.
#
# ## Ultimate Goal
# Compile a database of all the aldermen who served between 2012 and 2023.
#
# ## Steps
# This will be broken down into two parts. Part 1 is where I will grab all the bullet points from wikipedia. Part 2 is where I scrape the pages of people who have profile links.
#
# # Part 1

# %%
def compile_aldermen_for_wards(ul_element, ward_number, aldermen_dict):
    """
    Gather each the ward aldermen for wards whose aldermen are listed as bullet oints. 
    
    inputs:
        ul_element: element known to contain bullet points
        ward_number: str associated with number of ward
        aldermen_dict: dictionary to contain ward_numbers as the key, values 
        will be a list of dictionaries. Key is an alderman's name, value is any 
        link associated with them
    
    outputs: 
        aldermen_dict: dictionary to contain ward_numbers as the key, values 
        will be a list of dictionaries. Key is an alderman's name, value is any 
        link associated with them
    
    """
    # Define key elements
    
    ward_aldermen = []
    bullet_points = ul_element.cssselect("li")
    for bullet in bullet_points:
        links = bullet.cssselect('a')
        profile_link = None        
        if links is not None:
            for element in links:
                # Wikipedia will often link to a file or its bibliography. I 
                # only want a link if it has the person's biography there
                href = element.get('href')
                if re.search("File", str(href), re.IGNORECASE) or \
                    re.search("cite_note", str(href), re.IGNORECASE):
                    continue
                else:
                    profile_link = "https://en.wikipedia.org/" + href
                    break
        # Now I should create a dictionary with the indivudual as the key and 
        # the links as the value
        # I will then add this dictionary to a list. This list will then be the 
        # value of final dictionary where the key is the ward
        
        # clean name courtesy of: https://stackoverflow.com/questions/640001/how-can-i-remove-text-within-parentheses-with-a-regex
        clean_name = re.sub(r'\([^)]*\)', '', bullet.text_content())
        person_tuple = (str.strip(clean_name), profile_link)
        ward_aldermen.append(person_tuple)
    
    aldermen_dict[ward_number] = ward_aldermen
    
    return aldermen_dict

# %%
def find_ward():

    aldermen_dict = {}
    
    # Define key elements
    url = "https://en.wikipedia.org/wiki/List_of_Chicago_alderpersons_since_1923"
    url_text = httpx.get(url)
    root = lxml.html.fromstring(url_text.text)

    body_content = root.cssselect('div.mw-body-content')[0]
    heading = body_content.cssselect('div.mw-heading.mw-heading3')

    for ward_number in heading:
        num = re.findall("\\d+", ward_number.text_content())
        ward = num[0]
        
        # Each part of the page is structured a bit differently. 
        # Sometimes, I a ul element is found immediately after the heading. Other 
        # times, they have figures or paragraphs after the heading and before the 
        # list of aldermen. For that reason, I grab the next five elements.
        
        sibling_1 = ward_number.getnext()
        sibling_2 = sibling_1.getnext()
        sibling_3 = sibling_2.getnext()
        sibling_4 = sibling_3.getnext()
        sibling_5 = sibling_4.getnext()
        
        for element in [sibling_1, sibling_2, sibling_3, sibling_4, sibling_5]:
            if re.search("table", str(element), re.IGNORECASE):
                # if there's a table associated with this ward, I don't care about
                # it, so I move onto the next ward
                break
            elif re.search("ul", str(element), re.IGNORECASE):
                aldermen_dict = \
                    compile_aldermen_for_wards(element, ward, aldermen_dict)
                break
            else:
                continue

    return aldermen_dict

# %%
aldermen_dict = find_ward()

aldermen_dict
# Out:
# {'5': [('Charles S. Eaton', None),
#   ('Leonard J. Grossman', None),
#   ('Charles S. Eaton', None),
#   ('Irving J. Schreiber', None),
#   ('James J. Cusack Jr.', None),
#   ('Paul Howard Douglas',
#    'https://en.wikipedia.org//wiki/Paul_Howard_Douglas'),
#   ('Bertram B. Moss', None),
#   ('Robert E. Merriam', 'https://en.wikipedia.org//wiki/Robert_E._Merriam'),
#   ('Leon Despres', 'https://en.wikipedia.org//wiki/Leon_Despres'),
#   ('Ross Lathrop', None),
#   ('Lawrence Bloom', None),
#   ('Barbara Holt', None),
#   ('Leslie Hairston', 'https://en.wikipedia.org//wiki/Leslie_Hairston')],
#  '6': [('Guy Guernsey', None),
#   ('John F. Healy', None),
#   ('Patrick Sheridan Smith', None),
#   ('Francis J. Hogan', None),
#   ('David R. Muir', None),
#   ('Sydney A. Jones Jr.', None),
#   ('Robert H. Miller', None),
#   ('A. A. Rayner Jr.',
#    'https://en.wikipedia.org//w/index.php?title=A._A._Rayner_Jr.&action=edit&redlink=1'),
#   ('Eugene Sawyer', 'https://en.wikipedia.org//wiki/Eugene_Sawyer'),
#   ('John O. Steele',
#    'https://en.wikipedia.org//w/index.php?title=John_O._Steele&action=edit&redlink=1'),
#   ('Freddrenna Lyle', 'https://en.wikipedia.org//wiki/Freddrenna_Lyle'),
#   ('Roderick Sawyer', 'https://en.wikipedia.org//wiki/Roderick_Sawyer')],
#  '7': [('Ross A. Woodhull', None),
#   ('Clement A. Nance', None),
#   ('Barnet Hodes', None),
#   ('Thomas J. Daley', None),
#   ('Nicholas J. Bohling', None),
#   ('Robert S. Wilinski', None),
#   ('Gerald E. Jones', None),
#   ('Robert S. Wilinski', None),
#   ('Joseph G. Bertrand', None),
#   ('William Beavers', 'https://en.wikipedia.org//wiki/William_Beavers'),
#   ('Darcel Beavers', None),
#   ('Sandi Jackson', 'https://en.wikipedia.org//wiki/Sandi_Jackson'),
#   ('Natashia Holmes', 'https://en.wikipedia.org//wiki/Natashia_Holmes'),
#   ('Gregory Mitchell', 'https://en.wikipedia.org//wiki/Gregory_Mitchell')],
#  '8': [('William D. Meyering',
#    'https://en.wikipedia.org//wiki/William_D._Meyering'),
#   ('David L. Sutton',
#    'https://en.wikipedia.org//w/index.php?title=David_L._Sutton&action=edit&redlink=1'),
#   ('Michael F. Mulcahy', None),
#   ('Roy E. Olin', None),
#   ('Einar Johnson', None),
#   ('James A. Condon', None),
#   ('William Cousins Jr.',
#    'https://en.wikipedia.org//wiki/William_Cousins_(judge)'),
#   ('Marian Humes', None),
#   ('Keith Caldwell', None),
#   ('Lorraine L. Dixon', None),
#   ('Todd Stroger', 'https://en.wikipedia.org//wiki/Todd_Stroger'),
#   ('Michelle A. Harris', 'https://en.wikipedia.org//wiki/Michelle_A._Harris')],
#  '9': [('Sheldon M. Govier', None),
#   ('Arthur G. Lindell', None),
#   ('Reginald DuBois', None),
#   ('Dominic J. Lupo', None),
#   ('Alexander A. Adduci', None),
#   ('Robert Shaw',
#    'https://en.wikipedia.org//wiki/Robert_Shaw_(Illinois_politician)'),
#   ('Perry H. Hutchinson', None),
#   ('Robert Shaw', None),
#   ('Melvin Powell Sr.[2]', None),
#   ('Anthony Beale', 'https://en.wikipedia.org//wiki/Anthony_Beale')],
#  '10': [('Ernest M. Cross', None),
#   ('William A. Rowan', 'https://en.wikipedia.org//wiki/William_A._Rowan'),
#   ('William J. Pieczynski', None),
#   ('Emil V. Pacini', None),
#   ('John J. Buchanan', None),
#   ('Edward Vrdolyak', 'https://en.wikipedia.org//wiki/Edward_Vrdolyak'),
#   ('Victor Vrdolyak', None),
#   ('John J. Buchanan', None),
#   ('John Pope', 'https://en.wikipedia.org//wiki/John_Pope_(alderman)'),
#   ('Susan Sadlowski Garza',
#    'https://en.wikipedia.org//wiki/Susan_Sadlowski_Garza')],
#  '11': [('Timothy A. Hogan', None),
#   ('John P. Wilson', None),
#   ('Thomas A. Doyle', None),
#   ('Hugh B. Connelly', None),
#   ('John F. Wall', None),
#   ('Stanley J. Nowakowski', None),
#   ('Matthew J. Danaher', None),
#   ('Michael Anthony Bilandic',
#    'https://en.wikipedia.org//wiki/Michael_Anthony_Bilandic'),
#   ('Patrick M. Huels', None),
#   ('James Balcer', 'https://en.wikipedia.org//wiki/James_Balcer'),
#   ('Patrick Daley Thompson',
#    'https://en.wikipedia.org//wiki/Patrick_Daley_Thompson'),
#   ('Nicole Lee', 'https://en.wikipedia.org//wiki/Nicole_Lee_(politician)')],
#  '12': [('Ernest J. Kunstmann', None),
#   ('Bryan Hartnett', None),
#   ('Benjamin J. Zintak', None),
#   ('Bryan Hartnett', None),
#   ('Edmund J. Kucharski',
#    'https://en.wikipedia.org//w/index.php?title=Edmund_J._Kucharski&action=edit&redlink=1'),
#   ('Arthur V. Zelezinski', None),
#   ('Donald T. Swinarski',
#    'https://en.wikipedia.org//wiki/Donald_T._Swinarski'),
#   ('George A. Kwak', None),
#   ('Aloysius Majerczyk', 'https://en.wikipedia.org//wiki/Aloysius_Majerczyk'),
#   ('Mark Fary',
#    'https://en.wikipedia.org//w/index.php?title=Mark_Fary&action=edit&redlink=1'),
#   ('Ray Frias', None),
#   ('George Cardenas', 'https://en.wikipedia.org//wiki/George_Cardenas'),
#   ('Anabel Abarca', 'https://en.wikipedia.org//wiki/Anabel_Abarca'),
#   ('Julia Ramirez', 'https://en.wikipedia.org//wiki/Julia_Ramirez')],
#  '13': [('Joseph B. McDonough', None),
#   ('Thomas A. Doyle', None),
#   ('John E. Egan', None),
#   ('Michael P. Hogan', None),
#   ('John E. Egan', None),
#   ('David W. Healy', None),
#   ('Casamir J. Staszcuk', None),
#   ('John S. Madrzyk', None),
#   ('Frank Olivo', 'https://en.wikipedia.org//wiki/Frank_Olivo'),
#   ('Marty Quinn',
#    'https://en.wikipedia.org//wiki/Marty_Quinn_(Illinois_politician)')],
#  '15': [('Thomas F. Byrne', None),
#   ('James F. Kovarik', None),
#   ('Edward F. Vyzral', None),
#   ('Frank Micek', None),
#   ('Joseph J. Krska', None),
#   ('Francis X. Lawlor', None),
#   ('Kenneth B. Jaksy', None),
#   ('Frank J. Brady', None),
#   ('Marlene C. Carter', None),
#   ('Virgil E. Jones', None),
#   ('Theodore Thomas',
#    'https://en.wikipedia.org//wiki/Theodore_Thomas_(alderman)'),
#   ('Toni Foulkes', 'https://en.wikipedia.org//wiki/Toni_Foulkes'),
#   ('Raymond Lopez', 'https://en.wikipedia.org//wiki/Raymond_Lopez')],
#  '16': [('Terence Moran',
#    'https://en.wikipedia.org//w/index.php?title=Terence_Moran&action=edit&redlink=1'),
#   ('John S. Boyle',
#    'https://en.wikipedia.org//w/index.php?title=John_S._Boyle&action=edit&redlink=1'),
#   ('Paul M. Sheridan Sr.', None),
#   ('Paul M. Sheridan Jr.', None),
#   ('Anna Langford', 'https://en.wikipedia.org//wiki/Anna_Langford'),
#   ('Eloise Barden', None),
#   ('Anna Langford', 'https://en.wikipedia.org//wiki/Anna_Langford'),
#   ('Shirley Coleman', 'https://en.wikipedia.org//wiki/Shirley_Coleman'),
#   ('JoAnn Thompson', None),
#   ('Toni Foulkes', 'https://en.wikipedia.org//wiki/Toni_Foulkes'),
#   ('Stephanie Coleman', 'https://en.wikipedia.org//wiki/Stephanie_Coleman')],
#  '17': [('John H. Lyle',
#    'https://en.wikipedia.org//w/index.php?title=John_H._Lyle&action=edit&redlink=1'),
#   ('Robert E. Barbee', None),
#   ('James G. Coyle', None),
#   ('Frank J. Corr', 'https://en.wikipedia.org//wiki/Frank_J._Corr'),
#   ('William T. Murphy', None),
#   ('Arthur A. Slight', None),
#   ('Charles Chew', 'https://en.wikipedia.org//wiki/Charles_Chew'),
#   ('William H. Shannon', None),
#   ('Tyrone McFolling', None),
#   ('Allan Streeter', None),
#   ('Terry Peterson',
#    'https://en.wikipedia.org//w/index.php?title=Terry_Peterson&action=edit&redlink=1'),
#   ('Latasha Thomas', 'https://en.wikipedia.org//wiki/Latasha_Thomas'),
#   ('David H. Moore', 'https://en.wikipedia.org//wiki/David_H._Moore')],
#  '18': [('Patrick F. Ryan', None),
#   ('Walter W. Morris', None),
#   ('Harry E. Perry', None),
#   ("Bernard J. O'Hallaren", None),
#   ('Thomas J. Corcoran', None),
#   ('Frank J. McGrath', None),
#   ('James C. Murray', None),
#   ('Edward J. Hines', None),
#   ('Robert T. Kellam', None),
#   ('Thomas W. Murphy',
#    'https://en.wikipedia.org//wiki/Thomas_W._Murphy_(Illinois_judge)'),
#   ('Lona Lane', None),
#   ('Derrick Curtis', 'https://en.wikipedia.org//wiki/Derrick_Curtis')],
#  '20': [('Henry L. Fick', None),
#   ('A.J. Prignano', None),
#   ('William V. Pacelli', 'https://en.wikipedia.org//wiki/William_V._Pacelli'),
#   ('Anthony Pistilli', None),
#   ('Kenneth E. Campbell', None),
#   ('Clifford P. Kelley', None),
#   ('Ernest Jones', None),
#   ('Arenda Troutman', 'https://en.wikipedia.org//wiki/Arenda_Troutman'),
#   ('Willie Cochran', 'https://en.wikipedia.org//wiki/Willie_Cochran'),
#   ('Jeanette Taylor', 'https://en.wikipedia.org//wiki/Jeanette_Taylor')],
#  '21': [('Dennis A. Horan', None),
#   ('John J. Lagodney', None),
#   ('Joseph F. Ropa', None),
#   ('Charles S. Bonk', 'https://en.wikipedia.org//wiki/Charles_S._Bonk'),
#   ('Samuel Yaksic', None),
#   ('Wilson Frost, Democratic', 'https://en.wikipedia.org//wiki/Wilson_Frost'),
#   ('Bennett Stewart, Democratic',
#    'https://en.wikipedia.org//wiki/Bennett_Stewart'),
#   ('Niles Sherman', None),
#   ('Jesse J. Evans', None),
#   ('Leonard DeVille', None),
#   ('Howard Brookins Jr.', 'https://en.wikipedia.org//wiki/Howard_Brookins')],
#  '22': [('Joseph Cepak', None),
#   ('Henry Sonnenschein', None),
#   ('Otto F. Janousek', None),
#   ('Frank D. Stemberk', None),
#   ('Jesús "Chuy" García',
#    'https://en.wikipedia.org//wiki/Jes%C3%BAs_%22Chuy%22_Garc%C3%ADa'),
#   ('Ricardo Muñoz', 'https://en.wikipedia.org//wiki/Ricardo_Mu%C3%B1oz'),
#   ('Michael D. Rodriguez',
#    'https://en.wikipedia.org//wiki/Michael_Rodriguez_(politician)')],
#  '23': [('Joseph O. Kostner', None),
#   ('John Toman', None),
#   ('Joseph Kacena Jr.', None),
#   ('George J. Tourek', None),
#   ('Frank J. Kuta', None),
#   ('Joseph Potempa', None),
#   ('Bill Lipinski', 'https://en.wikipedia.org//wiki/Bill_Lipinski'),
#   ('William F. Krystyniak', None),
#   ('James Laski', None),
#   ('Michael R. Zalewski',
#    'https://en.wikipedia.org//wiki/Michael_R._Zalewski'),
#   ('Silvana Tabares', 'https://en.wikipedia.org//wiki/Silvana_Tabares')],
#  '24': [('Jacob Arvey', 'https://en.wikipedia.org//wiki/Jacob_Arvey'),
#   ('Fred Fischman', None),
#   ('Louis London', None),
#   ('Sidney D. Deutsch', None),
#   ('Benjamin F. Lewis', 'https://en.wikipedia.org//wiki/Benjamin_F._Lewis'),
#   ('George W. Collins', 'https://en.wikipedia.org//wiki/George_W._Collins'),
#   ('David Rhodes', None),
#   ('Walter Shumpert', None),
#   ('William C. Henry', None),
#   ('Jesse L. Miller Jr.', None),
#   ('Michael Chandler', None),
#   ('Sharon Denise Dixon',
#    'https://en.wikipedia.org//wiki/Sharon_Denise_Dixon'),
#   ('Michael Chandler', None),
#   ('Michael Scott Jr.', 'https://en.wikipedia.org//wiki/Michael_Scott_Jr.')],
#  '28': [('George M. Maypole',
#    'https://en.wikipedia.org//wiki/George_M._Maypole'),
#   ('George D. Kells', None),
#   ('Patrick P. Petrone', None),
#   ('Anthony G. Girolami', None),
#   ('Alphonse Tomaso', None),
#   ('Angelo C. Provenzano', None),
#   ('Joseph Jambrone', None),
#   ('Jimmy L. Washington', None),
#   ('William Carothers', None),
#   ('Ed Smith', 'https://en.wikipedia.org//wiki/Ed_Smith_(alderman)'),
#   ('Jason Ervin', 'https://en.wikipedia.org//wiki/Jason_Ervin')],
#  '29': [('Albert J. Horan', None),
#   ('Thomas J. Terrell', None),
#   ('Joseph S. Gillespie', None),
#   ('George R. Pigott', None),
#   ('Thomas F. Burke', None),
#   ('Robert Biggs', None),
#   ('Leroy Cross', None),
#   ('Danny K. Davis', 'https://en.wikipedia.org//wiki/Danny_K._Davis'),
#   ('Sam Burrell',
#    'https://en.wikipedia.org//w/index.php?title=Sam_Burrell&action=edit&redlink=1'),
#   ('Isaac Carothers', 'https://en.wikipedia.org//wiki/Isaac_Carothers'),
#   ('Deborah L. Graham', 'https://en.wikipedia.org//wiki/Deborah_L._Graham'),
#   ('Chris Taliaferro', 'https://en.wikipedia.org//wiki/Chris_Taliaferro')],
#  '30': [('John S. Clark Jr.', None),
#   ('Edward J. Upton', None),
#   ('Edmund J. Hughes', None),
#   ('Daniel J. Ronan', None),
#   ('Edwin H. McMahon', None),
#   ('Elmer R. Filippini', None),
#   ('George A. Hagopian', None),
#   ('George J. Hagopian', None),
#   ('Carole Bialczak', None),
#   ('Michael Wojcik', None),
#   ('Ariel Reboyras', 'https://en.wikipedia.org//wiki/Ariel_Reboyras')],
#  '33': [('Joseph Petlak', None),
#   ('George M. Rozczynialski', None),
#   ('Joseph P. Rostenkowski', None),
#   ('Zefiryn H. Kadow', None),
#   ('Vincent S. Zwiefka', None),
#   ('John B. Brandt', None),
#   ('Robert Brandt', None),
#   ('Rex Sande', None),
#   ('Richard Mell', 'https://en.wikipedia.org//wiki/Richard_Mell'),
#   ('Deb Mell', 'https://en.wikipedia.org//wiki/Deb_Mell'),
#   ('Rossana Rodriguez-Sanchez',
#    'https://en.wikipedia.org//wiki/Rossana_Rodriguez-Sanchez')],
#  '34': [('Edward J. Kaindl', None),
#   ('Thomas Patrick Keane', None),
#   ('Matt Porten', None),
#   ('Herbert F. Geisler', None),
#   ('Rex Sande', None),
#   ('Wilson Frost', None),
#   ('Lemuel Austin Jr.', None),
#   ('Carrie Austin', 'https://en.wikipedia.org//wiki/Carrie_Austin'),
#   ('Bill Conway', 'https://en.wikipedia.org//wiki/Bill_Conway_(politician)')],
#  '35': [('George Seif', None),
#   ('Matt Porten', None),
#   ('Walter J. Orlikoski', None),
#   ('Frank Peska',
#    'https://en.wikipedia.org//w/index.php?title=Frank_Peska&action=edit&redlink=1'),
#   ('Casimir C. Laskowski',
#    'https://en.wikipedia.org//wiki/Casimir_C._Laskowski'),
#   ('John C. Marcin',
#    'https://en.wikipedia.org//w/index.php?title=John_C._Marcin&action=edit&redlink=1'),
#   ('Joseph S. Kotlarz Jr.', None),
#   ('Michael A. Wojcik',
#    'https://en.wikipedia.org//w/index.php?title=Michael_A._Wojcik&action=edit&redlink=1'),
#   ('Vilma Colom', None),
#   ('Rey Colón', 'https://en.wikipedia.org//wiki/Rey_Col%C3%B3n'),
#   ('Carlos Ramirez-Rosa',
#    'https://en.wikipedia.org//wiki/Carlos_Ramirez-Rosa')],
#  '36': [('A.C. Sievers', None),
#   ('Eugene L. Nusser', None),
#   ('George W. Robinson', None),
#   ('Richard M. Walsh', None),
#   ('Louis P. Garippo', None),
#   ('Frank Ringa', None),
#   ('Alfred J. Cilella', None),
#   ('Robert L. Massey', None),
#   ('John F. Aiello', None),
#   ('Louis Farina', None),
#   ('William Banks', 'https://en.wikipedia.org//wiki/William_Banks_(alderman)'),
#   ('John Rice', 'https://en.wikipedia.org//wiki/John_Rice_(alderman)'),
#   ('Nicholas Sposato', 'https://en.wikipedia.org//wiki/Nicholas_Sposato'),
#   ('Gilbert Villegas', 'https://en.wikipedia.org//wiki/Gilbert_Villegas')],
#  '37': [('Wiley W. Mills', None),
#   ('James H. Taylor', None),
#   ('Wiley W. Mills', None),
#   ('Roger J. Kiley', None),
#   ('Francis E. Callahan', None),
#   ('William J. Lancaster', None),
#   ('Paul T. Corcoran', None),
#   ('Thomas J. Casey', None),
#   ('Frank A. Damato', None),
#   ('Percy Z. Giles', None),
#   ('Emma Mitts', 'https://en.wikipedia.org//wiki/Emma_Mitts')],
#  '39': [('Frank J. Tomczak', None),
#   ('Frank R. Ringa', None),
#   ('Walter J. Orlikoski', None),
#   ('James H. Hurley', None),
#   ('Hyman L. Brody', None),
#   ('Ray N. Jacobs', None),
#   ('George L. Buckley', None),
#   ('Phillip A. Shapiro', None),
#   ('Anthony C. Laurino', None),
#   ('Margaret Laurino', 'https://en.wikipedia.org//wiki/Margaret_Laurino'),
#   ('Samantha Nugent', 'https://en.wikipedia.org//wiki/Samantha_Nugent')],
#  '40': [('Christ A. Jensen', None),
#   ('John William Chapman',
#    'https://en.wikipedia.org//wiki/John_William_Chapman'),
#   ('Joseph C. Ross', None),
#   ('Samuel Gurman', None),
#   ('Benjamin M. Becker', None),
#   ('Seymour Simon', 'https://en.wikipedia.org//wiki/Seymour_Simon'),
#   ('Nathan J. Kaplan', None),
#   ('Seymour Simon', 'https://en.wikipedia.org//wiki/Seymour_Simon'),
#   ('Solomon Gutstein', 'https://en.wikipedia.org//wiki/Solomon_Gutstein'),
#   ('Ivan Rittenberg', None),
#   ("Patrick J. O'Connor",
#    'https://en.wikipedia.org//wiki/Patrick_J._O%27Connor'),
#   ('Andre Vasquez', 'https://en.wikipedia.org//wiki/Andre_Vasquez')],
#  '41': [('Thomas J. Bowler', None),
#   ('James C. Moreland', None),
#   ('William J. Cowhey', None),
#   ('Joseph P. Immel Jr.', None),
#   ('Harry Bell', None),
#   ('Edward T. Scholl', 'https://en.wikipedia.org//wiki/Edward_T._Scholl'),
#   ('Roman Pucinski', 'https://en.wikipedia.org//wiki/Roman_Pucinski'),
#   ('Brian Doherty',
#    'https://en.wikipedia.org//wiki/Brian_Doherty_(politician)'),
#   ("Mary O'Connor",
#    'https://en.wikipedia.org//wiki/Mary_O%27Connor_(alderman)'),
#   ('Anthony Napolitano', 'https://en.wikipedia.org//wiki/Anthony_Napolitano')],
#  '44': [('Thomas O. Wallace', None),
#   ('Albert Loescher', None),
#   ('John J. Grealis', None),
#   ('Leo C. Burmeister Jr.', None),
#   ('Thomas Rosenberg', None),
#   ('William Singer', 'https://en.wikipedia.org//wiki/William_Singer'),
#   ('Dick Simpson', 'https://en.wikipedia.org//wiki/Dick_Simpson_(politician)'),
#   ('Bruce Young', None),
#   ('John Merlo', 'https://en.wikipedia.org//wiki/John_Merlo'),
#   ('Bernie Hansen', 'https://en.wikipedia.org//wiki/Bernie_Hansen'),
#   ('Tom Tunney', 'https://en.wikipedia.org//wiki/Tom_Tunney'),
#   ('Bennett Lawson', 'https://en.wikipedia.org//wiki/Bennett_Lawson')],
#  '45': [('Leo M. Brieske', None),
#   ('William Feigenbutz', None),
#   ('Edwin F. Meyer',
#    'https://en.wikipedia.org//w/index.php?title=Edwin_F._Meyer&action=edit&redlink=1'),
#   ('Theron W. Merryman',
#    'https://en.wikipedia.org//w/index.php?title=Theron_W._Merryman&action=edit&redlink=1'),
#   ('Charles J. Fleck', None),
#   ('Charles H. Weber', None),
#   ('Edwin P. Fifielski', None),
#   ('Richard S. Clewis', None),
#   ('Gerald McLaughlin', None),
#   ('Patrick Levar', 'https://en.wikipedia.org//wiki/Patrick_Levar'),
#   ('John Arena', 'https://en.wikipedia.org//wiki/John_Arena'),
#   ('Jim Gardiner',
#    'https://en.wikipedia.org//wiki/Jim_Gardiner_(Chicago_politician)')],
#  '46': [('Oscar F. Nelson', None),
#   ('James F. Young', None),
#   ('Joseph R. Kerwin', None),
#   ('Christopher B. Cohen',
#    'https://en.wikipedia.org//wiki/Christopher_B_Cohen'),
#   ('Ralph Axelrod', None),
#   ('Jerome M. Orbach', None),
#   ('Helen Shiller', 'https://en.wikipedia.org//wiki/Helen_Shiller'),
#   ('James Cappleman', 'https://en.wikipedia.org//wiki/James_Cappleman'),
#   ('Angela Clay', 'https://en.wikipedia.org//wiki/Angela_Clay')],
#  '48': [('Frank J. Link', None),
#   ('Francis L. Boutell [dates 2]',
#    'https://en.wikipedia.org//wiki/Cook_County_Board_of_Commissioners'),
#   ('John A. Massen', None),
#   ('Robert C. Quirk', None),
#   ('Allen A. Freeman', None),
#   ('Morris H. Hirsh', None),
#   ("Robert J. O'Rourke", None),
#   ('Marilou Hedlund', None),
#   ('Dennis H. Block',
#    'https://en.wikipedia.org//w/index.php?title=Dennis_H._Block&action=edit&redlink=1'),
#   ('Marion K. Volini', None),
#   ('Kathy Osterman', 'https://en.wikipedia.org//wiki/Kathy_Osterman'),
#   ('Mary Ann Smith', 'https://en.wikipedia.org//wiki/Mary_Ann_Smith'),
#   ('Harry Osterman', 'https://en.wikipedia.org//wiki/Harry_Osterman'),
#   ('Leni Manaa-Hoppenworth',
#    'https://en.wikipedia.org//wiki/Leni_Manaa-Hoppenworth')]}

# %% [markdown]
# # Part 2
# Great! Now that I have my dictionary. I find the start and end year for each person. I am particularly interested in the years 2012-2023, so I won't bother to get data for everyone.

# %%
def find_alder_link(aldermen_dict):
    aldermen_dates_dict = {}
    for ward, aldermen_and_links in aldermen_dict.items():
        all_info = []
        for tup in aldermen_and_links:
            alderperson = tup[0]
            link = tup[1]
            # we have a series of different labels for dates so we can evaluate 
            # what has happened
            if link is not None:
                dates = "link exists"
                resp = httpx.get(link)
                if resp.status_code == 200:
                    root = lxml.html.fromstring(resp.text)
                    # This is the box that has the in office dates, but sometimes 
                    # it doesn't exist
                    info_box = root.cssselect("table.infobox.vcard")
                    print(alderperson,info_box, len(info_box))
                    if len(info_box) == 1:
                        info_elements = info_box[0].cssselect('th.infobox-header')
                        print(info_elements)
                        if len(info_elements) == 0:
                            dates = "no headings"
                        else:
                            for element in info_elements:
                                print(f"{ward}, {alderperson}, has this heading: {element.text_content()}")
                                # we want to find the row header that is associated 
                                # with being a Chicago alderperson — and not the council president                       
                                if re.search("ward", (element.text_content()), re.IGNORECASE) \
                                    or re.search("alder", element.text_content(), \
                                        re.IGNORECASE) or re.search("Chicago City Council", \
                                            element.text_content(), re.IGNORECASE) and \
                                            not re.search("President", element.text_content(), re.IGNORECASE):
                                    print("Good heading!")
                                    # We also want to see if they have the correct ward listed -- if there is one. 
                                    if re.search("\\d+", element.text_content(), re.IGNORECASE) is None or ward in element.text_content():
                                        print("either ward in text or no ward")
                                        # We want to find the row itself this is associated 
                                        # with rather than the actual header     
                                        row_parent = element.getparent()
                                        # The header we want is in the next two rows
                                        header_option1 = row_parent.getnext()
                                        header_option2 = header_option1.getnext()
                                        if re.search("office", header_option1.text_content(), re.IGNORECASE):
                                            dates_raw = header_option1.text_content()
                                            dates_raw = re.sub("In office", "", dates_raw)
                                            dates_raw = re.sub("Assumed office", "", dates_raw)
                        # clean name courtesy of: https://stackoverflow.com/questions/640001/how-can-i-remove-text-within-parentheses-with-a-regex
                                            dates_raw = re.sub(r'\([^)]*\)', ' ', dates_raw)
                                            dates_raw = re.sub(r'\xa0', ' ', dates_raw)
                                            dates = str.strip(re.sub(r'\[[^)]*\]', ' ', dates_raw))
                                        elif re.search("office", header_option2.text_content(), re.IGNORECASE):
                                            dates_raw = header_option2.text_content()
                                            dates_raw = re.sub("In office", "", dates_raw)
                                            dates_raw = re.sub("Assumed office", "", dates_raw)
                        # clean name courtesy of: https://stackoverflow.com/questions/640001/how-can-i-remove-text-within-parentheses-with-a-regex
                                            dates_raw = re.sub(r'\([^)]*\)', ' ', dates_raw)
                                            dates_raw = re.sub(r'\xa0', ' ', dates_raw)
                                            dates = str.strip(re.sub(r'\[[^)]*\]', '', dates_raw))
                                        else:
                                            dates = "unknown from link"
                                        break
                                else:
                                    print("bad heading")
                                    dates = "no suitable heading"
                    else:
                        dates = "ERROR, BOX ELEMENT"
                    
                else:
                    dates = "ERROR, BAD LINK"       
            else:
                dates = "Unknown"
                
            person_tup = (alderperson, dates)
            all_info.append(person_tup)
            
        aldermen_dates_dict[ward] = all_info
            
    return aldermen_dates_dict

# %% [markdown]
# I've checked through the bad links and decided I'm okay with letting those go.
#
# Now it's time to finalize a list of aldermen who have a start date and end date, add them to a dictionary

# %%
aldermen_dates_dict = find_alder_link(aldermen_dict)
# Out:
# Paul Howard Douglas [<Element table at 0x11f8cd180>] 1
# [<Element th at 0x12841b250>, <Element th at 0x12841a990>, <Element th at 0x12841a120>, <Element th at 0x128418af0>, <Element th at 0x11fc5e3a0>]
# 5, Paul Howard Douglas, has this heading: United States Senatorfrom Illinois
# bad heading
# 5, Paul Howard Douglas, has this heading: Member of the Chicago City Councilfrom the 5th ward
# Good heading!
# either ward in text or no ward
# Robert E. Merriam [] 0
# Leon Despres [<Element table at 0x11f8cd180>] 1
# [<Element th at 0x11f89dd10>, <Element th at 0x12804b7f0>]
# 5, Leon Despres, has this heading: Chicago Alderman from the 5th ward
# Good heading!
# either ward in text or no ward
# Leslie Hairston [<Element table at 0x12841a120>] 1
# [<Element th at 0x128c984b0>, <Element th at 0x12841b250>]
# 5, Leslie Hairston, has this heading: Member of the Chicago City Councilfrom the 5th ward
# Good heading!
# either ward in text or no ward
# Eugene Sawyer [<Element table at 0x128c98550>] 1
# [<Element th at 0x128418af0>, <Element th at 0x12804aad0>, <Element th at 0x11f8cc190>]
# 6, Eugene Sawyer, has this heading: 53rd Mayor of Chicago
# bad heading
# 6, Eugene Sawyer, has this heading: Member of the Chicago City Councilfrom the 6th ward
# Good heading!
# either ward in text or no ward
# Freddrenna Lyle [<Element table at 0x12841a120>] 1
# [<Element th at 0x11f80c820>, <Element th at 0x11f820d70>, <Element th at 0x128007660>]
# 6, Freddrenna Lyle, has this heading: Judge of the Circuit Court of Cook County
# bad heading
# 6, Freddrenna Lyle, has this heading: Member of the Chicago City Council from the 6th ward
# Good heading!
# either ward in text or no ward
# Roderick Sawyer [<Element table at 0x12841b250>] 1
# [<Element th at 0x12841a120>, <Element th at 0x128c6c050>]
# 6, Roderick Sawyer, has this heading: Member of the Chicago City Councilfrom the 6th ward
# Good heading!
# either ward in text or no ward
# William Beavers [<Element table at 0x11f80c820>] 1
# [<Element th at 0x11f8cc190>, <Element th at 0x11fc5e3a0>, <Element th at 0x11f89dd10>]
# 7, William Beavers, has this heading: Cook County Commissioner from the 4th district
# bad heading
# 7, William Beavers, has this heading: Member of the Chicago City Council from the 7th ward
# Good heading!
# either ward in text or no ward
# Sandi Jackson [<Element table at 0x12841b250>] 1
# [<Element th at 0x128418af0>, <Element th at 0x128442170>]
# 7, Sandi Jackson, has this heading: Member of the Chicago City Councilfrom the 7th ward
# Good heading!
# either ward in text or no ward
# Natashia Holmes [<Element table at 0x11f8cc190>] 1
# [<Element th at 0x128007660>, <Element th at 0x11f80c820>]
# 7, Natashia Holmes, has this heading: City of Chicago Alderman from the 7th ward
# Good heading!
# either ward in text or no ward
# Gregory Mitchell [<Element table at 0x11f820d70>] 1
# [<Element th at 0x128c984b0>, <Element th at 0x12841b250>]
# 7, Gregory Mitchell, has this heading: Member of the Chicago City Councilfrom the 7th ward
# Good heading!
# either ward in text or no ward
# William D. Meyering [<Element table at 0x12841a120>] 1
# [<Element th at 0x12804aad0>, <Element th at 0x11f8cc190>, <Element th at 0x128442580>, <Element th at 0x128440c80>, <Element th at 0x128442f80>]
# 8, William D. Meyering, has this heading: Chief Probation Officer of Cook County[1]
# bad heading
# 8, William D. Meyering, has this heading: Cook County Sheriff
# bad heading
# 8, William D. Meyering, has this heading: Chicago Alderman from the 8th ward[3]
# Good heading!
# either ward in text or no ward
# William Cousins Jr. [<Element table at 0x11f80c820>] 1
# [<Element th at 0x11f89dd10>, <Element th at 0x1284405a0>, <Element th at 0x128402e40>, <Element th at 0x1284038e0>, <Element th at 0x128403ac0>]
# 8, William Cousins Jr., has this heading: Illinois Appellate Court Judge
# bad heading
# 8, William Cousins Jr., has this heading: Illinois Circuit Court Judge
# bad heading
# 8, William Cousins Jr., has this heading: Chicago Alderman from the 8th ward
# Good heading!
# either ward in text or no ward
# Todd Stroger [<Element table at 0x128442580>] 1
# [<Element th at 0x11fc5e3a0>, <Element th at 0x12841a120>, <Element th at 0x12804aad0>, <Element th at 0x128ca1220>, <Element th at 0x1284018b0>]
# 8, Todd Stroger, has this heading: President of the Cook County Board of Commissioners
# bad heading
# 8, Todd Stroger, has this heading: Chicago Alderman from the 8th ward
# Good heading!
# either ward in text or no ward
# Michelle A. Harris [<Element table at 0x128440c80>] 1
# [<Element th at 0x128442f80>, <Element th at 0x11f80c820>]
# 8, Michelle A. Harris, has this heading: Member of the Chicago City Councilfrom the 8th ward
# Good heading!
# either ward in text or no ward
# Robert Shaw [<Element table at 0x128005e50>] 1
# [<Element th at 0x128007660>, <Element th at 0x12841b250>, <Element th at 0x128403cf0>]
# 9, Robert Shaw, has this heading: Commissioner of Cook County Board of Review from the 3rd district
# bad heading
# 9, Robert Shaw, has this heading: Chicago Alderman from the 9th ward
# Good heading!
# either ward in text or no ward
# Anthony Beale [<Element table at 0x128442f80>] 1
# [<Element th at 0x11f8cc190>, <Element th at 0x12804aad0>]
# 9, Anthony Beale, has this heading: Member of the Chicago City Councilfrom the 9th ward
# Good heading!
# either ward in text or no ward
# William A. Rowan [<Element table at 0x12804b3e0>] 1
# [<Element th at 0x11fc5e3a0>, <Element th at 0x128403520>, <Element th at 0x128403c00>, <Element th at 0x128403390>]
# 10, William A. Rowan, has this heading: United States Comptroller of Customs at Chicago
# bad heading
# 10, William A. Rowan, has this heading: Member of the U.S. House of Representativesfrom Illinois's 2nd district
# bad heading
# 10, William A. Rowan, has this heading: Member of the Chicago City Councilfrom the 10th ward
# Good heading!
# either ward in text or no ward
# Edward Vrdolyak [<Element table at 0x12804bc00>] 1
# [<Element th at 0x12804b3e0>, <Element th at 0x128401f90>, <Element th at 0x128401ae0>, <Element th at 0x128403cf0>]
# 10, Edward Vrdolyak, has this heading: Member of the Chicago City Council for Chicago's 10th ward
# Good heading!
# either ward in text or no ward
# John Pope [<Element table at 0x1284013b0>] 1
# [<Element th at 0x12841a120>, <Element th at 0x1284028f0>]
# 10, John Pope, has this heading: City of Chicago Aldermanfrom the 10th ward
# Good heading!
# either ward in text or no ward
# Susan Sadlowski Garza [<Element table at 0x12841b250>] 1
# [<Element th at 0x1284013b0>, <Element th at 0x128401f90>]
# 10, Susan Sadlowski Garza, has this heading: Member of the Chicago City Councilfrom the 10th ward
# Good heading!
# either ward in text or no ward
# Michael Anthony Bilandic [<Element table at 0x11f8cc190>] 1
# [<Element th at 0x12841b250>, <Element th at 0x1284028f0>, <Element th at 0x128401d60>, <Element th at 0x1284011d0>, <Element th at 0x1284010e0>, <Element th at 0x1284683c0>, <Element th at 0x1284680a0>]
# 11, Michael Anthony Bilandic, has this heading: Chief Justice of the Illinois Supreme Court
# bad heading
# 11, Michael Anthony Bilandic, has this heading: Member of the Supreme Court of Illinois
# bad heading
# 11, Michael Anthony Bilandic, has this heading: Illinois Appellate Court judge
# bad heading
# 11, Michael Anthony Bilandic, has this heading: 49th Mayor of Chicago
# bad heading
# 11, Michael Anthony Bilandic, has this heading: Chicago Alderman from the 11th Ward
# Good heading!
# either ward in text or no ward
# James Balcer [<Element table at 0x12804bc00>] 1
# [<Element th at 0x11f80c820>, <Element th at 0x1284680f0>]
# 11, James Balcer, has this heading: City of Chicago Alderman
# Good heading!
# either ward in text or no ward
# Patrick Daley Thompson [<Element table at 0x1284028f0>] 1
# [<Element th at 0x128401d60>, <Element th at 0x11fc5e3a0>]
# 11, Patrick Daley Thompson, has this heading: Member of the Chicago City Councilfrom the 11th ward
# Good heading!
# either ward in text or no ward
# Nicole Lee [<Element table at 0x12841a120>] 1
# [<Element th at 0x1284011d0>, <Element th at 0x1284680f0>]
# 11, Nicole Lee, has this heading: Member of the Chicago City Councilfrom the 11th ward
# Good heading!
# either ward in text or no ward
# Donald T. Swinarski [] 0
# Aloysius Majerczyk [] 0
# George Cardenas [<Element table at 0x1284013b0>] 1
# [<Element th at 0x1284028f0>, <Element th at 0x128469a90>, <Element th at 0x12846a030>]
# 12, George Cardenas, has this heading: Member of the Cook County Board of Reviewfrom the 1st district
# bad heading
# 12, George Cardenas, has this heading: Former member of the Chicago City Councilfrom the 12th ward
# Good heading!
# either ward in text or no ward
# Anabel Abarca [<Element table at 0x1284439d0>] 1
# [<Element th at 0x1284433e0>, <Element th at 0x12846b2a0>]
# 12, Anabel Abarca, has this heading: Member of the Chicago City Councilfrom the 12th ward
# Good heading!
# either ward in text or no ward
# Julia Ramirez [<Element table at 0x12841b390>] 1
# [<Element th at 0x12841b250>, <Element th at 0x12846a030>]
# 12, Julia Ramirez, has this heading: Member of the Chicago City Councilfrom the 12th ward
# Good heading!
# either ward in text or no ward
# Frank Olivo [<Element table at 0x1284031b0>] 1
# [<Element th at 0x128403660>, <Element th at 0x1284012c0>]
# 13, Frank Olivo, has this heading: Member of the Chicago City Council from the 13th ward
# Good heading!
# either ward in text or no ward
# Marty Quinn [<Element table at 0x1284027b0>] 1
# [<Element th at 0x1284031b0>, <Element th at 0x128400a00>]
# 13, Marty Quinn, has this heading: Member of the Chicago City Council from the 13th ward
# Good heading!
# either ward in text or no ward
# Theodore Thomas [] 0
# Toni Foulkes [<Element table at 0x128402b70>] 1
# [<Element th at 0x128400820>, <Element th at 0x1284027b0>]
# 15, Toni Foulkes, has this heading: Member of the Chicago City Councilfrom the 16th ward
# Good heading!
# 15, Toni Foulkes, has this heading: Member of the Chicago City Councilfrom the 15th ward
# Good heading!
# either ward in text or no ward
# Raymond Lopez [<Element table at 0x128401310>] 1
# [<Element th at 0x128400780>, <Element th at 0x128400ff0>]
# 15, Raymond Lopez, has this heading: Member of the Chicago City Councilfrom the 15th ward
# Good heading!
# either ward in text or no ward
# Anna Langford [<Element table at 0x128403b10>] 1
# [<Element th at 0x128402800>, <Element th at 0x128403480>]
# 16, Anna Langford, has this heading: Chicago Alderman from the 16th Ward
# Good heading!
# either ward in text or no ward
# Anna Langford [<Element table at 0x128401f40>] 1
# [<Element th at 0x128403b10>, <Element th at 0x128400780>]
# 16, Anna Langford, has this heading: Chicago Alderman from the 16th Ward
# Good heading!
# either ward in text or no ward
# Shirley Coleman [<Element table at 0x128402800>] 1
# [<Element th at 0x128401f40>, <Element th at 0x1284037f0>]
# 16, Shirley Coleman, has this heading: City of Chicago Alderman
# Good heading!
# either ward in text or no ward
# Toni Foulkes [<Element table at 0x128403b10>] 1
# [<Element th at 0x128402fd0>, <Element th at 0x128403480>]
# 16, Toni Foulkes, has this heading: Member of the Chicago City Councilfrom the 16th ward
# Good heading!
# either ward in text or no ward
# Stephanie Coleman [<Element table at 0x128400780>] 1
# [<Element th at 0x1284031b0>, <Element th at 0x128403b10>]
# 16, Stephanie Coleman, has this heading: Member of the Chicago City Councilfrom the 16th ward
# Good heading!
# either ward in text or no ward
# Frank J. Corr [<Element table at 0x128400ff0>] 1
# [<Element th at 0x128400780>, <Element th at 0x11e2d8500>]
# 17, Frank J. Corr, has this heading: Acting Mayor of Chicago
# bad heading
# 17, Frank J. Corr, has this heading: Personal details
# bad heading
# Charles Chew [<Element table at 0x1284031b0>] 1
# [<Element th at 0x128403480>, <Element th at 0x1284420d0>]
# 17, Charles Chew, has this heading: Member of the Illinois Senatefrom the 16th district29th district
# bad heading
# 17, Charles Chew, has this heading: Personal details
# bad heading
# Latasha Thomas [<Element table at 0x128403b10>] 1
# [<Element th at 0x1284027b0>, <Element th at 0x128441040>]
# 17, Latasha Thomas, has this heading: City of Chicago Alderman
# Good heading!
# either ward in text or no ward
# David H. Moore [<Element table at 0x128442530>] 1
# [<Element th at 0x11e2d8500>, <Element th at 0x128443b10>]
# 17, David H. Moore, has this heading: Member of the Chicago City Councilfrom the 17th ward
# Good heading!
# either ward in text or no ward
# Thomas W. Murphy [] 0
# Derrick Curtis [<Element table at 0x1284420d0>] 1
# [<Element th at 0x128442530>, <Element th at 0x12804a530>]
# 18, Derrick Curtis, has this heading: Member of the Chicago City Councilfrom the 18th ward
# Good heading!
# either ward in text or no ward
# William V. Pacelli [] 0
# Arenda Troutman [<Element table at 0x128441040>] 1
# [<Element th at 0x1284420d0>, <Element th at 0x128007610>]
# 20, Arenda Troutman, has this heading: City of Chicago Alderman
# Good heading!
# either ward in text or no ward
# Willie Cochran [<Element table at 0x128400780>] 1
# [<Element th at 0x128443b10>, <Element th at 0x12804b250>]
# 20, Willie Cochran, has this heading: City of Chicago Alderman
# Good heading!
# either ward in text or no ward
# Jeanette Taylor [<Element table at 0x128442530>] 1
# [<Element th at 0x1284027b0>, <Element th at 0x11fcb0f00>]
# 20, Jeanette Taylor, has this heading: Member of the Chicago City Councilfrom the 20th Ward
# Good heading!
# either ward in text or no ward
# Charles S. Bonk [] 0
# Wilson Frost, Democratic [<Element table at 0x12804b980>] 1
# [<Element th at 0x128441040>, <Element th at 0x11f821090>, <Element th at 0x11f820c80>]
# 21, Wilson Frost, Democratic, has this heading: Commissioner of the Cook County Board of Appeals
# bad heading
# 21, Wilson Frost, Democratic, has this heading: Chicago Alderman
# Good heading!
# either ward in text or no ward
# Bennett Stewart, Democratic [<Element table at 0x128402fd0>] 1
# [<Element th at 0x12804b980>, <Element th at 0x11f820d20>, <Element th at 0x11f8234d0>]
# 21, Bennett Stewart, Democratic, has this heading: Member of the U.S. House of Representativesfrom Illinois's 1st district
# bad heading
# 21, Bennett Stewart, Democratic, has this heading: Chicago Alderman from the 21st Ward
# Good heading!
# either ward in text or no ward
# Howard Brookins Jr. [<Element table at 0x11f820c80>] 1
# [<Element th at 0x12804b250>, <Element th at 0x11f823d40>]
# 21, Howard Brookins Jr., has this heading: Member of the Chicago City Councilfrom the 21st ward
# Good heading!
# either ward in text or no ward
# Jesús "Chuy" García [<Element table at 0x11f8234d0>] 1
# [<Element th at 0x128443b10>, <Element th at 0x11f820d20>, <Element th at 0x12846af80>, <Element th at 0x12846a6c0>, <Element th at 0x12846ada0>]
# 22, Jesús "Chuy" García, has this heading: Member of the U.S. House of Representativesfrom Illinois's 4th district
# bad heading
# 22, Jesús "Chuy" García, has this heading: Member of the Cook County Board of Commissionersfrom the 7th district
# bad heading
# 22, Jesús "Chuy" García, has this heading: Member of the Illinois Senatefrom the 1st district
# bad heading
# 22, Jesús "Chuy" García, has this heading: Member of the Chicago City Councilfrom the 22nd ward
# Good heading!
# either ward in text or no ward
# Ricardo Muñoz [<Element table at 0x1284027b0>] 1
# [<Element th at 0x11f823d40>, <Element th at 0x12846a850>]
# 22, Ricardo Muñoz, has this heading: Member of the Chicago City Council from the 22nd Ward
# Good heading!
# either ward in text or no ward
# Michael D. Rodriguez [<Element table at 0x11f820d20>] 1
# [<Element th at 0x128007610>, <Element th at 0x12846a6c0>]
# 22, Michael D. Rodriguez, has this heading: Member of the Chicago City Councilfrom the 22nd ward
# Good heading!
# either ward in text or no ward
# Bill Lipinski [<Element table at 0x12804b980>] 1
# [<Element th at 0x128402fd0>, <Element th at 0x12846a850>, <Element th at 0x12846a170>]
# 23, Bill Lipinski, has this heading: Member of the U.S. House of Representativesfrom Illinois
# bad heading
# 23, Bill Lipinski, has this heading: Member of the Chicago City Council
# Good heading!
# either ward in text or no ward
# Michael R. Zalewski [<Element table at 0x1284693b0>] 1
# [<Element th at 0x1284027b0>, <Element th at 0x128468c80>]
# 23, Michael R. Zalewski, has this heading: Member of the Chicago City Councilfor the 23rd ward
# Good heading!
# either ward in text or no ward
# Silvana Tabares [<Element table at 0x128443b10>] 1
# [<Element th at 0x1284693b0>, <Element th at 0x12846a850>, <Element th at 0x12846a170>]
# 23, Silvana Tabares, has this heading: Member of the Chicago City Councilfrom the 23rd ward
# Good heading!
# either ward in text or no ward
# Jacob Arvey [<Element table at 0x11f823d40>] 1
# [<Element th at 0x12804b980>, <Element th at 0x128468c80>, <Element th at 0x1284681e0>]
# 24, Jacob Arvey, has this heading: Democratic National Committeeman from Illinois
# bad heading
# 24, Jacob Arvey, has this heading: Personal details
# bad heading
# 24, Jacob Arvey, has this heading: Military service
# bad heading
# Benjamin F. Lewis [<Element table at 0x1284687d0>] 1
# [<Element th at 0x12804b250>, <Element th at 0x1284693b0>]
# 24, Benjamin F. Lewis, has this heading: Alderman of the Chicago City Council
# Good heading!
# either ward in text or no ward
# George W. Collins [<Element table at 0x11f820d20>] 1
# [<Element th at 0x1284687d0>, <Element th at 0x128468190>, <Element th at 0x1284681e0>]
# 24, George W. Collins, has this heading: Member of the U.S. House of Representativesfrom Illinois's 6th district
# bad heading
# 24, George W. Collins, has this heading: Personal details
# bad heading
# 24, George W. Collins, has this heading: Military service
# bad heading
# Sharon Denise Dixon [<Element table at 0x12804b250>] 1
# [<Element th at 0x12804b980>, <Element th at 0x128478140>]
# 24, Sharon Denise Dixon, has this heading: Chicago City Council
# Good heading!
# either ward in text or no ward
# Michael Scott Jr. [<Element table at 0x11f820370>] 1
# [<Element th at 0x11f820320>, <Element th at 0x11f821e00>, <Element th at 0x11f821f90>]
# 24, Michael Scott Jr., has this heading: Member of theCook County Board of Commissionersfrom the 2nd district
# bad heading
# 24, Michael Scott Jr., has this heading: Member of theChicago City Councilfrom the 24th ward
# Good heading!
# either ward in text or no ward
# George M. Maypole [] 0
# Ed Smith [<Element table at 0x11f820730>] 1
# []
# Jason Ervin [<Element table at 0x11f80cf50>] 1
# [<Element th at 0x11f8208c0>, <Element th at 0x11f821f90>]
# 28, Jason Ervin, has this heading: Member of the Chicago City Councilfrom the 28th ward
# Good heading!
# either ward in text or no ward
# Danny K. Davis [<Element table at 0x11f820be0>] 1
# [<Element th at 0x1186eb6b0>, <Element th at 0x12841a6c0>, <Element th at 0x11f823d40>, <Element th at 0x11fc5f4d0>]
# 29, Danny K. Davis, has this heading: Member of the U.S. House of Representativesfrom Illinois's 7th district
# bad heading
# 29, Danny K. Davis, has this heading: Member of the Cook County Board of Commissioners
# bad heading
# 29, Danny K. Davis, has this heading: Member of the Chicago City Councilfrom the 29th Ward
# Good heading!
# either ward in text or no ward
# Isaac Carothers [] 0
# Deborah L. Graham [<Element table at 0x11f820320>] 1
# [<Element th at 0x11f823480>, <Element th at 0x12804b020>, <Element th at 0x12804bca0>]
# 29, Deborah L. Graham, has this heading: Member of the Chicago City Council from the 29th ward
# Good heading!
# either ward in text or no ward
# Chris Taliaferro [<Element table at 0x11f8208c0>] 1
# [<Element th at 0x11de34e10>, <Element th at 0x11f821f90>, <Element th at 0x11f820fa0>]
# 29, Chris Taliaferro, has this heading: Member of the Chicago City Councilfrom the 29th ward
# Good heading!
# either ward in text or no ward
# Ariel Reboyras [<Element table at 0x12804bca0>] 1
# [<Element th at 0x11f820be0>, <Element th at 0x128c98550>]
# 30, Ariel Reboyras, has this heading: Member of the Chicago City Councilfrom the 30th ward
# Good heading!
# either ward in text or no ward
# Richard Mell [<Element table at 0x11f823d40>] 1
# [<Element th at 0x12841a6c0>, <Element th at 0x11f8208c0>, <Element th at 0x11f821f90>]
# 33, Richard Mell, has this heading: 2nd Vice Mayor of Chicago
# bad heading
# 33, Richard Mell, has this heading: Member of the Chicago City Councilfrom the 33rd ward
# Good heading!
# either ward in text or no ward
# Deb Mell [<Element table at 0x1186eb6b0>] 1
# [<Element th at 0x11f823d40>, <Element th at 0x128442210>, <Element th at 0x128440e60>]
# 33, Deb Mell, has this heading: Member of the Chicago City Council from the 33rd ward
# Good heading!
# either ward in text or no ward
# Rossana Rodriguez-Sanchez [<Element table at 0x11f8208c0>] 1
# [<Element th at 0x11f821f90>, <Element th at 0x12804bca0>]
# 33, Rossana Rodriguez-Sanchez, has this heading: Member of the Chicago City Councilfrom the 33rd ward
# Good heading!
# either ward in text or no ward
# Carrie Austin [<Element table at 0x11de34e10>] 1
# [<Element th at 0x11f820be0>, <Element th at 0x128442210>]
# 34, Carrie Austin, has this heading: Member of the Chicago City Councilfrom the 34th ward
# Good heading!
# either ward in text or no ward
# Bill Conway [<Element table at 0x11f8208c0>] 1
# [<Element th at 0x11f823480>, <Element th at 0x128440e60>, <Element th at 0x128441ae0>]
# 34, Bill Conway, has this heading: Member of the Chicago City Councilfrom the 34th ward
# Good heading!
# either ward in text or no ward
# Casimir C. Laskowski [<Element table at 0x11f821f90>] 1
# [<Element th at 0x11f8208c0>, <Element th at 0x128442490>, <Element th at 0x1284433e0>]
# 35, Casimir C. Laskowski, has this heading: 1st Vice Mayor of Chicago
# bad heading
# 35, Casimir C. Laskowski, has this heading: Member of the Chicago City Councilfrom the 35th ward
# Good heading!
# either ward in text or no ward
# Rey Colón [<Element table at 0x128440e60>] 1
# [<Element th at 0x11f821f90>, <Element th at 0x128441ae0>]
# 35, Rey Colón, has this heading: City of Chicago Alderman
# Good heading!
# either ward in text or no ward
# Carlos Ramirez-Rosa [<Element table at 0x11f823d40>] 1
# [<Element th at 0x128c98550>, <Element th at 0x128468aa0>]
# 35, Carlos Ramirez-Rosa, has this heading: Member of the Chicago City Councilfrom the 35th ward
# Good heading!
# either ward in text or no ward
# William Banks [<Element table at 0x11f820be0>] 1
# [<Element th at 0x11f823d40>, <Element th at 0x12846a6c0>]
# 36, William Banks, has this heading: City of Chicago Aldermanfrom the 36th Ward
# Good heading!
# either ward in text or no ward
# John Rice [<Element table at 0x12804bca0>] 1
# [<Element th at 0x11f8208c0>, <Element th at 0x128469860>]
# 36, John Rice, has this heading: City of Chicago Aldermanfrom the 36th Ward
# Good heading!
# either ward in text or no ward
# Nicholas Sposato [<Element table at 0x128442490>] 1
# [<Element th at 0x11f821f90>, <Element th at 0x128469400>, <Element th at 0x12846a1c0>]
# 36, Nicholas Sposato, has this heading: Member of the Chicago City Councilfrom the 38th ward
# Good heading!
# 36, Nicholas Sposato, has this heading: Member of the Chicago City Councilfrom the 36th ward
# Good heading!
# either ward in text or no ward
# Gilbert Villegas [<Element table at 0x128441ae0>] 1
# [<Element th at 0x11f820be0>, <Element th at 0x128469860>, <Element th at 0x12846a6c0>]
# 36, Gilbert Villegas, has this heading: Member of the Chicago City Councilfrom the 36th ward
# Good heading!
# either ward in text or no ward
# Emma Mitts [<Element table at 0x128c98550>] 1
# [<Element th at 0x1284433e0>, <Element th at 0x128469400>]
# 37, Emma Mitts, has this heading: Member of the Chicago City Councilfrom the 37th ward
# Good heading!
# either ward in text or no ward
# Margaret Laurino [<Element table at 0x11f823d40>] 1
# [<Element th at 0x128442490>, <Element th at 0x12846b2a0>]
# 39, Margaret Laurino, has this heading: City of Chicago Aldermanfrom the 39th Ward
# Good heading!
# either ward in text or no ward
# Samantha Nugent [<Element table at 0x128469860>] 1
# [<Element th at 0x128469400>, <Element th at 0x11f8208c0>, <Element th at 0x128403840>]
# 39, Samantha Nugent, has this heading: President pro tempore of the Chicago City Council
# bad heading
# 39, Samantha Nugent, has this heading: Member of the Chicago City Councilfrom the 39th ward
# Good heading!
# either ward in text or no ward
# John William Chapman [<Element table at 0x128441ae0>] 1
# [<Element th at 0x128c98550>, <Element th at 0x128400aa0>, <Element th at 0x128400a50>]
# 40, John William Chapman, has this heading: 37th Lieutenant Governor of Illinois
# bad heading
# 40, John William Chapman, has this heading: Member of the Chicago City Councilfrom the 40th Ward
# Good heading!
# either ward in text or no ward
# Seymour Simon [] 0
# Seymour Simon [] 0
# Solomon Gutstein [] 0
# Patrick J. O'Connor [<Element table at 0x11f820be0>] 1
# [<Element th at 0x128402940>, <Element th at 0x128402990>]
# 40, Patrick J. O'Connor, has this heading: Chicago Aldermanfrom the 40th Ward
# Good heading!
# either ward in text or no ward
# Andre Vasquez [<Element table at 0x1284433e0>] 1
# [<Element th at 0x11f821f90>, <Element th at 0x128400aa0>]
# 40, Andre Vasquez, has this heading: Member of the Chicago City Councilfrom the 40th ward
# Good heading!
# either ward in text or no ward
# Edward T. Scholl [] 0
# Roman Pucinski [<Element table at 0x128402e90>] 1
# [<Element th at 0x128402990>, <Element th at 0x1284017c0>, <Element th at 0x128401ae0>, <Element th at 0x128400140>]
# 41, Roman Pucinski, has this heading: Member of the U.S. House of Representativesfrom Illinois's 11th district
# bad heading
# 41, Roman Pucinski, has this heading: City of Chicago Aldermanfrom the 41st Ward
# Good heading!
# either ward in text or no ward
# Brian Doherty [<Element table at 0x1284022b0>] 1
# [<Element th at 0x128402e90>, <Element th at 0x128401f90>]
# 41, Brian Doherty, has this heading: Member of the Chicago City Councilfrom the 41st ward
# Good heading!
# either ward in text or no ward
# Mary O'Connor [<Element table at 0x1284017c0>] 1
# [<Element th at 0x1284022b0>, <Element th at 0x128469860>]
# 41, Mary O'Connor, has this heading: Member of the Chicago City Councilfrom the 41st ward
# Good heading!
# either ward in text or no ward
# Anthony Napolitano [<Element table at 0x11e2858b0>] 1
# [<Element th at 0x11f83fc50>, <Element th at 0x11fcb0820>]
# 41, Anthony Napolitano, has this heading: Member of the Chicago City Councilfrom the 41st ward
# Good heading!
# either ward in text or no ward
# William Singer [<Element table at 0x11f8cc1e0>] 1
# [<Element th at 0x1186eb6b0>, <Element th at 0x11f8cc2d0>]
# 44, William Singer, has this heading: Chicago Alderman
# Good heading!
# either ward in text or no ward
# Dick Simpson [<Element table at 0x128c98550>] 1
# [<Element th at 0x11f8cdc70>, <Element th at 0x128ca1680>]
# 44, Dick Simpson, has this heading: Chicago Alderman from the 44th Ward
# Good heading!
# either ward in text or no ward
# John Merlo [<Element table at 0x11fcb0fa0>] 1
# [<Element th at 0x11f8cd180>, <Element th at 0x12846ae90>]
# 44, John Merlo, has this heading: Member of the Chicago City Council from the 44th ward
# Good heading!
# either ward in text or no ward
# Bernie Hansen [<Element table at 0x11fc4b9d0>] 1
# [<Element th at 0x12846a710>, <Element th at 0x12846a3a0>]
# 44, Bernie Hansen, has this heading: City of Chicago Alderman
# Good heading!
# either ward in text or no ward
# Tom Tunney [<Element table at 0x128469590>] 1
# [<Element th at 0x11e2858b0>, <Element th at 0x128469770>, <Element th at 0x12846a2b0>]
# 44, Tom Tunney, has this heading: 8th Vice Mayor of Chicago
# bad heading
# 44, Tom Tunney, has this heading: Member of the Chicago City Councilfrom the 44th ward
# Good heading!
# either ward in text or no ward
# Bennett Lawson [<Element table at 0x128469cc0>] 1
# [<Element th at 0x128469590>, <Element th at 0x128469270>]
# 44, Bennett Lawson, has this heading: Member of the Chicago City Councilfrom the 44th ward
# Good heading!
# either ward in text or no ward
# Patrick Levar [] 0
# John Arena [<Element table at 0x11f8cc2d0>] 1
# [<Element th at 0x12846bcf0>, <Element th at 0x128468c80>]
# 45, John Arena, has this heading: Member of the Chicago City Councilfrom the 45th ward
# Good heading!
# either ward in text or no ward
# Jim Gardiner [<Element table at 0x1284681e0>] 1
# [<Element th at 0x11f8cdc70>, <Element th at 0x12846b930>]
# 45, Jim Gardiner, has this heading: Member of the Chicago City Councilfrom the 45th ward
# Good heading!
# either ward in text or no ward
# Christopher B. Cohen [] 0
# Helen Shiller [<Element table at 0x1284681e0>] 1
# [<Element th at 0x128469cc0>, <Element th at 0x128469e00>]
# 46, Helen Shiller, has this heading: Member of the Chicago City Council from the 46th ward
# Good heading!
# either ward in text or no ward
# James Cappleman [<Element table at 0x128469b30>] 1
# [<Element th at 0x12846bcf0>, <Element th at 0x11f820230>]
# 46, James Cappleman, has this heading: Member of the Chicago City Councilfrom the 46th ward
# Good heading!
# either ward in text or no ward
# Angela Clay [<Element table at 0x11f83fc50>] 1
# [<Element th at 0x128469b30>, <Element th at 0x128469090>]
# 46, Angela Clay, has this heading: Member of the Chicago City Councilfrom the 46th ward
# Good heading!
# either ward in text or no ward
# Francis L. Boutell [dates 2] [<Element table at 0x128469cc0>] 1
# [<Element th at 0x11f8235c0>, <Element th at 0x12846bcf0>, <Element th at 0x12804b1b0>, <Element th at 0x12804b2a0>, <Element th at 0x12804bb10>, <Element th at 0x1280483c0>]
# 48, Francis L. Boutell [dates 2], has this heading: Type
# bad heading
# 48, Francis L. Boutell [dates 2], has this heading: Leadership
# bad heading
# 48, Francis L. Boutell [dates 2], has this heading: Structure
# bad heading
# 48, Francis L. Boutell [dates 2], has this heading: Elections
# bad heading
# 48, Francis L. Boutell [dates 2], has this heading: Meeting place
# bad heading
# 48, Francis L. Boutell [dates 2], has this heading: Website
# bad heading
# Kathy Osterman [<Element table at 0x128469090>] 1
# [<Element th at 0x128469e00>, <Element th at 0x11f8cc2d0>]
# 48, Kathy Osterman, has this heading: Member of Chicago City Councilfor the 48th ward
# Good heading!
# either ward in text or no ward
# Mary Ann Smith [<Element table at 0x128ca26c0>] 1
# [<Element th at 0x12846be80>, <Element th at 0x1280483c0>]
# 48, Mary Ann Smith, has this heading: Member of Chicago City Councilfor the 48th ward
# Good heading!
# either ward in text or no ward
# Harry Osterman [<Element table at 0x12804bd40>] 1
# [<Element th at 0x128469b30>, <Element th at 0x11e2858b0>, <Element th at 0x11f821220>]
# 48, Harry Osterman, has this heading: Member of the Chicago City Councilfrom the 48th ward
# Good heading!
# either ward in text or no ward
# Leni Manaa-Hoppenworth [<Element table at 0x11f820230>] 1
# [<Element th at 0x12804bd40>, <Element th at 0x11f8235c0>]
# 48, Leni Manaa-Hoppenworth, has this heading: Member of the Chicago City Councilfrom the 48th ward
# Good heading!
# either ward in text or no ward

# %%
aldermen_dates_dict
# Out:
# {'5': [('Charles S. Eaton', 'Unknown'),
#   ('Leonard J. Grossman', 'Unknown'),
#   ('Charles S. Eaton', 'Unknown'),
#   ('Irving J. Schreiber', 'Unknown'),
#   ('James J. Cusack Jr.', 'Unknown'),
#   ('Paul Howard Douglas', '1939–1942'),
#   ('Bertram B. Moss', 'Unknown'),
#   ('Robert E. Merriam', 'ERROR, BOX ELEMENT'),
#   ('Leon Despres', '1955–1975'),
#   ('Ross Lathrop', 'Unknown'),
#   ('Lawrence Bloom', 'Unknown'),
#   ('Barbara Holt', 'Unknown'),
#   ('Leslie Hairston', 'May 1999 – May 15, 2023')],
#  '6': [('Guy Guernsey', 'Unknown'),
#   ('John F. Healy', 'Unknown'),
#   ('Patrick Sheridan Smith', 'Unknown'),
#   ('Francis J. Hogan', 'Unknown'),
#   ('David R. Muir', 'Unknown'),
#   ('Sydney A. Jones Jr.', 'Unknown'),
#   ('Robert H. Miller', 'Unknown'),
#   ('A. A. Rayner Jr.', 'ERROR, BAD LINK'),
#   ('Eugene Sawyer', 'February 28, 1971  – December 2, 1987'),
#   ('John O. Steele', 'ERROR, BAD LINK'),
#   ('Freddrenna Lyle', 'February 8, 1998 – May 15, 2011'),
#   ('Roderick Sawyer', 'May 16, 2011 – May 15, 2023')],
#  '7': [('Ross A. Woodhull', 'Unknown'),
#   ('Clement A. Nance', 'Unknown'),
#   ('Barnet Hodes', 'Unknown'),
#   ('Thomas J. Daley', 'Unknown'),
#   ('Nicholas J. Bohling', 'Unknown'),
#   ('Robert S. Wilinski', 'Unknown'),
#   ('Gerald E. Jones', 'Unknown'),
#   ('Robert S. Wilinski', 'Unknown'),
#   ('Joseph G. Bertrand', 'Unknown'),
#   ('William Beavers', '1983–2006'),
#   ('Darcel Beavers', 'Unknown'),
#   ('Sandi Jackson', 'May 21, 2007 – January 15, 2013'),
#   ('Natashia Holmes', 'February 13, 2013 – May 18, 2015'),
#   ('Gregory Mitchell', 'May 18, 2015')],
#  '8': [('William D. Meyering', 'April 1923 – December 1930'),
#   ('David L. Sutton', 'ERROR, BAD LINK'),
#   ('Michael F. Mulcahy', 'Unknown'),
#   ('Roy E. Olin', 'Unknown'),
#   ('Einar Johnson', 'Unknown'),
#   ('James A. Condon', 'Unknown'),
#   ('William Cousins Jr.', '1967  –1976'),
#   ('Marian Humes', 'Unknown'),
#   ('Keith Caldwell', 'Unknown'),
#   ('Lorraine L. Dixon', 'Unknown'),
#   ('Todd Stroger', 'September 5, 2001 – December 4, 2006'),
#   ('Michelle A. Harris', 'December 13, 2006')],
#  '9': [('Sheldon M. Govier', 'Unknown'),
#   ('Arthur G. Lindell', 'Unknown'),
#   ('Reginald DuBois', 'Unknown'),
#   ('Dominic J. Lupo', 'Unknown'),
#   ('Alexander A. Adduci', 'Unknown'),
#   ('Robert Shaw', 'May 1987 – December 1998'),
#   ('Perry H. Hutchinson', 'Unknown'),
#   ('Robert Shaw', 'Unknown'),
#   ('Melvin Powell Sr.[2]', 'Unknown'),
#   ('Anthony Beale', 'May 1999')],
#  '10': [('Ernest M. Cross', 'Unknown'),
#   ('William A. Rowan', '1927–1942'),
#   ('William J. Pieczynski', 'Unknown'),
#   ('Emil V. Pacini', 'Unknown'),
#   ('John J. Buchanan', 'Unknown'),
#   ('Edward Vrdolyak', '1971–1987'),
#   ('Victor Vrdolyak', 'Unknown'),
#   ('John J. Buchanan', 'Unknown'),
#   ('John Pope', 'May 1999   – May 2015'),
#   ('Susan Sadlowski Garza', 'May 18, 2015 – May 15, 2023')],
#  '11': [('Timothy A. Hogan', 'Unknown'),
#   ('John P. Wilson', 'Unknown'),
#   ('Thomas A. Doyle', 'Unknown'),
#   ('Hugh B. Connelly', 'Unknown'),
#   ('John F. Wall', 'Unknown'),
#   ('Stanley J. Nowakowski', 'Unknown'),
#   ('Matthew J. Danaher', 'Unknown'),
#   ('Michael Anthony Bilandic', 'June 12, 1969 – June 7, 1977'),
#   ('Patrick M. Huels', 'Unknown'),
#   ('James Balcer', '1997–2015'),
#   ('Patrick Daley Thompson', 'May 18, 2015 – February 14, 2022'),
#   ('Nicole Lee', 'March 28, 2022')],
#  '12': [('Ernest J. Kunstmann', 'Unknown'),
#   ('Bryan Hartnett', 'Unknown'),
#   ('Benjamin J. Zintak', 'Unknown'),
#   ('Bryan Hartnett', 'Unknown'),
#   ('Edmund J. Kucharski', 'ERROR, BAD LINK'),
#   ('Arthur V. Zelezinski', 'Unknown'),
#   ('Donald T. Swinarski', 'ERROR, BOX ELEMENT'),
#   ('George A. Kwak', 'Unknown'),
#   ('Aloysius Majerczyk', 'ERROR, BOX ELEMENT'),
#   ('Mark Fary', 'ERROR, BAD LINK'),
#   ('Ray Frias', 'Unknown'),
#   ('George Cardenas', '2003–2022'),
#   ('Anabel Abarca', 'December 14, 2022 – May 15, 2023'),
#   ('Julia Ramirez', 'May 15, 2023')],
#  '13': [('Joseph B. McDonough', 'Unknown'),
#   ('Thomas A. Doyle', 'Unknown'),
#   ('John E. Egan', 'Unknown'),
#   ('Michael P. Hogan', 'Unknown'),
#   ('John E. Egan', 'Unknown'),
#   ('David W. Healy', 'Unknown'),
#   ('Casamir J. Staszcuk', 'Unknown'),
#   ('John S. Madrzyk', 'Unknown'),
#   ('Frank Olivo', '1994-2011'),
#   ('Marty Quinn', 'May 2011')],
#  '15': [('Thomas F. Byrne', 'Unknown'),
#   ('James F. Kovarik', 'Unknown'),
#   ('Edward F. Vyzral', 'Unknown'),
#   ('Frank Micek', 'Unknown'),
#   ('Joseph J. Krska', 'Unknown'),
#   ('Francis X. Lawlor', 'Unknown'),
#   ('Kenneth B. Jaksy', 'Unknown'),
#   ('Frank J. Brady', 'Unknown'),
#   ('Marlene C. Carter', 'Unknown'),
#   ('Virgil E. Jones', 'Unknown'),
#   ('Theodore Thomas', 'ERROR, BOX ELEMENT'),
#   ('Toni Foulkes', '2007–2015'),
#   ('Raymond Lopez', 'May 18, 2015')],
#  '16': [('Terence Moran', 'ERROR, BAD LINK'),
#   ('John S. Boyle', 'ERROR, BAD LINK'),
#   ('Paul M. Sheridan Sr.', 'Unknown'),
#   ('Paul M. Sheridan Jr.', 'Unknown'),
#   ('Anna Langford', 'February 1983 – January 27, 1991'),
#   ('Eloise Barden', 'Unknown'),
#   ('Anna Langford', 'February 1983 – January 27, 1991'),
#   ('Shirley Coleman', 'January 27, 1991 – May 30, 2007'),
#   ('JoAnn Thompson', 'Unknown'),
#   ('Toni Foulkes', '2015–2019'),
#   ('Stephanie Coleman', 'May 20, 2019')],
#  '17': [('John H. Lyle', 'ERROR, BAD LINK'),
#   ('Robert E. Barbee', 'Unknown'),
#   ('James G. Coyle', 'Unknown'),
#   ('Frank J. Corr', 'no suitable heading'),
#   ('William T. Murphy', 'Unknown'),
#   ('Arthur A. Slight', 'Unknown'),
#   ('Charles Chew', 'no suitable heading'),
#   ('William H. Shannon', 'Unknown'),
#   ('Tyrone McFolling', 'Unknown'),
#   ('Allan Streeter', 'Unknown'),
#   ('Terry Peterson', 'ERROR, BAD LINK'),
#   ('Latasha Thomas', '2000–2015'),
#   ('David H. Moore', 'May 18, 2015')],
#  '18': [('Patrick F. Ryan', 'Unknown'),
#   ('Walter W. Morris', 'Unknown'),
#   ('Harry E. Perry', 'Unknown'),
#   ("Bernard J. O'Hallaren", 'Unknown'),
#   ('Thomas J. Corcoran', 'Unknown'),
#   ('Frank J. McGrath', 'Unknown'),
#   ('James C. Murray', 'Unknown'),
#   ('Edward J. Hines', 'Unknown'),
#   ('Robert T. Kellam', 'Unknown'),
#   ('Thomas W. Murphy', 'ERROR, BOX ELEMENT'),
#   ('Lona Lane', 'Unknown'),
#   ('Derrick Curtis', 'May 18, 2015')],
#  '20': [('Henry L. Fick', 'Unknown'),
#   ('A.J. Prignano', 'Unknown'),
#   ('William V. Pacelli', 'ERROR, BOX ELEMENT'),
#   ('Anthony Pistilli', 'Unknown'),
#   ('Kenneth E. Campbell', 'Unknown'),
#   ('Clifford P. Kelley', 'Unknown'),
#   ('Ernest Jones', 'Unknown'),
#   ('Arenda Troutman', 'April 1990 – February 2007'),
#   ('Willie Cochran', '2007–2019'),
#   ('Jeanette Taylor', 'May 20, 2019')],
#  '21': [('Dennis A. Horan', 'Unknown'),
#   ('John J. Lagodney', 'Unknown'),
#   ('Joseph F. Ropa', 'Unknown'),
#   ('Charles S. Bonk', 'ERROR, BOX ELEMENT'),
#   ('Samuel Yaksic', 'Unknown'),
#   ('Wilson Frost, Democratic', '1971–1987'),
#   ('Bennett Stewart, Democratic', '1971–1979'),
#   ('Niles Sherman', 'Unknown'),
#   ('Jesse J. Evans', 'Unknown'),
#   ('Leonard DeVille', 'Unknown'),
#   ('Howard Brookins Jr.', 'May 2003 – May 15, 2023')],
#  '22': [('Joseph Cepak', 'Unknown'),
#   ('Henry Sonnenschein', 'Unknown'),
#   ('Otto F. Janousek', 'Unknown'),
#   ('Frank D. Stemberk', 'Unknown'),
#   ('Jesús "Chuy" García', 'March 25, 1986 – January 1, 1993'),
#   ('Ricardo Muñoz', 'January 1993   – May 20, 2019'),
#   ('Michael D. Rodriguez', 'May 20, 2019')],
#  '23': [('Joseph O. Kostner', 'Unknown'),
#   ('John Toman', 'Unknown'),
#   ('Joseph Kacena Jr.', 'Unknown'),
#   ('George J. Tourek', 'Unknown'),
#   ('Frank J. Kuta', 'Unknown'),
#   ('Joseph Potempa', 'Unknown'),
#   ('Bill Lipinski', '1975–1983'),
#   ('William F. Krystyniak', 'Unknown'),
#   ('James Laski', 'Unknown'),
#   ('Michael R. Zalewski', 'May 1995   – May 31, 2018'),
#   ('Silvana Tabares', 'June 28, 2018')],
#  '24': [('Jacob Arvey', 'no suitable heading'),
#   ('Fred Fischman', 'Unknown'),
#   ('Louis London', 'Unknown'),
#   ('Sidney D. Deutsch', 'Unknown'),
#   ('Benjamin F. Lewis', 'April 8, 1958 – February 28, 1963'),
#   ('George W. Collins', 'no suitable heading'),
#   ('David Rhodes', 'Unknown'),
#   ('Walter Shumpert', 'Unknown'),
#   ('William C. Henry', 'Unknown'),
#   ('Jesse L. Miller Jr.', 'Unknown'),
#   ('Michael Chandler', 'Unknown'),
#   ('Sharon Denise Dixon', 'May 21, 2007 – May 2011'),
#   ('Michael Chandler', 'Unknown'),
#   ('Michael Scott Jr.', 'May 18, 2015 – June 3, 2022')],
#  '28': [('George M. Maypole', 'ERROR, BOX ELEMENT'),
#   ('George D. Kells', 'Unknown'),
#   ('Patrick P. Petrone', 'Unknown'),
#   ('Anthony G. Girolami', 'Unknown'),
#   ('Alphonse Tomaso', 'Unknown'),
#   ('Angelo C. Provenzano', 'Unknown'),
#   ('Joseph Jambrone', 'Unknown'),
#   ('Jimmy L. Washington', 'Unknown'),
#   ('William Carothers', 'Unknown'),
#   ('Ed Smith', 'no headings'),
#   ('Jason Ervin', 'January 13, 2011')],
#  '29': [('Albert J. Horan', 'Unknown'),
#   ('Thomas J. Terrell', 'Unknown'),
#   ('Joseph S. Gillespie', 'Unknown'),
#   ('George R. Pigott', 'Unknown'),
#   ('Thomas F. Burke', 'Unknown'),
#   ('Robert Biggs', 'Unknown'),
#   ('Leroy Cross', 'Unknown'),
#   ('Danny K. Davis', 'April 16, 1979 – December 20, 1990'),
#   ('Sam Burrell', 'ERROR, BAD LINK'),
#   ('Isaac Carothers', 'ERROR, BOX ELEMENT'),
#   ('Deborah L. Graham', '2010–2015'),
#   ('Chris Taliaferro', 'May 18, 2015')],
#  '30': [('John S. Clark Jr.', 'Unknown'),
#   ('Edward J. Upton', 'Unknown'),
#   ('Edmund J. Hughes', 'Unknown'),
#   ('Daniel J. Ronan', 'Unknown'),
#   ('Edwin H. McMahon', 'Unknown'),
#   ('Elmer R. Filippini', 'Unknown'),
#   ('George A. Hagopian', 'Unknown'),
#   ('George J. Hagopian', 'Unknown'),
#   ('Carole Bialczak', 'Unknown'),
#   ('Michael Wojcik', 'Unknown'),
#   ('Ariel Reboyras', 'May 2003 – May 15, 2023')],
#  '33': [('Joseph Petlak', 'Unknown'),
#   ('George M. Rozczynialski', 'Unknown'),
#   ('Joseph P. Rostenkowski', 'Unknown'),
#   ('Zefiryn H. Kadow', 'Unknown'),
#   ('Vincent S. Zwiefka', 'Unknown'),
#   ('John B. Brandt', 'Unknown'),
#   ('Robert Brandt', 'Unknown'),
#   ('Rex Sande', 'Unknown'),
#   ('Richard Mell', '1975 – July 24, 2013'),
#   ('Deb Mell', 'July 24, 2013 – May 20, 2019'),
#   ('Rossana Rodriguez-Sanchez', 'May 20, 2019')],
#  '34': [('Edward J. Kaindl', 'Unknown'),
#   ('Thomas Patrick Keane', 'Unknown'),
#   ('Matt Porten', 'Unknown'),
#   ('Herbert F. Geisler', 'Unknown'),
#   ('Rex Sande', 'Unknown'),
#   ('Wilson Frost', 'Unknown'),
#   ('Lemuel Austin Jr.', 'Unknown'),
#   ('Carrie Austin', 'August 5, 1994 – March 1, 2023'),
#   ('Bill Conway', 'May 15, 2023')],
#  '35': [('George Seif', 'Unknown'),
#   ('Matt Porten', 'Unknown'),
#   ('Walter J. Orlikoski', 'Unknown'),
#   ('Frank Peska', 'ERROR, BAD LINK'),
#   ('Casimir C. Laskowski', 'April 20, 1955 – April 16, 1979'),
#   ('John C. Marcin', 'ERROR, BAD LINK'),
#   ('Joseph S. Kotlarz Jr.', 'Unknown'),
#   ('Michael A. Wojcik', 'ERROR, BAD LINK'),
#   ('Vilma Colom', 'Unknown'),
#   ('Rey Colón', '2003–2015'),
#   ('Carlos Ramirez-Rosa', 'May 18, 2015')],
#  '36': [('A.C. Sievers', 'Unknown'),
#   ('Eugene L. Nusser', 'Unknown'),
#   ('George W. Robinson', 'Unknown'),
#   ('Richard M. Walsh', 'Unknown'),
#   ('Louis P. Garippo', 'Unknown'),
#   ('Frank Ringa', 'Unknown'),
#   ('Alfred J. Cilella', 'Unknown'),
#   ('Robert L. Massey', 'Unknown'),
#   ('John F. Aiello', 'Unknown'),
#   ('Louis Farina', 'Unknown'),
#   ('William Banks', 'May 1983   – April 2009'),
#   ('John Rice', 'October 6, 2009 – May 16, 2011'),
#   ('Nicholas Sposato', 'May 16, 2011 – May 18, 2015'),
#   ('Gilbert Villegas', 'May 18, 2015')],
#  '37': [('Wiley W. Mills', 'Unknown'),
#   ('James H. Taylor', 'Unknown'),
#   ('Wiley W. Mills', 'Unknown'),
#   ('Roger J. Kiley', 'Unknown'),
#   ('Francis E. Callahan', 'Unknown'),
#   ('William J. Lancaster', 'Unknown'),
#   ('Paul T. Corcoran', 'Unknown'),
#   ('Thomas J. Casey', 'Unknown'),
#   ('Frank A. Damato', 'Unknown'),
#   ('Percy Z. Giles', 'Unknown'),
#   ('Emma Mitts', 'January 7, 2000')],
#  '39': [('Frank J. Tomczak', 'Unknown'),
#   ('Frank R. Ringa', 'Unknown'),
#   ('Walter J. Orlikoski', 'Unknown'),
#   ('James H. Hurley', 'Unknown'),
#   ('Hyman L. Brody', 'Unknown'),
#   ('Ray N. Jacobs', 'Unknown'),
#   ('George L. Buckley', 'Unknown'),
#   ('Phillip A. Shapiro', 'Unknown'),
#   ('Anthony C. Laurino', 'Unknown'),
#   ('Margaret Laurino', 'July 24, 1994 – May 20, 2019'),
#   ('Samantha Nugent', 'May 20, 2019')],
#  '40': [('Christ A. Jensen', 'Unknown'),
#   ('John William Chapman', '1927–1929'),
#   ('Joseph C. Ross', 'Unknown'),
#   ('Samuel Gurman', 'Unknown'),
#   ('Benjamin M. Becker', 'Unknown'),
#   ('Seymour Simon', 'ERROR, BOX ELEMENT'),
#   ('Nathan J. Kaplan', 'Unknown'),
#   ('Seymour Simon', 'ERROR, BOX ELEMENT'),
#   ('Solomon Gutstein', 'ERROR, BOX ELEMENT'),
#   ('Ivan Rittenberg', 'Unknown'),
#   ("Patrick J. O'Connor", 'May 1983   – May 2019'),
#   ('Andre Vasquez', 'May 20, 2019')],
#  '41': [('Thomas J. Bowler', 'Unknown'),
#   ('James C. Moreland', 'Unknown'),
#   ('William J. Cowhey', 'Unknown'),
#   ('Joseph P. Immel Jr.', 'Unknown'),
#   ('Harry Bell', 'Unknown'),
#   ('Edward T. Scholl', 'ERROR, BOX ELEMENT'),
#   ('Roman Pucinski', '1973–1991'),
#   ('Brian Doherty', 'May 1991 – May 2011'),
#   ("Mary O'Connor", 'May 2011 – May 2015'),
#   ('Anthony Napolitano', 'May 18, 2015')],
#  '44': [('Thomas O. Wallace', 'Unknown'),
#   ('Albert Loescher', 'Unknown'),
#   ('John J. Grealis', 'Unknown'),
#   ('Leo C. Burmeister Jr.', 'Unknown'),
#   ('Thomas Rosenberg', 'Unknown'),
#   ('William Singer', '1971–1975'),
#   ('Dick Simpson', '1971–1979'),
#   ('Bruce Young', 'Unknown'),
#   ('John Merlo', '1981–1983'),
#   ('Bernie Hansen', '1983–2002'),
#   ('Tom Tunney', 'January 16, 2003 – May 15, 2023'),
#   ('Bennett Lawson', 'May 15, 2023')],
#  '45': [('Leo M. Brieske', 'Unknown'),
#   ('William Feigenbutz', 'Unknown'),
#   ('Edwin F. Meyer', 'ERROR, BAD LINK'),
#   ('Theron W. Merryman', 'ERROR, BAD LINK'),
#   ('Charles J. Fleck', 'Unknown'),
#   ('Charles H. Weber', 'Unknown'),
#   ('Edwin P. Fifielski', 'Unknown'),
#   ('Richard S. Clewis', 'Unknown'),
#   ('Gerald McLaughlin', 'Unknown'),
#   ('Patrick Levar', 'ERROR, BOX ELEMENT'),
#   ('John Arena', 'May 2011   – May 2019'),
#   ('Jim Gardiner', 'May 20, 2019')],
#  '46': [('Oscar F. Nelson', 'Unknown'),
#   ('James F. Young', 'Unknown'),
#   ('Joseph R. Kerwin', 'Unknown'),
#   ('Christopher B. Cohen', 'ERROR, BOX ELEMENT'),
#   ('Ralph Axelrod', 'Unknown'),
#   ('Jerome M. Orbach', 'Unknown'),
#   ('Helen Shiller', '1987–2011'),
#   ('James Cappleman', 'May 16, 2011 – May 15, 2023'),
#   ('Angela Clay', 'May 15, 2023')],
#  '48': [('Frank J. Link', 'Unknown'),
#   ('Francis L. Boutell [dates 2]', 'no suitable heading'),
#   ('John A. Massen', 'Unknown'),
#   ('Robert C. Quirk', 'Unknown'),
#   ('Allen A. Freeman', 'Unknown'),
#   ('Morris H. Hirsh', 'Unknown'),
#   ("Robert J. O'Rourke", 'Unknown'),
#   ('Marilou Hedlund', 'Unknown'),
#   ('Dennis H. Block', 'ERROR, BAD LINK'),
#   ('Marion K. Volini', 'Unknown'),
#   ('Kathy Osterman', '1987–1989'),
#   ('Mary Ann Smith', '1989–2011'),
#   ('Harry Osterman', 'May 16, 2011 – May 15, 2023'),
#   ('Leni Manaa-Hoppenworth', 'May 15, 2023')]}

# %%
def aldermen_and_dates(aldermen_dates_dict):
    all_data = []
    alderman_and_dates = {}

    for ward, values in aldermen_dates_dict.items():
        aldermen = []
        for alder_info in values:
            alderperson = alder_info[0]
            dates = alder_info[1]
            if re.search("\\d+", dates):
                # Two types of hyphens I have to be aware of here
                if re.search('–', dates):
                    beg_end = re.split('–', dates)
                    begin = beg_end[0]
                elif re.search('-', dates):
                    beg_end = re.split('-', dates)
                    begin = beg_end[0]
                else:
                    beg_end = []
                    begin = dates
                if len(beg_end) == 2:
                    end = beg_end[1]
                else:
                    end = "present"
                    
            # To ensure I'll match Getnet's data, I'll copy the format he used
                row_data = {
                    "Ward": ward,
                    "Alderperson": alderperson,
                    "Start Date": str.strip(begin),
                    "End Date": str.strip(end),
                    "Party": None,
                    "Notes": None
                }
                all_data.append(row_data)
                    
            else:
                continue
            
    #with open('../data/wiki/libbys_scraped_data.json', 'w', encoding='utf-8') as f:
    #    json.dump(all_data, f, ensure_ascii=False, indent=4)

    return all_data

# %% [markdown]
# # Test Combining

# %%
url = 'https://en.wikipedia.org/wiki/List_of_Chicago_alderpersons_since_1923'
    
    # Call the function and store the scraped data
scraped_data = scrape_wikipedia_tables(url)

alderperson_dict = find_ward()
alder_dates = find_alder_link(alderperson_dict)
bullet_data = aldermen_and_dates(alder_dates)
# Out:
# 5, Paul Howard Douglas, has this heading: United States Senatorfrom Illinois
# 5, Paul Howard Douglas, has this heading: Member of the Chicago City Councilfrom the 5th ward
# Good heading!
# either ward in text or no ward
# 5, Leon Despres, has this heading: Chicago Alderman from the 5th ward
# Good heading!
# either ward in text or no ward
# 5, Leslie Hairston, has this heading: Member of the Chicago City Councilfrom the 5th ward
# Good heading!
# either ward in text or no ward
# 6, Eugene Sawyer, has this heading: 53rd Mayor of Chicago
# 6, Eugene Sawyer, has this heading: Member of the Chicago City Councilfrom the 6th ward
# Good heading!
# either ward in text or no ward
# 6, Freddrenna Lyle, has this heading: Judge of the Circuit Court of Cook County
# 6, Freddrenna Lyle, has this heading: Member of the Chicago City Council from the 6th ward
# Good heading!
# either ward in text or no ward
# 6, Roderick Sawyer, has this heading: Member of the Chicago City Councilfrom the 6th ward
# Good heading!
# either ward in text or no ward
# 7, William Beavers, has this heading: Cook County Commissioner from the 4th district
# 7, William Beavers, has this heading: Member of the Chicago City Council from the 7th ward
# Good heading!
# either ward in text or no ward
# 7, Sandi Jackson, has this heading: Member of the Chicago City Councilfrom the 7th ward
# Good heading!
# either ward in text or no ward
# 7, Natashia Holmes, has this heading: City of Chicago Alderman from the 7th ward
# Good heading!
# either ward in text or no ward
# 7, Gregory Mitchell, has this heading: Member of the Chicago City Councilfrom the 7th ward
# Good heading!
# either ward in text or no ward
# 8, William D. Meyering, has this heading: Chief Probation Officer of Cook County[1]
# 8, William D. Meyering, has this heading: Cook County Sheriff
# 8, William D. Meyering, has this heading: Chicago Alderman from the 8th ward[3]
# Good heading!
# either ward in text or no ward
# 8, William Cousins Jr., has this heading: Illinois Appellate Court Judge
# 8, William Cousins Jr., has this heading: Illinois Circuit Court Judge
# 8, William Cousins Jr., has this heading: Chicago Alderman from the 8th ward
# Good heading!
# either ward in text or no ward
# 8, Todd Stroger, has this heading: President of the Cook County Board of Commissioners
# 8, Todd Stroger, has this heading: Chicago Alderman from the 8th ward
# Good heading!
# either ward in text or no ward
# 8, Michelle A. Harris, has this heading: Member of the Chicago City Councilfrom the 8th ward
# Good heading!
# either ward in text or no ward
# 9, Robert Shaw, has this heading: Commissioner of Cook County Board of Review from the 3rd district
# 9, Robert Shaw, has this heading: Chicago Alderman from the 9th ward
# Good heading!
# either ward in text or no ward
# 9, Anthony Beale, has this heading: Member of the Chicago City Councilfrom the 9th ward
# Good heading!
# either ward in text or no ward
# 10, William A. Rowan, has this heading: United States Comptroller of Customs at Chicago
# 10, William A. Rowan, has this heading: Member of the U.S. House of Representativesfrom Illinois's 2nd district
# 10, William A. Rowan, has this heading: Member of the Chicago City Councilfrom the 10th ward
# Good heading!
# either ward in text or no ward
# 10, Edward Vrdolyak, has this heading: Member of the Chicago City Council for Chicago's 10th ward
# Good heading!
# either ward in text or no ward
# 10, John Pope, has this heading: City of Chicago Aldermanfrom the 10th ward
# Good heading!
# either ward in text or no ward
# 10, Susan Sadlowski Garza, has this heading: Member of the Chicago City Councilfrom the 10th ward
# Good heading!
# either ward in text or no ward
# 11, Michael Anthony Bilandic, has this heading: Chief Justice of the Illinois Supreme Court
# 11, Michael Anthony Bilandic, has this heading: Member of the Supreme Court of Illinois
# 11, Michael Anthony Bilandic, has this heading: Illinois Appellate Court judge
# 11, Michael Anthony Bilandic, has this heading: 49th Mayor of Chicago
# 11, Michael Anthony Bilandic, has this heading: Chicago Alderman from the 11th Ward
# Good heading!
# either ward in text or no ward
# 11, James Balcer, has this heading: City of Chicago Alderman
# Good heading!
# either ward in text or no ward
# 11, Patrick Daley Thompson, has this heading: Member of the Chicago City Councilfrom the 11th ward
# Good heading!
# either ward in text or no ward
# 11, Nicole Lee, has this heading: Member of the Chicago City Councilfrom the 11th ward
# Good heading!
# either ward in text or no ward
# 12, George Cardenas, has this heading: Member of the Cook County Board of Reviewfrom the 1st district
# 12, George Cardenas, has this heading: Former member of the Chicago City Councilfrom the 12th ward
# Good heading!
# either ward in text or no ward
# 12, Anabel Abarca, has this heading: Member of the Chicago City Councilfrom the 12th ward
# Good heading!
# either ward in text or no ward
# 12, Julia Ramirez, has this heading: Member of the Chicago City Councilfrom the 12th ward
# Good heading!
# either ward in text or no ward
# 13, Frank Olivo, has this heading: Member of the Chicago City Council from the 13th ward
# Good heading!
# either ward in text or no ward
# 13, Marty Quinn, has this heading: Member of the Chicago City Council from the 13th ward
# Good heading!
# either ward in text or no ward
# 15, Toni Foulkes, has this heading: Member of the Chicago City Councilfrom the 16th ward
# Good heading!
# 15, Toni Foulkes, has this heading: Member of the Chicago City Councilfrom the 15th ward
# Good heading!
# either ward in text or no ward
# 15, Raymond Lopez, has this heading: Member of the Chicago City Councilfrom the 15th ward
# Good heading!
# either ward in text or no ward
# 16, Anna Langford, has this heading: Chicago Alderman from the 16th Ward
# Good heading!
# either ward in text or no ward
# 16, Anna Langford, has this heading: Chicago Alderman from the 16th Ward
# Good heading!
# either ward in text or no ward
# 16, Shirley Coleman, has this heading: City of Chicago Alderman
# Good heading!
# either ward in text or no ward
# 16, Toni Foulkes, has this heading: Member of the Chicago City Councilfrom the 16th ward
# Good heading!
# either ward in text or no ward
# 16, Stephanie Coleman, has this heading: Member of the Chicago City Councilfrom the 16th ward
# Good heading!
# either ward in text or no ward
# 17, Frank J. Corr, has this heading: Acting Mayor of Chicago
# 17, Frank J. Corr, has this heading: Personal details
# 17, Charles Chew, has this heading: Member of the Illinois Senatefrom the 16th district29th district
# 17, Charles Chew, has this heading: Personal details
# 17, Latasha Thomas, has this heading: City of Chicago Alderman
# Good heading!
# either ward in text or no ward
# 17, David H. Moore, has this heading: Member of the Chicago City Councilfrom the 17th ward
# Good heading!
# either ward in text or no ward
# 18, Derrick Curtis, has this heading: Member of the Chicago City Councilfrom the 18th ward
# Good heading!
# either ward in text or no ward
# 20, Arenda Troutman, has this heading: City of Chicago Alderman
# Good heading!
# either ward in text or no ward
# 20, Willie Cochran, has this heading: City of Chicago Alderman
# Good heading!
# either ward in text or no ward
# 20, Jeanette Taylor, has this heading: Member of the Chicago City Councilfrom the 20th Ward
# Good heading!
# either ward in text or no ward
# 21, Wilson Frost, Democratic, has this heading: Commissioner of the Cook County Board of Appeals
# 21, Wilson Frost, Democratic, has this heading: Chicago Alderman
# Good heading!
# either ward in text or no ward
# 21, Bennett Stewart, Democratic, has this heading: Member of the U.S. House of Representativesfrom Illinois's 1st district
# 21, Bennett Stewart, Democratic, has this heading: Chicago Alderman from the 21st Ward
# Good heading!
# either ward in text or no ward
# 21, Howard Brookins Jr., has this heading: Member of the Chicago City Councilfrom the 21st ward
# Good heading!
# either ward in text or no ward
# 22, Jesús "Chuy" García, has this heading: Member of the U.S. House of Representativesfrom Illinois's 4th district
# 22, Jesús "Chuy" García, has this heading: Member of the Cook County Board of Commissionersfrom the 7th district
# 22, Jesús "Chuy" García, has this heading: Member of the Illinois Senatefrom the 1st district
# 22, Jesús "Chuy" García, has this heading: Member of the Chicago City Councilfrom the 22nd ward
# Good heading!
# either ward in text or no ward
# 22, Ricardo Muñoz, has this heading: Member of the Chicago City Council from the 22nd Ward
# Good heading!
# either ward in text or no ward
# 22, Michael D. Rodriguez, has this heading: Member of the Chicago City Councilfrom the 22nd ward
# Good heading!
# either ward in text or no ward
# 23, Bill Lipinski, has this heading: Member of the U.S. House of Representativesfrom Illinois
# 23, Bill Lipinski, has this heading: Member of the Chicago City Council
# 23, Bill Lipinski, has this heading: Personal details
# 23, Michael R. Zalewski, has this heading: Member of the Chicago City Councilfor the 23rd ward
# Good heading!
# either ward in text or no ward
# 23, Silvana Tabares, has this heading: Member of the Chicago City Councilfrom the 23rd ward
# Good heading!
# either ward in text or no ward
# 24, Jacob Arvey, has this heading: Democratic National Committeeman from Illinois
# 24, Jacob Arvey, has this heading: Personal details
# 24, Jacob Arvey, has this heading: Military service
# 24, Benjamin F. Lewis, has this heading: Alderman of the Chicago City Council
# Good heading!
# either ward in text or no ward
# 24, George W. Collins, has this heading: Member of the U.S. House of Representativesfrom Illinois's 6th district
# 24, George W. Collins, has this heading: Personal details
# 24, George W. Collins, has this heading: Military service
# 24, Sharon Denise Dixon, has this heading: Chicago City Council
# 24, Sharon Denise Dixon, has this heading: Personal details
# 24, Michael Scott Jr., has this heading: Member of theCook County Board of Commissionersfrom the 2nd district
# 24, Michael Scott Jr., has this heading: Member of theChicago City Councilfrom the 24th ward
# Good heading!
# either ward in text or no ward
# 28, Jason Ervin, has this heading: Member of the Chicago City Councilfrom the 28th ward
# Good heading!
# either ward in text or no ward
# 29, Danny K. Davis, has this heading: Member of the U.S. House of Representativesfrom Illinois's 7th district
# 29, Danny K. Davis, has this heading: Member of the Cook County Board of Commissioners
# 29, Danny K. Davis, has this heading: Member of the Chicago City Councilfrom the 29th Ward
# Good heading!
# either ward in text or no ward
# 29, Deborah L. Graham, has this heading: Member of the Chicago City Council from the 29th ward
# Good heading!
# either ward in text or no ward
# 29, Chris Taliaferro, has this heading: Member of the Chicago City Councilfrom the 29th ward
# Good heading!
# either ward in text or no ward
# 30, Ariel Reboyras, has this heading: Member of the Chicago City Councilfrom the 30th ward
# Good heading!
# either ward in text or no ward
# 33, Richard Mell, has this heading: 2nd Vice Mayor of Chicago
# 33, Richard Mell, has this heading: Member of the Chicago City Councilfrom the 33rd ward
# Good heading!
# either ward in text or no ward
# 33, Deb Mell, has this heading: Member of the Chicago City Council from the 33rd ward
# Good heading!
# either ward in text or no ward
# 33, Rossana Rodriguez-Sanchez, has this heading: Member of the Chicago City Councilfrom the 33rd ward
# Good heading!
# either ward in text or no ward
# 34, Carrie Austin, has this heading: Member of the Chicago City Councilfrom the 34th ward
# Good heading!
# either ward in text or no ward
# 34, Bill Conway, has this heading: Member of the Chicago City Councilfrom the 34th ward
# Good heading!
# either ward in text or no ward
# 35, Casimir C. Laskowski, has this heading: 1st Vice Mayor of Chicago
# 35, Casimir C. Laskowski, has this heading: Member of the Chicago City Councilfrom the 35th ward
# Good heading!
# either ward in text or no ward
# 35, Rey Colón, has this heading: City of Chicago Alderman
# Good heading!
# either ward in text or no ward
# 35, Carlos Ramirez-Rosa, has this heading: Member of the Chicago City Councilfrom the 35th ward
# Good heading!
# either ward in text or no ward
# 36, William Banks, has this heading: City of Chicago Aldermanfrom the 36th Ward
# Good heading!
# either ward in text or no ward
# 36, John Rice, has this heading: City of Chicago Aldermanfrom the 36th Ward
# Good heading!
# either ward in text or no ward
# 36, Nicholas Sposato, has this heading: Member of the Chicago City Councilfrom the 38th ward
# Good heading!
# 36, Nicholas Sposato, has this heading: Member of the Chicago City Councilfrom the 36th ward
# Good heading!
# either ward in text or no ward
# 36, Gilbert Villegas, has this heading: Member of the Chicago City Councilfrom the 36th ward
# Good heading!
# either ward in text or no ward
# 37, Emma Mitts, has this heading: Member of the Chicago City Councilfrom the 37th ward
# Good heading!
# either ward in text or no ward
# 39, Margaret Laurino, has this heading: City of Chicago Aldermanfrom the 39th Ward
# Good heading!
# either ward in text or no ward
# 39, Samantha Nugent, has this heading: President pro tempore of the Chicago City Council
# 39, Samantha Nugent, has this heading: Member of the Chicago City Councilfrom the 39th ward
# Good heading!
# either ward in text or no ward
# 40, John William Chapman, has this heading: 37th Lieutenant Governor of Illinois
# 40, John William Chapman, has this heading: Member of the Chicago City Councilfrom the 40th Ward
# Good heading!
# either ward in text or no ward
# 40, Patrick J. O'Connor, has this heading: Chicago Aldermanfrom the 40th Ward
# Good heading!
# either ward in text or no ward
# 40, Andre Vasquez, has this heading: Member of the Chicago City Councilfrom the 40th ward
# Good heading!
# either ward in text or no ward
# 41, Roman Pucinski, has this heading: Member of the U.S. House of Representativesfrom Illinois's 11th district
# 41, Roman Pucinski, has this heading: City of Chicago Aldermanfrom the 41st Ward
# Good heading!
# either ward in text or no ward
# 41, Brian Doherty, has this heading: Member of the Chicago City Councilfrom the 41st ward
# Good heading!
# either ward in text or no ward
# 41, Mary O'Connor, has this heading: Member of the Chicago City Councilfrom the 41st ward
# Good heading!
# either ward in text or no ward
# 41, Anthony Napolitano, has this heading: Member of the Chicago City Councilfrom the 41st ward
# Good heading!
# either ward in text or no ward
# 44, William Singer, has this heading: Chicago Alderman
# Good heading!
# either ward in text or no ward
# 44, Dick Simpson, has this heading: Chicago Alderman from the 44th Ward
# Good heading!
# either ward in text or no ward
# 44, John Merlo, has this heading: Member of the Chicago City Council from the 44th ward
# Good heading!
# either ward in text or no ward
# 44, Bernie Hansen, has this heading: City of Chicago Alderman
# Good heading!
# either ward in text or no ward
# 44, Tom Tunney, has this heading: 8th Vice Mayor of Chicago
# 44, Tom Tunney, has this heading: Member of the Chicago City Councilfrom the 44th ward
# Good heading!
# either ward in text or no ward
# 44, Bennett Lawson, has this heading: Member of the Chicago City Councilfrom the 44th ward
# Good heading!
# either ward in text or no ward
# 45, John Arena, has this heading: Member of the Chicago City Councilfrom the 45th ward
# Good heading!
# either ward in text or no ward
# 45, Jim Gardiner, has this heading: Member of the Chicago City Councilfrom the 45th ward
# Good heading!
# either ward in text or no ward
# 46, Helen Shiller, has this heading: Member of the Chicago City Council from the 46th ward
# Good heading!
# either ward in text or no ward
# 46, James Cappleman, has this heading: Member of the Chicago City Councilfrom the 46th ward
# Good heading!
# either ward in text or no ward
# 46, Angela Clay, has this heading: Member of the Chicago City Councilfrom the 46th ward
# Good heading!
# either ward in text or no ward
# 48, Francis L. Boutell [dates 2], has this heading: Type
# 48, Francis L. Boutell [dates 2], has this heading: Leadership
# 48, Francis L. Boutell [dates 2], has this heading: Structure
# 48, Francis L. Boutell [dates 2], has this heading: Elections
# 48, Francis L. Boutell [dates 2], has this heading: Meeting place
# 48, Francis L. Boutell [dates 2], has this heading: Website
# 48, Kathy Osterman, has this heading: Member of Chicago City Councilfor the 48th ward
# Good heading!
# either ward in text or no ward
# 48, Mary Ann Smith, has this heading: Member of Chicago City Councilfor the 48th ward
# Good heading!
# either ward in text or no ward
# 48, Harry Osterman, has this heading: Member of the Chicago City Councilfrom the 48th ward
# Good heading!
# either ward in text or no ward
# 48, Leni Manaa-Hoppenworth, has this heading: Member of the Chicago City Councilfrom the 48th ward
# Good heading!
# either ward in text or no ward

# %%
all_data = []

all_data.extend(scraped_data)

all_data.extend(bullet_data)

# %%
all_data
# Out:
# [{'Ward': '1st',
#   'Alderperson': 'John Coughlin',
#   'Start Date': 'April 16, 1923',
#   'End Date': 'November 11, 1938',
#   'Party': 'Democratic',
#   'Notes': 'Had been serving since 1892    Died in office'},
#  {'Ward': '1st',
#   'Alderperson': 'Michael Kenna',
#   'Start Date': 'April 12, 1939',
#   'End Date': 'April 9, 1943',
#   'Party': 'Democratic',
#   'Notes': 'Had previously served from 1897 to 1923'},
#  {'Ward': '1st',
#   'Alderperson': 'John Budinger',
#   'Start Date': 'April 9, 1943',
#   'End Date': '1951',
#   'Party': 'Democratic',
#   'Notes': 'Had previously served (previous iteration of) the 4th ward from 1910 to 1912'},
#  {'Ward': '1st',
#   'Alderperson': "John D'Arco Sr.",
#   'Start Date': '1951',
#   'End Date': '1963',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '1st',
#   'Alderperson': 'Fred Roti',
#   'Start Date': '1968',
#   'End Date': '1991',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '1st',
#   'Alderperson': 'Ted Mazola',
#   'Start Date': '1991',
#   'End Date': '1995',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '1st',
#   'Alderperson': 'Jesse Granato',
#   'Start Date': '1995',
#   'End Date': 'May 19, 2003',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '1st',
#   'Alderperson': 'Manuel Flores',
#   'Start Date': 'May 19, 2003',
#   'End Date': 'January 4, 2010',
#   'Party': 'Democratic',
#   'Notes': 'Appointed to be Chairman of the  Illinois Commerce Commission'},
#  {'Ward': '1st',
#   'Alderperson': 'Proco Joe Moreno',
#   'Start Date': 'March 26, 2010',
#   'End Date': 'May 20, 2019',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '1st',
#   'Alderperson': 'Daniel La Spata',
#   'Start Date': 'May 20, 2019',
#   'End Date': 'present',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '2nd',
#   'Alderperson': 'Louis B. Anderson',
#   'Start Date': 'April 16, 1923',
#   'End Date': '1933',
#   'Party': 'Republican',
#   'Notes': 'Had been serving since 1917'},
#  {'Ward': '2nd',
#   'Alderperson': 'William L. Dawson',
#   'Start Date': '1933',
#   'End Date': 'April 12, 1939',
#   'Party': 'Republican',
#   'Notes': ''},
#  {'Ward': '2nd',
#   'Alderperson': 'Earl B. Dickerson',
#   'Start Date': 'April 12, 1939',
#   'End Date': 'April 9, 1943',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '2nd',
#   'Alderperson': 'William H. Harvey',
#   'Start Date': 'April 9, 1943',
#   'End Date': 'December 20, 1968',
#   'Party': 'N/A',
#   'Notes': 'Became a  County Commissioner'},
#  {'Ward': '2nd',
#   'Alderperson': 'Fred D. Hubbard',
#   'Start Date': 'March 11, 1969',
#   'End Date': 'March 16, 1972',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '2nd',
#   'Alderperson': 'William Barnett',
#   'Start Date': 'August 15, 1972',
#   'End Date': '1983',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '2nd',
#   'Alderperson': 'Bobby Rush',
#   'Start Date': '1983',
#   'End Date': '1993',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '2nd',
#   'Alderperson': 'Madeline Haithcock',
#   'Start Date': '1993',
#   'End Date': 'May 21, 2007',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '2nd',
#   'Alderperson': 'Robert Fioretti',
#   'Start Date': 'May 21, 2007',
#   'End Date': 'May 2015',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '2nd',
#   'Alderperson': 'Brian K. Hopkins',
#   'Start Date': 'May 2015',
#   'End Date': 'present',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '3rd',
#   'Alderperson': 'Robert R. Jackson',
#   'Start Date': 'April 16, 1923',
#   'End Date': 'April 12, 1939',
#   'Party': 'Republican',
#   'Notes': 'Had been serving then-2nd ward since 1918'},
#  {'Ward': '3rd',
#   'Alderperson': 'Benjaim A. Grant',
#   'Start Date': 'April 12, 1939',
#   'End Date': 'April 9, 1943',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '3rd',
#   'Alderperson': 'Oscar Stanton De Priest',
#   'Start Date': 'April 9, 1943',
#   'End Date': '1947',
#   'Party': 'Republican',
#   'Notes': 'Had previously served then-2nd ward from 1915 to 1917'},
#  {'Ward': '3rd',
#   'Alderperson': 'Archibald Carey Jr.',
#   'Start Date': '1947',
#   'End Date': '1955',
#   'Party': 'Republican',
#   'Notes': ''},
#  {'Ward': '3rd',
#   'Alderperson': 'Ralph Metcalfe',
#   'Start Date': '1955',
#   'End Date': 'December 1970',
#   'Party': 'Democratic',
#   'Notes': 'Became a Congressman'},
#  {'Ward': '3rd',
#   'Alderperson': 'Tyrone T. Kenner',
#   'Start Date': 'February 23, 1971',
#   'End Date': 'February 11, 1985',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '3rd',
#   'Alderperson': 'Dorothy Tillman',
#   'Start Date': 'February 11, 1985',
#   'End Date': 'April 27, 2007',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '3rd',
#   'Alderperson': 'Pat Dowell',
#   'Start Date': 'April 27, 2007',
#   'End Date': 'Present',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '4th',
#   'Alderperson': 'Abraham H. Cohen',
#   'Start Date': 'April 12, 1939',
#   'End Date': '1955',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '4th',
#   'Alderperson': 'Claude Holman',
#   'Start Date': '1955',
#   'End Date': 'June 1, 1973',
#   'Party': 'N/A',
#   'Notes': 'Died in office'},
#  {'Ward': '4th',
#   'Alderperson': 'Timothy C. Evans',
#   'Start Date': 'November 27, 1973',
#   'End Date': '1991',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '4th',
#   'Alderperson': 'Toni Preckwinkle',
#   'Start Date': '1991',
#   'End Date': '2010',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '4th',
#   'Alderperson': 'William D. Burns',
#   'Start Date': 'May 2011',
#   'End Date': 'February 2016',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '4th',
#   'Alderperson': 'Sophia King',
#   'Start Date': 'April 16, 2016',
#   'End Date': 'present',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '14th',
#   'Alderperson': "William R. O'Toole",
#   'Start Date': 'April 16, 1923',
#   'End Date': '1931',
#   'Party': 'Democratic',
#   'Notes': 'Had been serving then-30th ward since 1914'},
#  {'Ward': '14th',
#   'Alderperson': 'James J. McDermott',
#   'Start Date': '1933',
#   'End Date': 'December 3, 1942',
#   'Party': 'Democratic',
#   'Notes': 'Elected to Cook County Board of Appeals'},
#  {'Ward': '14th',
#   'Alderperson': 'Clarence P. Wagner',
#   'Start Date': 'April 9, 1943',
#   'End Date': 'July 10, 1953',
#   'Party': 'N/A',
#   'Notes': 'Died in office'},
#  {'Ward': '14th',
#   'Alderperson': 'Joseph P. Burke',
#   'Start Date': 'November 3, 1953',
#   'End Date': 'May 11, 1968',
#   'Party': 'Democratic',
#   'Notes': 'Died in office'},
#  {'Ward': '14th',
#   'Alderperson': 'Edward M. Burke',
#   'Start Date': 'March 14, 1969',
#   'End Date': 'Present',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '19th',
#   'Alderperson': 'Donald S. McKinlay',
#   'Start Date': 'April 16, 1923',
#   'End Date': '1928',
#   'Party': 'Democratic',
#   'Notes': 'Resigned to become a judge [ 3 ]'},
#  {'Ward': '19th',
#   'Alderperson': 'O.E. Northrup',
#   'Start Date': '1929',
#   'End Date': '1935',
#   'Party': 'Republican',
#   'Notes': ''},
#  {'Ward': '19th',
#   'Alderperson': 'John J. Duffy',
#   'Start Date': '1935',
#   'End Date': 'December 1, 1950',
#   'Party': 'N/A',
#   'Notes': 'Elected to the Cook County Board of Commissioners'},
#  {'Ward': '19th',
#   'Alderperson': 'David T. McKiernan',
#   'Start Date': '1951',
#   'End Date': 'May 25, 1957',
#   'Party': 'N/A',
#   'Notes': 'Died in office'},
#  {'Ward': '19th',
#   'Alderperson': 'Thomas F. Fitzpatrick',
#   'Start Date': 'September 17, 1957',
#   'End Date': 'April 1, 1975',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '19th',
#   'Alderperson': 'Jeremiah E. Joyce',
#   'Start Date': 'April 1, 1975',
#   'End Date': 'February 1, 1979',
#   'Party': 'Democratic',
#   'Notes': 'Elected to the  Illinois General Assembly  for the 28th district'},
#  {'Ward': '19th',
#   'Alderperson': 'Michael F. Sheahan',
#   'Start Date': 'April 16, 1979',
#   'End Date': '1991',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '19th',
#   'Alderperson': 'Virginia Rugai',
#   'Start Date': '1991',
#   'End Date': '2011',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '19th',
#   'Alderperson': "Matthew O'Shea",
#   'Start Date': '2011',
#   'End Date': 'present',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '25th',
#   'Alderperson': 'John Powers',
#   'Start Date': 'April 16, 1923',
#   'End Date': '1927',
#   'Party': 'Democratic',
#   'Notes': 'Had been serving then-19th ward since 1905 and previously from 1888 to 1904'},
#  {'Ward': '25th',
#   'Alderperson': 'James Bowler',
#   'Start Date': '1927',
#   'End Date': 'June 7, 1934   February 26, 1935',
#   'Party': 'Democratic',
#   'Notes': 'Had previously served then-19th ward between 1906 and 1923   Briefly vacated office to become a Public Vehicle License Commissioner   Became a Congressman representing  IL-7'},
#  {'Ward': '25th',
#   'Alderperson': 'Vito Marzullo',
#   'Start Date': 'November 3, 1953',
#   'End Date': '1985',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '25th',
#   'Alderperson': 'Daniel Solis',
#   'Start Date': '1996',
#   'End Date': '2019',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '25th',
#   'Alderperson': 'Byron Sigcho-Lopez',
#   'Start Date': '2019',
#   'End Date': 'present',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '26th',
#   'Alderperson': 'Mathew William Bieszczat',
#   'Start Date': 'February 5, 1945',
#   'End Date': 'November 8, 1960',
#   'Party': 'N/A',
#   'Notes': 'Elected bailiff of  Municipal Court of Chicago'},
#  {'Ward': '26th',
#   'Alderperson': 'Stanley M. Zydlo',
#   'Start Date': 'February 26, 1963',
#   'End Date': 'April 16, 1979',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '26th',
#   'Alderperson': 'Michael Nardulli',
#   'Start Date': '1979',
#   'End Date': '1986',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '26th',
#   'Alderperson': 'Luis Gutiérrez',
#   'Start Date': 'May 2, 1986',
#   'End Date': 'December 12, 1992',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '26th',
#   'Alderperson': 'Billy Ocasio',
#   'Start Date': '1994',
#   'End Date': '2009',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '26th',
#   'Alderperson': 'Roberto Maldonado',
#   'Start Date': '2009',
#   'End Date': 'present',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '27th',
#   'Alderperson': 'John J. Touhy',
#   'Start Date': 'April 16, 1923',
#   'End Date': 'December 1, 1926 [ dates 2 ]',
#   'Party': 'Democratic',
#   'Notes': 'Had been serving then-18th ward since 1917 Resigned to take office as a Sanitary District Trustee [ dates 2 ]'},
#  {'Ward': '27th',
#   'Alderperson': 'Harry C. Van Norman',
#   'Start Date': '1927',
#   'End Date': 'October 11, 1929 [ dates 3 ]',
#   'Party': 'Democratic',
#   'Notes': 'Died in office [ dates 3 ]'},
#  {'Ward': '27th',
#   'Alderperson': 'Harry L. Sain',
#   'Start Date': '1933',
#   'End Date': 'February 23, 1971',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '27th',
#   'Alderperson': 'Eugene Ray',
#   'Start Date': 'February 23, 1971',
#   'End Date': '1983',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '27th',
#   'Alderperson': 'Rickey R. Hendon',
#   'Start Date': '1991',
#   'End Date': 'January 13, 1993',
#   'Party': 'Democratic',
#   'Notes': 'Elected to the  Illinois Senate  for the 5th district'},
#  {'Ward': '27th',
#   'Alderperson': 'Walter Burnett Jr.',
#   'Start Date': 'May 1995',
#   'End Date': 'present',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '31st',
#   'Alderperson': 'Stanley Adamkiewicz',
#   'Start Date': 'April 16, 1923',
#   'End Date': '1929',
#   'Party': 'Democratic',
#   'Notes': 'Had previously served then-17th ward from 1917 to 1921'},
#  {'Ward': '31st',
#   'Alderperson': 'Thomas Patrick Keane',
#   'Start Date': '1933',
#   'End Date': 'July 13, 1945',
#   'Party': 'Democratic',
#   'Notes': 'Redistricted from the 34th ward   Died in office'},
#  {'Ward': '31st',
#   'Alderperson': 'Thomas E. Keane',
#   'Start Date': 'September 4, 1945',
#   'End Date': 'October 9, 1974',
#   'Party': 'N/A',
#   'Notes': 'Convicted of mail fraud and conspiracy'},
#  {'Ward': '31st',
#   'Alderperson': 'Ray Suarez',
#   'Start Date': '1991',
#   'End Date': 'May 2015',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '31st',
#   'Alderperson': 'Milly Santiago',
#   'Start Date': 'May 2015',
#   'End Date': 'May 20, 2019',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '31st',
#   'Alderperson': 'Felix Cardona, Jr.',
#   'Start Date': 'May 20, 2019',
#   'End Date': 'Present',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '32nd',
#   'Alderperson': 'Bernard C. Prusinski',
#   'Start Date': '1955',
#   'End Date': '1959',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '32nd',
#   'Alderperson': 'Robert J. Sulski',
#   'Start Date': '1959',
#   'End Date': 'November 28, 1968',
#   'Party': 'N/A',
#   'Notes': 'Became a Circuit Court Judge'},
#  {'Ward': '32nd',
#   'Alderperson': 'Terry Gabinski',
#   'Start Date': 'March 12, 1969',
#   'End Date': 'May 21, 1998',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '32nd',
#   'Alderperson': 'Theodore Matlak',
#   'Start Date': 'May 21, 1998',
#   'End Date': 'May 20, 2007',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '32nd',
#   'Alderperson': 'Scott Waguespack',
#   'Start Date': 'May 20, 2007',
#   'End Date': 'present',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '38th',
#   'Alderperson': 'Max Adamowski',
#   'Start Date': 'April 16, 1923',
#   'End Date': 'July 16, 1929 [ dates 5 ]',
#   'Party': 'Democratic',
#   'Notes': 'Had been serving then-22nd ward since 1916 Died in office [ dates 5 ]'},
#  {'Ward': '38th',
#   'Alderperson': 'Patrick J. Cullerton',
#   'Start Date': '1935',
#   'End Date': 'April 17, 1958',
#   'Party': 'N/A',
#   'Notes': 'Elected Cook County Assessor'},
#  {'Ward': '38th',
#   'Alderperson': 'William J. Cullerton',
#   'Start Date': '1959',
#   'End Date': 'April 14, 1973',
#   'Party': 'N/A',
#   'Notes': 'Died in office'},
#  {'Ward': '38th',
#   'Alderperson': 'Thomas W. Cullerton',
#   'Start Date': 'November 27, 1973',
#   'End Date': '1993',
#   'Party': 'N/A',
#   'Notes': 'Died in office'},
#  {'Ward': '38th',
#   'Alderperson': 'Thomas R. Allen',
#   'Start Date': '1993',
#   'End Date': '2010',
#   'Party': 'N/A',
#   'Notes': 'Became a judge of the Cook County  Illinois Circuit Court'},
#  {'Ward': '38th',
#   'Alderperson': 'Timothy Cullerton',
#   'Start Date': '2011',
#   'End Date': '2013',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '38th',
#   'Alderperson': 'Nicholas Sposato',
#   'Start Date': '2013',
#   'End Date': 'present',
#   'Party': 'Democratic',
#   'Notes': 'Redistricted from 36th ward'},
#  {'Ward': '42nd',
#   'Alderperson': 'Dorsey Crowe',
#   'Start Date': 'April 16, 1923',
#   'End Date': 'July 1, 1962',
#   'Party': 'Democratic',
#   'Notes': 'Had been serving then-21st ward since 1919    Died in office'},
#  {'Ward': '42nd',
#   'Alderperson': 'Mayer Goldberg',
#   'Start Date': 'February 26, 1963',
#   'End Date': 'November 29, 1968',
#   'Party': 'Democratic',
#   'Notes': 'Became a Circuit Court Judge'},
#  {'Ward': '42nd',
#   'Alderperson': 'Burton Natarus',
#   'Start Date': '1971',
#   'End Date': '2007',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '42nd',
#   'Alderperson': 'Brendan Reilly',
#   'Start Date': '2007',
#   'End Date': 'Present',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '43rd',
#   'Alderperson': 'Arthur F. Albert',
#   'Start Date': 'April 16, 1923',
#   'End Date': 'October 31, 1927',
#   'Party': 'Republican',
#   'Notes': 'Had been serving then-22nd ward since 1921  Albert lost the first round of the  1927 election  to Haffa, but had been granted a runoff that he would win. However, the runoff was disputed and the Council unseated him in favor of Haffa, claiming that the judge who had granted the runoff had erred in counting spoiled ballots to determine the majority Haffa needed to avoid a runoff.'},
#  {'Ward': '43rd',
#   'Alderperson': 'Arthur F. Albert',
#   'Start Date': '1929',
#   'End Date': '1931',
#   'Party': 'Republican',
#   'Notes': ''},
#  {'Ward': '43rd',
#   'Alderperson': 'James B. Waller',
#   'Start Date': '1931',
#   'End Date': '1933',
#   'Party': 'Republican',
#   'Notes': ''},
#  {'Ward': '43rd',
#   'Alderperson': 'Paddy Bauler',
#   'Start Date': '1933',
#   'End Date': 'April 9, 1943',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '43rd',
#   'Alderperson': 'James B. Waller',
#   'Start Date': 'April 9, 1943',
#   'End Date': '1947',
#   'Party': 'Republican',
#   'Notes': ''},
#  {'Ward': '43rd',
#   'Alderperson': 'Paddy Bauler',
#   'Start Date': '1947',
#   'End Date': '1967',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '43rd',
#   'Alderperson': 'William Singer',
#   'Start Date': '1971',
#   'End Date': '1975',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '43rd',
#   'Alderperson': 'Martin J. Oberman',
#   'Start Date': '1975',
#   'End Date': '1987',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '43rd',
#   'Alderperson': 'Edwin Eisendrath',
#   'Start Date': '1987',
#   'End Date': '1993',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '43rd',
#   'Alderperson': 'Charles Bernardini',
#   'Start Date': '1993',
#   'End Date': '1999',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '43rd',
#   'Alderperson': 'Vi Daley',
#   'Start Date': '1999',
#   'End Date': 'May 16, 2011',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '43rd',
#   'Alderperson': 'Michele Smith',
#   'Start Date': 'May 16, 2011',
#   'End Date': 'August 12, 2022',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '43rd',
#   'Alderperson': 'Timmy Knudsen',
#   'Start Date': 'September 21, 2022',
#   'End Date': 'Present',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '47th',
#   'Alderperson': 'John J. Hoellen Jr.',
#   'Start Date': '1947',
#   'End Date': '1975',
#   'Party': 'Republican',
#   'Notes': ''},
#  {'Ward': '47th',
#   'Alderperson': 'Eugene Schulter',
#   'Start Date': 'February 25, 1975',
#   'End Date': 'May 16, 2011',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '47th',
#   'Alderperson': 'Ameya Pawar',
#   'Start Date': 'May 16, 2011',
#   'End Date': 'May 20, 2019',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '47th',
#   'Alderperson': 'Matt Martin',
#   'Start Date': 'May 20, 2019',
#   'End Date': 'Present',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '49th',
#   'Alderperson': 'Esther Saperstein',
#   'Start Date': 'February 25, 1975',
#   'End Date': 'April 16, 1979',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '49th',
#   'Alderperson': 'David Orr',
#   'Start Date': '1979',
#   'End Date': '1990',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '49th',
#   'Alderperson': 'Joe Moore',
#   'Start Date': '1991',
#   'End Date': 'May 20, 2019',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '49th',
#   'Alderperson': 'Maria Hadden',
#   'Start Date': 'May 20, 2019',
#   'End Date': 'present',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '50th',
#   'Alderperson': 'Bernard Stone',
#   'Start Date': '1973',
#   'End Date': '2011',
#   'Party': 'Democratic',
#   'Notes': ''},
#  {'Ward': '50th',
#   'Alderperson': 'Debra Silverstein',
#   'Start Date': '2011',
#   'End Date': 'present',
#   'Party': 'N/A',
#   'Notes': ''},
#  {'Ward': '5',
#   'Alderperson': 'Paul Howard Douglas',
#   'Start Date': '1939',
#   'End Date': '1942',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '5',
#   'Alderperson': 'Leon Despres',
#   'Start Date': '1955',
#   'End Date': '1975',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '5',
#   'Alderperson': 'Leslie Hairston',
#   'Start Date': 'May 1999',
#   'End Date': 'May 15, 2023',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '6',
#   'Alderperson': 'Eugene Sawyer',
#   'Start Date': 'February 28, 1971',
#   'End Date': 'December 2, 1987',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '6',
#   'Alderperson': 'Freddrenna Lyle',
#   'Start Date': 'February 8, 1998',
#   'End Date': 'May 15, 2011',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '6',
#   'Alderperson': 'Roderick Sawyer',
#   'Start Date': 'May 16, 2011',
#   'End Date': 'May 15, 2023',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '7',
#   'Alderperson': 'William Beavers',
#   'Start Date': '1983',
#   'End Date': '2006',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '7',
#   'Alderperson': 'Sandi Jackson',
#   'Start Date': 'May 21, 2007',
#   'End Date': 'January 15, 2013',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '7',
#   'Alderperson': 'Natashia Holmes',
#   'Start Date': 'February 13, 2013',
#   'End Date': 'May 18, 2015',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '7',
#   'Alderperson': 'Gregory Mitchell',
#   'Start Date': 'May 18, 2015',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '8',
#   'Alderperson': 'William D. Meyering',
#   'Start Date': 'April 1923',
#   'End Date': 'December 1930',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '8',
#   'Alderperson': 'William Cousins Jr.',
#   'Start Date': '1967',
#   'End Date': '1976',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '8',
#   'Alderperson': 'Todd Stroger',
#   'Start Date': 'September 5, 2001',
#   'End Date': 'December 4, 2006',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '8',
#   'Alderperson': 'Michelle A. Harris',
#   'Start Date': 'December 13, 2006',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '9',
#   'Alderperson': 'Robert Shaw',
#   'Start Date': 'May 1987',
#   'End Date': 'December 1998',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '9',
#   'Alderperson': 'Anthony Beale',
#   'Start Date': 'May 1999',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '10',
#   'Alderperson': 'William A. Rowan',
#   'Start Date': '1927',
#   'End Date': '1942',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '10',
#   'Alderperson': 'Edward Vrdolyak',
#   'Start Date': '1971',
#   'End Date': '1987',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '10',
#   'Alderperson': 'John Pope',
#   'Start Date': 'May 1999',
#   'End Date': 'May 2015',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '10',
#   'Alderperson': 'Susan Sadlowski Garza',
#   'Start Date': 'May 18, 2015',
#   'End Date': 'May 15, 2023',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '11',
#   'Alderperson': 'Michael Anthony Bilandic',
#   'Start Date': 'June 12, 1969',
#   'End Date': 'June 7, 1977',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '11',
#   'Alderperson': 'James Balcer',
#   'Start Date': '1997',
#   'End Date': '2015',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '11',
#   'Alderperson': 'Patrick Daley Thompson',
#   'Start Date': 'May 18, 2015',
#   'End Date': 'February 14, 2022',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '11',
#   'Alderperson': 'Nicole Lee',
#   'Start Date': 'March 28, 2022',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '12',
#   'Alderperson': 'George Cardenas',
#   'Start Date': '2003',
#   'End Date': '2022',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '12',
#   'Alderperson': 'Anabel Abarca',
#   'Start Date': 'December 14, 2022',
#   'End Date': 'May 15, 2023',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '12',
#   'Alderperson': 'Julia Ramirez',
#   'Start Date': 'May 15, 2023',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '13',
#   'Alderperson': 'Frank Olivo',
#   'Start Date': '1994',
#   'End Date': '2011',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '13',
#   'Alderperson': 'Marty Quinn',
#   'Start Date': 'May 2011',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '15',
#   'Alderperson': 'Toni Foulkes',
#   'Start Date': '2007',
#   'End Date': '2015',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '15',
#   'Alderperson': 'Raymond Lopez',
#   'Start Date': 'May 18, 2015',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '16',
#   'Alderperson': 'Anna Langford',
#   'Start Date': 'February 1983',
#   'End Date': 'January 27, 1991',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '16',
#   'Alderperson': 'Anna Langford',
#   'Start Date': 'February 1983',
#   'End Date': 'January 27, 1991',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '16',
#   'Alderperson': 'Shirley Coleman',
#   'Start Date': 'January 27, 1991',
#   'End Date': 'May 30, 2007',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '16',
#   'Alderperson': 'Toni Foulkes',
#   'Start Date': '2015',
#   'End Date': '2019',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '16',
#   'Alderperson': 'Stephanie Coleman',
#   'Start Date': 'May 20, 2019',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '17',
#   'Alderperson': 'Latasha Thomas',
#   'Start Date': '2000',
#   'End Date': '2015',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '17',
#   'Alderperson': 'David H. Moore',
#   'Start Date': 'May 18, 2015',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '18',
#   'Alderperson': 'Derrick Curtis',
#   'Start Date': 'May 18, 2015',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '20',
#   'Alderperson': 'Arenda Troutman',
#   'Start Date': 'April 1990',
#   'End Date': 'February 2007',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '20',
#   'Alderperson': 'Willie Cochran',
#   'Start Date': '2007',
#   'End Date': '2019',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '20',
#   'Alderperson': 'Jeanette Taylor',
#   'Start Date': 'May 20, 2019',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '21',
#   'Alderperson': 'Wilson Frost, Democratic',
#   'Start Date': '1971',
#   'End Date': '1987',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '21',
#   'Alderperson': 'Bennett Stewart, Democratic',
#   'Start Date': '1971',
#   'End Date': '1979',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '21',
#   'Alderperson': 'Howard Brookins Jr.',
#   'Start Date': 'May 2003',
#   'End Date': 'May 15, 2023',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '22',
#   'Alderperson': 'Jesús "Chuy" García',
#   'Start Date': 'March 25, 1986',
#   'End Date': 'January 1, 1993',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '22',
#   'Alderperson': 'Ricardo Muñoz',
#   'Start Date': 'January 1993',
#   'End Date': 'May 20, 2019',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '22',
#   'Alderperson': 'Michael D. Rodriguez',
#   'Start Date': 'May 20, 2019',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '23',
#   'Alderperson': 'Michael R. Zalewski',
#   'Start Date': 'May 1995',
#   'End Date': 'May 31, 2018',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '23',
#   'Alderperson': 'Silvana Tabares',
#   'Start Date': 'June 28, 2018',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '24',
#   'Alderperson': 'Benjamin F. Lewis',
#   'Start Date': 'April 8, 1958',
#   'End Date': 'February 28, 1963',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '24',
#   'Alderperson': 'Michael Scott Jr.',
#   'Start Date': 'May 18, 2015',
#   'End Date': 'June 3, 2022',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '28',
#   'Alderperson': 'Jason Ervin',
#   'Start Date': 'January 13, 2011',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '29',
#   'Alderperson': 'Danny K. Davis',
#   'Start Date': 'April 16, 1979',
#   'End Date': 'December 20, 1990',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '29',
#   'Alderperson': 'Deborah L. Graham',
#   'Start Date': '2010',
#   'End Date': '2015',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '29',
#   'Alderperson': 'Chris Taliaferro',
#   'Start Date': 'May 18, 2015',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '30',
#   'Alderperson': 'Ariel Reboyras',
#   'Start Date': 'May 2003',
#   'End Date': 'May 15, 2023',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '33',
#   'Alderperson': 'Richard Mell',
#   'Start Date': '1975',
#   'End Date': 'July 24, 2013',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '33',
#   'Alderperson': 'Deb Mell',
#   'Start Date': 'July 24, 2013',
#   'End Date': 'May 20, 2019',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '33',
#   'Alderperson': 'Rossana Rodriguez-Sanchez',
#   'Start Date': 'May 20, 2019',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '34',
#   'Alderperson': 'Carrie Austin',
#   'Start Date': 'August 5, 1994',
#   'End Date': 'March 1, 2023',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '34',
#   'Alderperson': 'Bill Conway',
#   'Start Date': 'May 15, 2023',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '35',
#   'Alderperson': 'Casimir C. Laskowski',
#   'Start Date': 'April 20, 1955',
#   'End Date': 'April 16, 1979',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '35',
#   'Alderperson': 'Rey Colón',
#   'Start Date': '2003',
#   'End Date': '2015',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '35',
#   'Alderperson': 'Carlos Ramirez-Rosa',
#   'Start Date': 'May 18, 2015',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '36',
#   'Alderperson': 'William Banks',
#   'Start Date': 'May 1983',
#   'End Date': 'April 2009',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '36',
#   'Alderperson': 'John Rice',
#   'Start Date': 'October 6, 2009',
#   'End Date': 'May 16, 2011',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '36',
#   'Alderperson': 'Nicholas Sposato',
#   'Start Date': 'May 16, 2011',
#   'End Date': 'May 18, 2015',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '36',
#   'Alderperson': 'Gilbert Villegas',
#   'Start Date': 'May 18, 2015',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '37',
#   'Alderperson': 'Emma Mitts',
#   'Start Date': 'January 7, 2000',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '39',
#   'Alderperson': 'Margaret Laurino',
#   'Start Date': 'July 24, 1994',
#   'End Date': 'May 20, 2019',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '39',
#   'Alderperson': 'Samantha Nugent',
#   'Start Date': 'May 20, 2019',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '40',
#   'Alderperson': 'John William Chapman',
#   'Start Date': '1927',
#   'End Date': '1929',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '40',
#   'Alderperson': "Patrick J. O'Connor",
#   'Start Date': 'May 1983',
#   'End Date': 'May 2019',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '40',
#   'Alderperson': 'Andre Vasquez',
#   'Start Date': 'May 20, 2019',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '41',
#   'Alderperson': 'Roman Pucinski',
#   'Start Date': '1973',
#   'End Date': '1991',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '41',
#   'Alderperson': 'Brian Doherty',
#   'Start Date': 'May 1991',
#   'End Date': 'May 2011',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '41',
#   'Alderperson': "Mary O'Connor",
#   'Start Date': 'May 2011',
#   'End Date': 'May 2015',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '41',
#   'Alderperson': 'Anthony Napolitano',
#   'Start Date': 'May 18, 2015',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '44',
#   'Alderperson': 'William Singer',
#   'Start Date': '1971',
#   'End Date': '1975',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '44',
#   'Alderperson': 'Dick Simpson',
#   'Start Date': '1971',
#   'End Date': '1979',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '44',
#   'Alderperson': 'John Merlo',
#   'Start Date': '1981',
#   'End Date': '1983',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '44',
#   'Alderperson': 'Bernie Hansen',
#   'Start Date': '1983',
#   'End Date': '2002',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '44',
#   'Alderperson': 'Tom Tunney',
#   'Start Date': 'January 16, 2003',
#   'End Date': 'May 15, 2023',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '44',
#   'Alderperson': 'Bennett Lawson',
#   'Start Date': 'May 15, 2023',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '45',
#   'Alderperson': 'John Arena',
#   'Start Date': 'May 2011',
#   'End Date': 'May 2019',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '45',
#   'Alderperson': 'Jim Gardiner',
#   'Start Date': 'May 20, 2019',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '46',
#   'Alderperson': 'Helen Shiller',
#   'Start Date': '1987',
#   'End Date': '2011',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '46',
#   'Alderperson': 'James Cappleman',
#   'Start Date': 'May 16, 2011',
#   'End Date': 'May 15, 2023',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '46',
#   'Alderperson': 'Angela Clay',
#   'Start Date': 'May 15, 2023',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '48',
#   'Alderperson': 'Kathy Osterman',
#   'Start Date': '1987',
#   'End Date': '1989',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '48',
#   'Alderperson': 'Mary Ann Smith',
#   'Start Date': '1989',
#   'End Date': '2011',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '48',
#   'Alderperson': 'Harry Osterman',
#   'Start Date': 'May 16, 2011',
#   'End Date': 'May 15, 2023',
#   'Party': None,
#   'Notes': None},
#  {'Ward': '48',
#   'Alderperson': 'Leni Manaa-Hoppenworth',
#   'Start Date': 'May 15, 2023',
#   'End Date': 'present',
#   'Party': None,
#   'Notes': None}]

# %%
pd.DataFrame(all_data)
# Out:
#     Ward             Alderperson      Start Date           End Date  \
# 0    1st           John Coughlin  April 16, 1923  November 11, 1938
# 1    1st           Michael Kenna  April 12, 1939      April 9, 1943
# 2    1st           John Budinger   April 9, 1943               1951
# 3    1st         John D'Arco Sr.            1951               1963
# 4    1st               Fred Roti            1968               1991
# ..   ...                     ...             ...                ...
# 199   46             Angela Clay    May 15, 2023            present
# 200   48          Kathy Osterman            1987               1989
# 201   48          Mary Ann Smith            1989               2011
# 202   48          Harry Osterman    May 16, 2011       May 15, 2023
# 203   48  Leni Manaa-Hoppenworth    May 15, 2023            present
#
#           Party                                              Notes
# 0    Democratic      Had been serving since 1892    Died in office
# 1    Democratic            Had previously served from 1897 to 1923
# 2    Democratic  Had previously served (previous iteration of) ...
# 3    Democratic
# 4    Democratic
# ..          ...                                                ...
# 199        None                                               None
# 200        None                                               None
# 201        None                                               None
# 202        None                                               None
# 203        None                                               None
#
# [204 rows x 6 columns]
