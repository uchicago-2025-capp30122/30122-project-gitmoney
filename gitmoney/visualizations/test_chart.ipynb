# %%
# Final Version 
import csv
import pathlib
from typing import List
import altair as alt
import pandas as pd

def plot_calls_by_year_and_ward(csv_file: pathlib.Path) -> None:
    """
    Plot four stacked bar charts: calls and money spent by year and ward, categorized.

    Args:
        csv_file (pathlib.Path): Path to CSV file with year, ward, category, calls, and total_cost

    Returns:
        None (displays four plots)
    """
    # Define constants
    YEAR_RANGE = range(2019, 2024)  
    CAT_COLORS = {
        "Beautification": "#8B648B",
        "Bike Infrastructure": "#F8C8F1",
        "Lighting": "#E89545",
        "Parks & Recreation": "#5DB7B7",
        "Plants, Gardens, & Sustainability": "#82B65B",
        "Schools & Libraries": "#cdcb44",
        "Security Cameras": "#294896",
        "Streets & Transportation": "#BE5151"
    }
    CHART_WIDTH = 600
    CHART_HEIGHT = 400

    # Load and preprocess data once
    df = (pd.read_csv(csv_file)
          .assign(
              year=lambda x: x['year'].astype(int),
              ward=lambda x: x['ward'].astype(int),
              calls=lambda x: x['calls'].astype(float),
              total_cost=lambda x: x['total_cost'].astype(float)
          )
          .query('year in @YEAR_RANGE')
          .groupby(['year', 'ward', 'category'])[['calls', 'total_cost']]
          .sum()
          .reset_index())

    # Prepare aggregated data
    aggregations = {
        'calls_by_year': df.groupby(['year', 'category'])['calls'].sum().unstack(),
        'money_by_year': df.groupby(['year', 'category'])['total_cost'].sum().unstack(),
        'calls_by_ward': df.groupby(['ward', 'category'])['calls'].sum().unstack(),
        'money_by_ward': df.groupby(['ward', 'category'])['total_cost'].sum().unstack()
    }

    def create_chart(data: pd.DataFrame, title: str, x_label: str, y_label: str, rotate_x: bool = False) -> alt.Chart:
       
        melted_data = data.reset_index().melt(
            id_vars=data.index.name,
            var_name='category',
            value_name='value'
        )
        
        return (alt.Chart(melted_data)
                .mark_bar()
                .encode(
                    x=alt.X(f'{data.index.name}:O', 
                           title=x_label,
                           axis=alt.Axis(labelAngle=-90 if rotate_x else 0)),
                    y=alt.Y('value:Q', title=y_label, stack='zero'),
                    color=alt.Color('category:N',
                                  scale=alt.Scale(domain=list(CAT_COLORS.keys()),
                                                range=list(CAT_COLORS.values()))),
                    tooltip=[data.index.name, 'category', alt.Tooltip('value:Q', format='.2f')]
                )
                .properties(
                    title=title,
                    width=CHART_WIDTH,
                    height=CHART_HEIGHT
                ))

    # Define chart configurations
    chart_configs = [
        ('calls_by_year', '311 Calls by Year and Category (2019-2023)', 'Year', 'Number of 311 Calls', False),
        ('calls_by_ward', '311 Calls by Ward and Category (2019-2023)', 'Ward', 'Number of 311 Calls', True),
        ('money_by_year', 'Money Spent by Year and Category (2019-2023)', 'Year', 'Total Money Spent ($)', False),
        ('money_by_ward', 'Money Spent by Ward and Category (2019-2023)', 'Ward', 'Total Money Spent ($)', True)
    ]

    # Generate and display charts
    charts = [create_chart(aggregations[key], title, x_label, y_label, rotate)
              for key, title, x_label, y_label, rotate in chart_configs]
   
    
    # Altair's concatenation (Remove later)
    '''
    try:
        alt.vconcat(*charts).show()
    except AttributeError:'''
    for chart in charts:
        chart.show()

        # Generate and save charts


if __name__ == "__main__":
    csv_file = pathlib.Path.cwd().parent.parent / "30122-project-gitmoney" / "data" / "calls_money.csv"
    print(f"File path: {csv_file}")
    plot_calls_by_year_and_ward(csv_file)
# Out:
# File path: c:\Users\getne\30122-project-gitmoney\data\calls_money.csv
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)

# %%
import json
import pathlib
import altair as alt
import pandas as pd

def generate_chart_specs(csv_file: pathlib.Path) -> dict:
    # Constants
    YEAR_RANGE = range(2019, 2024)
    CAT_COLORS = {
        "Beautification": "#8B648B",
        "Bike Infrastructure": "#F8C8F1",
        "Lighting": "#E89545",
        "Parks & Recreation": "#5DB7B7",
        "Plants, Gardens, & Sustainability": "#82B65B",
        "Schools & Libraries": "#cdcb44",
        "Security Cameras": "#294896",
        "Streets & Transportation": "#BE5151"
    }
    CHART_WIDTH = 600
    CHART_HEIGHT = 400

    # Load and preprocess data
    df = (pd.read_csv(csv_file)
          .assign(
              year=lambda x: x['year'].astype(int),
              ward=lambda x: x['ward'].astype(int),
              calls=lambda x: x['calls'].astype(float),
              total_cost=lambda x: x['total_cost'].astype(float)
          )
          .query('year in @YEAR_RANGE')
          .groupby(['year', 'ward', 'category'])[['calls', 'total_cost']]
          .sum()
          .reset_index())

    # Aggregations
    aggregations = {
        'calls_by_year': df.groupby(['year', 'category'])['calls'].sum().unstack(),
        'money_by_year': df.groupby(['year', 'category'])['total_cost'].sum().unstack(),
        'calls_by_ward': df.groupby(['ward', 'category'])['calls'].sum().unstack(),
        'money_by_ward': df.groupby(['ward', 'category'])['total_cost'].sum().unstack()
    }

    def create_chart(data: pd.DataFrame, title: str, x_label: str, y_label: str, rotate_x: bool = False) -> dict:
        melted_data = data.reset_index().melt(
            id_vars=data.index.name,
            var_name='category',
            value_name='value'
        )
        chart = (alt.Chart(melted_data)
                .mark_bar()
                .encode(
                    x=alt.X(f'{data.index.name}:O', 
                           title=x_label,
                           axis=alt.Axis(labelAngle=-90 if rotate_x else 0)),
                    y=alt.Y('value:Q', title=y_label, stack='zero'),
                    color=alt.Color('category:N',
                                  scale=alt.Scale(domain=list(CAT_COLORS.keys()),
                                                range=list(CAT_COLORS.values()))),
                    tooltip=[data.index.name, 'category', alt.Tooltip('value:Q', format='.2f')]
                )
                .properties(
                    title=title,
                    width=CHART_WIDTH,
                    height=CHART_HEIGHT
                ))
        return chart.to_dict()

    # Chart configurations
    chart_configs = [
        ('calls_by_year', '311 Calls by Year and Category (2019-2023)', 'Year', 'Number of 311 Calls', False),
        ('calls_by_ward', '311 Calls by Ward and Category (2019-2023)', 'Ward', 'Number of 311 Calls', True),
        ('money_by_year', 'Money Spent by Year and Category (2019-2023)', 'Year', 'Total Money Spent ($)', False),
        ('money_by_ward', 'Money Spent by Ward and Category (2019-2023)', 'Ward', 'Total Money Spent ($)', True)
    ]

    # Generate chart specs
    chart_specs = {
        key: create_chart(aggregations[key], title, x_label, y_label, rotate)
        for key, title, x_label, y_label, rotate in chart_configs
    }
    return chart_specs

# Test in Jupyter
csv_file = pathlib.Path.cwd().parent.parent / "30122-project-gitmoney" / "data" / "calls_money.csv"
specs = generate_chart_specs(csv_file)

# Display the JSON specs in Jupyter
print(json.dumps(specs, indent=2))

# Optional: Test rendering one chart in Jupyter
chart = alt.Chart.from_dict(specs['calls_by_year'])
chart.display()
# Out:
# {
#   "calls_by_year": {
#     "config": {
#       "view": {
#         "continuousWidth": 300,
#         "continuousHeight": 300
#       }
#     },
#     "data": {
#       "name": "data-bad99b562f2bad02a4d3a4a0ad24cd68"
#     },
#     "mark": {
#       "type": "bar"
#     },
#     "encoding": {
#       "color": {
#         "field": "category",
#         "scale": {
#           "domain": [
#             "Beautification",
#             "Bike Infrastructure",
#             "Lighting",
#             "Parks & Recreation",
#             "Plants, Gardens, & Sustainability",
#             "Schools & Libraries",
#             "Security Cameras",
#             "Streets & Transportation"
#           ],
#           "range": [
#             "#8B648B",
#             "#F8C8F1",
#             "#E89545",
#             "#5DB7B7",
#             "#82B65B",
#             "#cdcb44",
#             "#294896",
#             "#BE5151"
#           ]
#         },
#         "type": "nominal"
#       },
#       "tooltip": [
#         {
#           "field": "year",
#           "type": "quantitative"
#         },
#         {
#           "field": "category",
#           "type": "nominal"
#         },
#         {
#           "field": "value",
#           "format": ".2f",
#           "type": "quantitative"
#         }
#       ],
#       "x": {
#         "axis": {
#           "labelAngle": 0
#         },
#         "field": "year",
#         "title": "Year",
#         "type": "ordinal"
#       },
#       "y": {
#         "field": "value",
#         "stack": "zero",
#         "title": "Number of 311 Calls",
#         "type": "quantitative"
#       }
#     },
#     "height": 400,
#     "title": "311 Calls by Year and Category (2019-2023)",
#     "width": 600,
#     "$schema": "https://vega.github.io/schema/vega-lite/v5.20.1.json",
#     "datasets": {
#       "data-bad99b562f2bad02a4d3a4a0ad24cd68": [
#         {
#           "year": 2019,
#           "category": "Beautification",
#           "value": 192651.0
#         },
#         {
#           "year": 2020,
#           "category": "Beautification",
#           "value": 226121.0
#         },
#         {
#           "year": 2021,
#           "category": "Beautification",
#           "value": 183231.0
#         },
#         {
#           "year": 2022,
#           "category": "Beautification",
#           "value": 151475.0
#         },
#         {
#           "year": 2023,
#           "category": "Beautification",
#           "value": 145395.0
#         },
#         {
#           "year": 2019,
#           "category": "Bike Infrastructure",
#           "value": 2119.0
#         },
#         {
#           "year": 2020,
#           "category": "Bike Infrastructure",
#           "value": 1118.0
#         },
#         {
#           "year": 2021,
#           "category": "Bike Infrastructure",
#           "value": 1986.0
#         },
#         {
#           "year": 2022,
#           "category": "Bike Infrastructure",
#           "value": 3446.0
#         },
#         {
#           "year": 2023,
#           "category": "Bike Infrastructure",
#           "value": 2734.0
#         },
#         {
#           "year": 2019,
#           "category": "Lighting",
#           "value": 27863.0
#         },
#         {
#           "year": 2020,
#           "category": "Lighting",
#           "value": 17720.0
#         },
#         {
#           "year": 2021,
#           "category": "Lighting",
#           "value": 8870.0
#         },
#         {
#           "year": 2022,
#           "category": "Lighting",
#           "value": 7559.0
#         },
#         {
#           "year": 2023,
#           "category": "Lighting",
#           "value": 8501.0
#         },
#         {
#           "year": 2019,
#           "category": "Parks & Recreation",
#           "value": 404.0
#         },
#         {
#           "year": 2020,
#           "category": "Parks & Recreation",
#           "value": 135.0
#         },
#         {
#           "year": 2021,
#           "category": "Parks & Recreation",
#           "value": 596.0
#         },
#         {
#           "year": 2022,
#           "category": "Parks & Recreation",
#           "value": 338.0
#         },
#         {
#           "year": 2023,
#           "category": "Parks & Recreation",
#           "value": 313.0
#         },
#         {
#           "year": 2019,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 21484.0
#         },
#         {
#           "year": 2020,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 21141.0
#         },
#         {
#           "year": 2021,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 21727.0
#         },
#         {
#           "year": 2022,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 31647.0
#         },
#         {
#           "year": 2023,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 40708.0
#         },
#         {
#           "year": 2019,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "year": 2020,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "year": 2021,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "year": 2022,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "year": 2023,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "year": 2019,
#           "category": "Security Cameras",
#           "value": 8966.0
#         },
#         {
#           "year": 2020,
#           "category": "Security Cameras",
#           "value": 10835.0
#         },
#         {
#           "year": 2021,
#           "category": "Security Cameras",
#           "value": 11289.0
#         },
#         {
#           "year": 2022,
#           "category": "Security Cameras",
#           "value": 11720.0
#         },
#         {
#           "year": 2023,
#           "category": "Security Cameras",
#           "value": 12045.0
#         },
#         {
#           "year": 2019,
#           "category": "Streets & Transportation",
#           "value": 264391.0
#         },
#         {
#           "year": 2020,
#           "category": "Streets & Transportation",
#           "value": 199902.0
#         },
#         {
#           "year": 2021,
#           "category": "Streets & Transportation",
#           "value": 167919.0
#         },
#         {
#           "year": 2022,
#           "category": "Streets & Transportation",
#           "value": 187936.0
#         },
#         {
#           "year": 2023,
#           "category": "Streets & Transportation",
#           "value": 160300.0
#         }
#       ]
#     }
#   },
#   "calls_by_ward": {
#     "config": {
#       "view": {
#         "continuousWidth": 300,
#         "continuousHeight": 300
#       }
#     },
#     "data": {
#       "name": "data-2504d5f428da4687b19b39cd484f16fb"
#     },
#     "mark": {
#       "type": "bar"
#     },
#     "encoding": {
#       "color": {
#         "field": "category",
#         "scale": {
#           "domain": [
#             "Beautification",
#             "Bike Infrastructure",
#             "Lighting",
#             "Parks & Recreation",
#             "Plants, Gardens, & Sustainability",
#             "Schools & Libraries",
#             "Security Cameras",
#             "Streets & Transportation"
#           ],
#           "range": [
#             "#8B648B",
#             "#F8C8F1",
#             "#E89545",
#             "#5DB7B7",
#             "#82B65B",
#             "#cdcb44",
#             "#294896",
#             "#BE5151"
#           ]
#         },
#         "type": "nominal"
#       },
#       "tooltip": [
#         {
#           "field": "ward",
#           "type": "quantitative"
#         },
#         {
#           "field": "category",
#           "type": "nominal"
#         },
#         {
#           "field": "value",
#           "format": ".2f",
#           "type": "quantitative"
#         }
#       ],
#       "x": {
#         "axis": {
#           "labelAngle": -90
#         },
#         "field": "ward",
#         "title": "Ward",
#         "type": "ordinal"
#       },
#       "y": {
#         "field": "value",
#         "stack": "zero",
#         "title": "Number of 311 Calls",
#         "type": "quantitative"
#       }
#     },
#     "height": 400,
#     "title": "311 Calls by Ward and Category (2019-2023)",
#     "width": 600,
#     "$schema": "https://vega.github.io/schema/vega-lite/v5.20.1.json",
#     "datasets": {
#       "data-2504d5f428da4687b19b39cd484f16fb": [
#         {
#           "ward": 1,
#           "category": "Beautification",
#           "value": 32710.0
#         },
#         {
#           "ward": 2,
#           "category": "Beautification",
#           "value": 11396.0
#         },
#         {
#           "ward": 3,
#           "category": "Beautification",
#           "value": 15395.0
#         },
#         {
#           "ward": 4,
#           "category": "Beautification",
#           "value": 12125.0
#         },
#         {
#           "ward": 5,
#           "category": "Beautification",
#           "value": 5489.0
#         },
#         {
#           "ward": 6,
#           "category": "Beautification",
#           "value": 21486.0
#         },
#         {
#           "ward": 7,
#           "category": "Beautification",
#           "value": 12044.0
#         },
#         {
#           "ward": 8,
#           "category": "Beautification",
#           "value": 13971.0
#         },
#         {
#           "ward": 9,
#           "category": "Beautification",
#           "value": 19661.0
#         },
#         {
#           "ward": 10,
#           "category": "Beautification",
#           "value": 18233.0
#         },
#         {
#           "ward": 11,
#           "category": "Beautification",
#           "value": 19074.0
#         },
#         {
#           "ward": 12,
#           "category": "Beautification",
#           "value": 33879.0
#         },
#         {
#           "ward": 13,
#           "category": "Beautification",
#           "value": 9538.0
#         },
#         {
#           "ward": 14,
#           "category": "Beautification",
#           "value": 36575.0
#         },
#         {
#           "ward": 15,
#           "category": "Beautification",
#           "value": 23336.0
#         },
#         {
#           "ward": 16,
#           "category": "Beautification",
#           "value": 33628.0
#         },
#         {
#           "ward": 17,
#           "category": "Beautification",
#           "value": 21362.0
#         },
#         {
#           "ward": 18,
#           "category": "Beautification",
#           "value": 16899.0
#         },
#         {
#           "ward": 19,
#           "category": "Beautification",
#           "value": 10298.0
#         },
#         {
#           "ward": 20,
#           "category": "Beautification",
#           "value": 25204.0
#         },
#         {
#           "ward": 21,
#           "category": "Beautification",
#           "value": 18448.0
#         },
#         {
#           "ward": 22,
#           "category": "Beautification",
#           "value": 20686.0
#         },
#         {
#           "ward": 23,
#           "category": "Beautification",
#           "value": 19320.0
#         },
#         {
#           "ward": 24,
#           "category": "Beautification",
#           "value": 32347.0
#         },
#         {
#           "ward": 25,
#           "category": "Beautification",
#           "value": 30122.0
#         },
#         {
#           "ward": 26,
#           "category": "Beautification",
#           "value": 18432.0
#         },
#         {
#           "ward": 27,
#           "category": "Beautification",
#           "value": 32976.0
#         },
#         {
#           "ward": 28,
#           "category": "Beautification",
#           "value": 29714.0
#         },
#         {
#           "ward": 29,
#           "category": "Beautification",
#           "value": 11445.0
#         },
#         {
#           "ward": 30,
#           "category": "Beautification",
#           "value": 14851.0
#         },
#         {
#           "ward": 31,
#           "category": "Beautification",
#           "value": 13034.0
#         },
#         {
#           "ward": 32,
#           "category": "Beautification",
#           "value": 23486.0
#         },
#         {
#           "ward": 33,
#           "category": "Beautification",
#           "value": 21639.0
#         },
#         {
#           "ward": 34,
#           "category": "Beautification",
#           "value": 24836.0
#         },
#         {
#           "ward": 35,
#           "category": "Beautification",
#           "value": 19157.0
#         },
#         {
#           "ward": 36,
#           "category": "Beautification",
#           "value": 14387.0
#         },
#         {
#           "ward": 37,
#           "category": "Beautification",
#           "value": 17144.0
#         },
#         {
#           "ward": 38,
#           "category": "Beautification",
#           "value": 9858.0
#         },
#         {
#           "ward": 39,
#           "category": "Beautification",
#           "value": 11731.0
#         },
#         {
#           "ward": 40,
#           "category": "Beautification",
#           "value": 10947.0
#         },
#         {
#           "ward": 41,
#           "category": "Beautification",
#           "value": 6937.0
#         },
#         {
#           "ward": 42,
#           "category": "Beautification",
#           "value": 16900.0
#         },
#         {
#           "ward": 43,
#           "category": "Beautification",
#           "value": 10433.0
#         },
#         {
#           "ward": 44,
#           "category": "Beautification",
#           "value": 9490.0
#         },
#         {
#           "ward": 45,
#           "category": "Beautification",
#           "value": 14063.0
#         },
#         {
#           "ward": 46,
#           "category": "Beautification",
#           "value": 7876.0
#         },
#         {
#           "ward": 47,
#           "category": "Beautification",
#           "value": 21391.0
#         },
#         {
#           "ward": 48,
#           "category": "Beautification",
#           "value": 8690.0
#         },
#         {
#           "ward": 49,
#           "category": "Beautification",
#           "value": 8674.0
#         },
#         {
#           "ward": 50,
#           "category": "Beautification",
#           "value": 7556.0
#         },
#         {
#           "ward": 1,
#           "category": "Bike Infrastructure",
#           "value": 500.0
#         },
#         {
#           "ward": 2,
#           "category": "Bike Infrastructure",
#           "value": 226.0
#         },
#         {
#           "ward": 3,
#           "category": "Bike Infrastructure",
#           "value": 152.0
#         },
#         {
#           "ward": 4,
#           "category": "Bike Infrastructure",
#           "value": 236.0
#         },
#         {
#           "ward": 5,
#           "category": "Bike Infrastructure",
#           "value": 98.0
#         },
#         {
#           "ward": 6,
#           "category": "Bike Infrastructure",
#           "value": 109.0
#         },
#         {
#           "ward": 7,
#           "category": "Bike Infrastructure",
#           "value": 12.0
#         },
#         {
#           "ward": 8,
#           "category": "Bike Infrastructure",
#           "value": 12.0
#         },
#         {
#           "ward": 9,
#           "category": "Bike Infrastructure",
#           "value": 14.0
#         },
#         {
#           "ward": 10,
#           "category": "Bike Infrastructure",
#           "value": 34.0
#         },
#         {
#           "ward": 11,
#           "category": "Bike Infrastructure",
#           "value": 237.0
#         },
#         {
#           "ward": 12,
#           "category": "Bike Infrastructure",
#           "value": 32.0
#         },
#         {
#           "ward": 13,
#           "category": "Bike Infrastructure",
#           "value": 13.0
#         },
#         {
#           "ward": 14,
#           "category": "Bike Infrastructure",
#           "value": 26.0
#         },
#         {
#           "ward": 15,
#           "category": "Bike Infrastructure",
#           "value": 12.0
#         },
#         {
#           "ward": 16,
#           "category": "Bike Infrastructure",
#           "value": 7.0
#         },
#         {
#           "ward": 17,
#           "category": "Bike Infrastructure",
#           "value": 18.0
#         },
#         {
#           "ward": 18,
#           "category": "Bike Infrastructure",
#           "value": 10.0
#         },
#         {
#           "ward": 19,
#           "category": "Bike Infrastructure",
#           "value": 8.0
#         },
#         {
#           "ward": 20,
#           "category": "Bike Infrastructure",
#           "value": 16.0
#         },
#         {
#           "ward": 21,
#           "category": "Bike Infrastructure",
#           "value": 60.0
#         },
#         {
#           "ward": 22,
#           "category": "Bike Infrastructure",
#           "value": 15.0
#         },
#         {
#           "ward": 23,
#           "category": "Bike Infrastructure",
#           "value": 21.0
#         },
#         {
#           "ward": 24,
#           "category": "Bike Infrastructure",
#           "value": 15.0
#         },
#         {
#           "ward": 25,
#           "category": "Bike Infrastructure",
#           "value": 416.0
#         },
#         {
#           "ward": 26,
#           "category": "Bike Infrastructure",
#           "value": 100.0
#         },
#         {
#           "ward": 27,
#           "category": "Bike Infrastructure",
#           "value": 3130.0
#         },
#         {
#           "ward": 28,
#           "category": "Bike Infrastructure",
#           "value": 671.0
#         },
#         {
#           "ward": 29,
#           "category": "Bike Infrastructure",
#           "value": 14.0
#         },
#         {
#           "ward": 30,
#           "category": "Bike Infrastructure",
#           "value": 81.0
#         },
#         {
#           "ward": 31,
#           "category": "Bike Infrastructure",
#           "value": 57.0
#         },
#         {
#           "ward": 32,
#           "category": "Bike Infrastructure",
#           "value": 559.0
#         },
#         {
#           "ward": 33,
#           "category": "Bike Infrastructure",
#           "value": 181.0
#         },
#         {
#           "ward": 34,
#           "category": "Bike Infrastructure",
#           "value": 420.0
#         },
#         {
#           "ward": 35,
#           "category": "Bike Infrastructure",
#           "value": 130.0
#         },
#         {
#           "ward": 36,
#           "category": "Bike Infrastructure",
#           "value": 72.0
#         },
#         {
#           "ward": 37,
#           "category": "Bike Infrastructure",
#           "value": 28.0
#         },
#         {
#           "ward": 38,
#           "category": "Bike Infrastructure",
#           "value": 25.0
#         },
#         {
#           "ward": 39,
#           "category": "Bike Infrastructure",
#           "value": 244.0
#         },
#         {
#           "ward": 40,
#           "category": "Bike Infrastructure",
#           "value": 308.0
#         },
#         {
#           "ward": 41,
#           "category": "Bike Infrastructure",
#           "value": 21.0
#         },
#         {
#           "ward": 42,
#           "category": "Bike Infrastructure",
#           "value": 1399.0
#         },
#         {
#           "ward": 43,
#           "category": "Bike Infrastructure",
#           "value": 323.0
#         },
#         {
#           "ward": 44,
#           "category": "Bike Infrastructure",
#           "value": 268.0
#         },
#         {
#           "ward": 45,
#           "category": "Bike Infrastructure",
#           "value": 195.0
#         },
#         {
#           "ward": 46,
#           "category": "Bike Infrastructure",
#           "value": 294.0
#         },
#         {
#           "ward": 47,
#           "category": "Bike Infrastructure",
#           "value": 242.0
#         },
#         {
#           "ward": 48,
#           "category": "Bike Infrastructure",
#           "value": 219.0
#         },
#         {
#           "ward": 49,
#           "category": "Bike Infrastructure",
#           "value": 72.0
#         },
#         {
#           "ward": 50,
#           "category": "Bike Infrastructure",
#           "value": 51.0
#         },
#         {
#           "ward": 1,
#           "category": "Lighting",
#           "value": 906.0
#         },
#         {
#           "ward": 2,
#           "category": "Lighting",
#           "value": 555.0
#         },
#         {
#           "ward": 3,
#           "category": "Lighting",
#           "value": 769.0
#         },
#         {
#           "ward": 4,
#           "category": "Lighting",
#           "value": 693.0
#         },
#         {
#           "ward": 5,
#           "category": "Lighting",
#           "value": 767.0
#         },
#         {
#           "ward": 6,
#           "category": "Lighting",
#           "value": 2770.0
#         },
#         {
#           "ward": 7,
#           "category": "Lighting",
#           "value": 1468.0
#         },
#         {
#           "ward": 8,
#           "category": "Lighting",
#           "value": 2763.0
#         },
#         {
#           "ward": 9,
#           "category": "Lighting",
#           "value": 2621.0
#         },
#         {
#           "ward": 10,
#           "category": "Lighting",
#           "value": 4283.0
#         },
#         {
#           "ward": 11,
#           "category": "Lighting",
#           "value": 1363.0
#         },
#         {
#           "ward": 12,
#           "category": "Lighting",
#           "value": 1117.0
#         },
#         {
#           "ward": 13,
#           "category": "Lighting",
#           "value": 3613.0
#         },
#         {
#           "ward": 14,
#           "category": "Lighting",
#           "value": 1401.0
#         },
#         {
#           "ward": 15,
#           "category": "Lighting",
#           "value": 742.0
#         },
#         {
#           "ward": 16,
#           "category": "Lighting",
#           "value": 1684.0
#         },
#         {
#           "ward": 17,
#           "category": "Lighting",
#           "value": 1877.0
#         },
#         {
#           "ward": 18,
#           "category": "Lighting",
#           "value": 2338.0
#         },
#         {
#           "ward": 19,
#           "category": "Lighting",
#           "value": 1486.0
#         },
#         {
#           "ward": 20,
#           "category": "Lighting",
#           "value": 1371.0
#         },
#         {
#           "ward": 21,
#           "category": "Lighting",
#           "value": 2800.0
#         },
#         {
#           "ward": 22,
#           "category": "Lighting",
#           "value": 1377.0
#         },
#         {
#           "ward": 23,
#           "category": "Lighting",
#           "value": 2361.0
#         },
#         {
#           "ward": 24,
#           "category": "Lighting",
#           "value": 987.0
#         },
#         {
#           "ward": 25,
#           "category": "Lighting",
#           "value": 887.0
#         },
#         {
#           "ward": 26,
#           "category": "Lighting",
#           "value": 745.0
#         },
#         {
#           "ward": 27,
#           "category": "Lighting",
#           "value": 1042.0
#         },
#         {
#           "ward": 28,
#           "category": "Lighting",
#           "value": 1077.0
#         },
#         {
#           "ward": 29,
#           "category": "Lighting",
#           "value": 1536.0
#         },
#         {
#           "ward": 30,
#           "category": "Lighting",
#           "value": 1116.0
#         },
#         {
#           "ward": 31,
#           "category": "Lighting",
#           "value": 1076.0
#         },
#         {
#           "ward": 32,
#           "category": "Lighting",
#           "value": 1061.0
#         },
#         {
#           "ward": 33,
#           "category": "Lighting",
#           "value": 1362.0
#         },
#         {
#           "ward": 34,
#           "category": "Lighting",
#           "value": 2406.0
#         },
#         {
#           "ward": 35,
#           "category": "Lighting",
#           "value": 1207.0
#         },
#         {
#           "ward": 36,
#           "category": "Lighting",
#           "value": 1536.0
#         },
#         {
#           "ward": 37,
#           "category": "Lighting",
#           "value": 1396.0
#         },
#         {
#           "ward": 38,
#           "category": "Lighting",
#           "value": 1961.0
#         },
#         {
#           "ward": 39,
#           "category": "Lighting",
#           "value": 1327.0
#         },
#         {
#           "ward": 40,
#           "category": "Lighting",
#           "value": 987.0
#         },
#         {
#           "ward": 41,
#           "category": "Lighting",
#           "value": 1451.0
#         },
#         {
#           "ward": 42,
#           "category": "Lighting",
#           "value": 231.0
#         },
#         {
#           "ward": 43,
#           "category": "Lighting",
#           "value": 446.0
#         },
#         {
#           "ward": 44,
#           "category": "Lighting",
#           "value": 403.0
#         },
#         {
#           "ward": 45,
#           "category": "Lighting",
#           "value": 1819.0
#         },
#         {
#           "ward": 46,
#           "category": "Lighting",
#           "value": 361.0
#         },
#         {
#           "ward": 47,
#           "category": "Lighting",
#           "value": 865.0
#         },
#         {
#           "ward": 48,
#           "category": "Lighting",
#           "value": 614.0
#         },
#         {
#           "ward": 49,
#           "category": "Lighting",
#           "value": 583.0
#         },
#         {
#           "ward": 50,
#           "category": "Lighting",
#           "value": 906.0
#         },
#         {
#           "ward": 1,
#           "category": "Parks & Recreation",
#           "value": 29.0
#         },
#         {
#           "ward": 2,
#           "category": "Parks & Recreation",
#           "value": 7.0
#         },
#         {
#           "ward": 3,
#           "category": "Parks & Recreation",
#           "value": 98.0
#         },
#         {
#           "ward": 4,
#           "category": "Parks & Recreation",
#           "value": 39.0
#         },
#         {
#           "ward": 5,
#           "category": "Parks & Recreation",
#           "value": 35.0
#         },
#         {
#           "ward": 6,
#           "category": "Parks & Recreation",
#           "value": 120.0
#         },
#         {
#           "ward": 7,
#           "category": "Parks & Recreation",
#           "value": 48.0
#         },
#         {
#           "ward": 8,
#           "category": "Parks & Recreation",
#           "value": 67.0
#         },
#         {
#           "ward": 9,
#           "category": "Parks & Recreation",
#           "value": 64.0
#         },
#         {
#           "ward": 10,
#           "category": "Parks & Recreation",
#           "value": 32.0
#         },
#         {
#           "ward": 11,
#           "category": "Parks & Recreation",
#           "value": 23.0
#         },
#         {
#           "ward": 12,
#           "category": "Parks & Recreation",
#           "value": 17.0
#         },
#         {
#           "ward": 13,
#           "category": "Parks & Recreation",
#           "value": 2.0
#         },
#         {
#           "ward": 14,
#           "category": "Parks & Recreation",
#           "value": 8.0
#         },
#         {
#           "ward": 15,
#           "category": "Parks & Recreation",
#           "value": 37.0
#         },
#         {
#           "ward": 16,
#           "category": "Parks & Recreation",
#           "value": 102.0
#         },
#         {
#           "ward": 17,
#           "category": "Parks & Recreation",
#           "value": 38.0
#         },
#         {
#           "ward": 18,
#           "category": "Parks & Recreation",
#           "value": 16.0
#         },
#         {
#           "ward": 19,
#           "category": "Parks & Recreation",
#           "value": 26.0
#         },
#         {
#           "ward": 20,
#           "category": "Parks & Recreation",
#           "value": 57.0
#         },
#         {
#           "ward": 21,
#           "category": "Parks & Recreation",
#           "value": 65.0
#         },
#         {
#           "ward": 22,
#           "category": "Parks & Recreation",
#           "value": 11.0
#         },
#         {
#           "ward": 23,
#           "category": "Parks & Recreation",
#           "value": 11.0
#         },
#         {
#           "ward": 24,
#           "category": "Parks & Recreation",
#           "value": 60.0
#         },
#         {
#           "ward": 25,
#           "category": "Parks & Recreation",
#           "value": 38.0
#         },
#         {
#           "ward": 26,
#           "category": "Parks & Recreation",
#           "value": 59.0
#         },
#         {
#           "ward": 27,
#           "category": "Parks & Recreation",
#           "value": 90.0
#         },
#         {
#           "ward": 28,
#           "category": "Parks & Recreation",
#           "value": 104.0
#         },
#         {
#           "ward": 29,
#           "category": "Parks & Recreation",
#           "value": 58.0
#         },
#         {
#           "ward": 30,
#           "category": "Parks & Recreation",
#           "value": 25.0
#         },
#         {
#           "ward": 31,
#           "category": "Parks & Recreation",
#           "value": 9.0
#         },
#         {
#           "ward": 32,
#           "category": "Parks & Recreation",
#           "value": 7.0
#         },
#         {
#           "ward": 33,
#           "category": "Parks & Recreation",
#           "value": 34.0
#         },
#         {
#           "ward": 34,
#           "category": "Parks & Recreation",
#           "value": 60.0
#         },
#         {
#           "ward": 35,
#           "category": "Parks & Recreation",
#           "value": 24.0
#         },
#         {
#           "ward": 36,
#           "category": "Parks & Recreation",
#           "value": 21.0
#         },
#         {
#           "ward": 37,
#           "category": "Parks & Recreation",
#           "value": 43.0
#         },
#         {
#           "ward": 38,
#           "category": "Parks & Recreation",
#           "value": 9.0
#         },
#         {
#           "ward": 39,
#           "category": "Parks & Recreation",
#           "value": 36.0
#         },
#         {
#           "ward": 40,
#           "category": "Parks & Recreation",
#           "value": 14.0
#         },
#         {
#           "ward": 41,
#           "category": "Parks & Recreation",
#           "value": 13.0
#         },
#         {
#           "ward": 42,
#           "category": "Parks & Recreation",
#           "value": 14.0
#         },
#         {
#           "ward": 43,
#           "category": "Parks & Recreation",
#           "value": 8.0
#         },
#         {
#           "ward": 44,
#           "category": "Parks & Recreation",
#           "value": 8.0
#         },
#         {
#           "ward": 45,
#           "category": "Parks & Recreation",
#           "value": 18.0
#         },
#         {
#           "ward": 46,
#           "category": "Parks & Recreation",
#           "value": 21.0
#         },
#         {
#           "ward": 47,
#           "category": "Parks & Recreation",
#           "value": 20.0
#         },
#         {
#           "ward": 48,
#           "category": "Parks & Recreation",
#           "value": 24.0
#         },
#         {
#           "ward": 49,
#           "category": "Parks & Recreation",
#           "value": 5.0
#         },
#         {
#           "ward": 50,
#           "category": "Parks & Recreation",
#           "value": 12.0
#         },
#         {
#           "ward": 1,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2442.0
#         },
#         {
#           "ward": 2,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 1023.0
#         },
#         {
#           "ward": 3,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 1210.0
#         },
#         {
#           "ward": 4,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 1035.0
#         },
#         {
#           "ward": 5,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 1300.0
#         },
#         {
#           "ward": 6,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 3197.0
#         },
#         {
#           "ward": 7,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2550.0
#         },
#         {
#           "ward": 8,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 3583.0
#         },
#         {
#           "ward": 9,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 3619.0
#         },
#         {
#           "ward": 10,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2738.0
#         },
#         {
#           "ward": 11,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 3948.0
#         },
#         {
#           "ward": 12,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 3226.0
#         },
#         {
#           "ward": 13,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2777.0
#         },
#         {
#           "ward": 14,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2276.0
#         },
#         {
#           "ward": 15,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 1718.0
#         },
#         {
#           "ward": 16,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2461.0
#         },
#         {
#           "ward": 17,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 4232.0
#         },
#         {
#           "ward": 18,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 3347.0
#         },
#         {
#           "ward": 19,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 6235.0
#         },
#         {
#           "ward": 20,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 1772.0
#         },
#         {
#           "ward": 21,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 3980.0
#         },
#         {
#           "ward": 22,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 3147.0
#         },
#         {
#           "ward": 23,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 3197.0
#         },
#         {
#           "ward": 24,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 3851.0
#         },
#         {
#           "ward": 25,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 1307.0
#         },
#         {
#           "ward": 26,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2241.0
#         },
#         {
#           "ward": 27,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 1953.0
#         },
#         {
#           "ward": 28,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 1943.0
#         },
#         {
#           "ward": 29,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2792.0
#         },
#         {
#           "ward": 30,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 3470.0
#         },
#         {
#           "ward": 31,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2779.0
#         },
#         {
#           "ward": 32,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 3396.0
#         },
#         {
#           "ward": 33,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2321.0
#         },
#         {
#           "ward": 34,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2859.0
#         },
#         {
#           "ward": 35,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2716.0
#         },
#         {
#           "ward": 36,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2737.0
#         },
#         {
#           "ward": 37,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2072.0
#         },
#         {
#           "ward": 38,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 5238.0
#         },
#         {
#           "ward": 39,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 4080.0
#         },
#         {
#           "ward": 40,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2751.0
#         },
#         {
#           "ward": 41,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 5142.0
#         },
#         {
#           "ward": 42,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 320.0
#         },
#         {
#           "ward": 43,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 1745.0
#         },
#         {
#           "ward": 44,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 1639.0
#         },
#         {
#           "ward": 45,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 4711.0
#         },
#         {
#           "ward": 46,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 1034.0
#         },
#         {
#           "ward": 47,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 3281.0
#         },
#         {
#           "ward": 48,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 1686.0
#         },
#         {
#           "ward": 49,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 1279.0
#         },
#         {
#           "ward": 50,
#           "category": "Plants, Gardens, & Sustainability",
#           "value": 2351.0
#         },
#         {
#           "ward": 1,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 2,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 3,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 4,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 5,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 6,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 7,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 8,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 9,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 10,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 11,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 12,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 13,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 14,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 15,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 16,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 17,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 18,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 19,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 20,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 21,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 22,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 23,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 24,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 25,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 26,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 27,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 28,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 29,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 30,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 31,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 32,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 33,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 34,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 35,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 36,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 37,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 38,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 39,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 40,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 41,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 42,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 43,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 44,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 45,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 46,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 47,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 48,
#           "category": "Schools & Libraries",
#           "value": 0.0
#         },
#         {
#           "ward": 49,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 50,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 1,
#           "category": "Security Cameras",
#           "value": 1213.0
#         },
#         {
#           "ward": 2,
#           "category": "Security Cameras",
#           "value": 550.0
#         },
#         {
#           "ward": 3,
#           "category": "Security Cameras",
#           "value": 982.0
#         },
#         {
#           "ward": 4,
#           "category": "Security Cameras",
#           "value": 425.0
#         },
#         {
#           "ward": 5,
#           "category": "Security Cameras",
#           "value": 571.0
#         },
#         {
#           "ward": 6,
#           "category": "Security Cameras",
#           "value": 2647.0
#         },
#         {
#           "ward": 7,
#           "category": "Security Cameras",
#           "value": 1359.0
#         },
#         {
#           "ward": 8,
#           "category": "Security Cameras",
#           "value": 1711.0
#         },
#         {
#           "ward": 9,
#           "category": "Security Cameras",
#           "value": 2089.0
#         },
#         {
#           "ward": 10,
#           "category": "Security Cameras",
#           "value": 940.0
#         },
#         {
#           "ward": 11,
#           "category": "Security Cameras",
#           "value": 869.0
#         },
#         {
#           "ward": 12,
#           "category": "Security Cameras",
#           "value": 832.0
#         },
#         {
#           "ward": 13,
#           "category": "Security Cameras",
#           "value": 225.0
#         },
#         {
#           "ward": 14,
#           "category": "Security Cameras",
#           "value": 565.0
#         },
#         {
#           "ward": 15,
#           "category": "Security Cameras",
#           "value": 968.0
#         },
#         {
#           "ward": 16,
#           "category": "Security Cameras",
#           "value": 2431.0
#         },
#         {
#           "ward": 17,
#           "category": "Security Cameras",
#           "value": 1841.0
#         },
#         {
#           "ward": 18,
#           "category": "Security Cameras",
#           "value": 884.0
#         },
#         {
#           "ward": 19,
#           "category": "Security Cameras",
#           "value": 225.0
#         },
#         {
#           "ward": 20,
#           "category": "Security Cameras",
#           "value": 1629.0
#         },
#         {
#           "ward": 21,
#           "category": "Security Cameras",
#           "value": 1733.0
#         },
#         {
#           "ward": 22,
#           "category": "Security Cameras",
#           "value": 838.0
#         },
#         {
#           "ward": 23,
#           "category": "Security Cameras",
#           "value": 350.0
#         },
#         {
#           "ward": 24,
#           "category": "Security Cameras",
#           "value": 2794.0
#         },
#         {
#           "ward": 25,
#           "category": "Security Cameras",
#           "value": 1092.0
#         },
#         {
#           "ward": 26,
#           "category": "Security Cameras",
#           "value": 1185.0
#         },
#         {
#           "ward": 27,
#           "category": "Security Cameras",
#           "value": 2389.0
#         },
#         {
#           "ward": 28,
#           "category": "Security Cameras",
#           "value": 3390.0
#         },
#         {
#           "ward": 29,
#           "category": "Security Cameras",
#           "value": 1124.0
#         },
#         {
#           "ward": 30,
#           "category": "Security Cameras",
#           "value": 741.0
#         },
#         {
#           "ward": 31,
#           "category": "Security Cameras",
#           "value": 766.0
#         },
#         {
#           "ward": 32,
#           "category": "Security Cameras",
#           "value": 1133.0
#         },
#         {
#           "ward": 33,
#           "category": "Security Cameras",
#           "value": 1072.0
#         },
#         {
#           "ward": 34,
#           "category": "Security Cameras",
#           "value": 2015.0
#         },
#         {
#           "ward": 35,
#           "category": "Security Cameras",
#           "value": 750.0
#         },
#         {
#           "ward": 36,
#           "category": "Security Cameras",
#           "value": 911.0
#         },
#         {
#           "ward": 37,
#           "category": "Security Cameras",
#           "value": 2521.0
#         },
#         {
#           "ward": 38,
#           "category": "Security Cameras",
#           "value": 486.0
#         },
#         {
#           "ward": 39,
#           "category": "Security Cameras",
#           "value": 622.0
#         },
#         {
#           "ward": 40,
#           "category": "Security Cameras",
#           "value": 506.0
#         },
#         {
#           "ward": 41,
#           "category": "Security Cameras",
#           "value": 183.0
#         },
#         {
#           "ward": 42,
#           "category": "Security Cameras",
#           "value": 357.0
#         },
#         {
#           "ward": 43,
#           "category": "Security Cameras",
#           "value": 425.0
#         },
#         {
#           "ward": 44,
#           "category": "Security Cameras",
#           "value": 474.0
#         },
#         {
#           "ward": 45,
#           "category": "Security Cameras",
#           "value": 565.0
#         },
#         {
#           "ward": 46,
#           "category": "Security Cameras",
#           "value": 1012.0
#         },
#         {
#           "ward": 47,
#           "category": "Security Cameras",
#           "value": 861.0
#         },
#         {
#           "ward": 48,
#           "category": "Security Cameras",
#           "value": 624.0
#         },
#         {
#           "ward": 49,
#           "category": "Security Cameras",
#           "value": 412.0
#         },
#         {
#           "ward": 50,
#           "category": "Security Cameras",
#           "value": 568.0
#         },
#         {
#           "ward": 1,
#           "category": "Streets & Transportation",
#           "value": 20927.0
#         },
#         {
#           "ward": 2,
#           "category": "Streets & Transportation",
#           "value": 13540.0
#         },
#         {
#           "ward": 3,
#           "category": "Streets & Transportation",
#           "value": 18259.0
#         },
#         {
#           "ward": 4,
#           "category": "Streets & Transportation",
#           "value": 16785.0
#         },
#         {
#           "ward": 5,
#           "category": "Streets & Transportation",
#           "value": 16482.0
#         },
#         {
# ...
#           "category": "Schools & Libraries",
#           "value": 365000.0
#         },
#         {
#           "ward": 14,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 15,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 16,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 17,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 18,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 19,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 20,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 21,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 22,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 23,
#           "category": "Schools & Libraries",
#           "value": 4750.0
#         },
#         {
#           "ward": 24,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 25,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 26,
#           "category": "Schools & Libraries",
#           "value": 20000.0
#         },
#         {
#           "ward": 27,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 28,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 29,
#           "category": "Schools & Libraries",
#           "value": 75000.0
#         },
#         {
#           "ward": 30,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 31,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 32,
#           "category": "Schools & Libraries",
#           "value": 500000.0
#         },
#         {
#           "ward": 33,
#           "category": "Schools & Libraries",
#           "value": 317000.0
#         },
#         {
#           "ward": 34,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 35,
#           "category": "Schools & Libraries",
#           "value": 218500.0
#         },
#         {
#           "ward": 36,
#           "category": "Schools & Libraries",
#           "value": 145000.0
#         },
#         {
#           "ward": 37,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 38,
#           "category": "Schools & Libraries",
#           "value": 10000.0
#         },
#         {
#           "ward": 39,
#           "category": "Schools & Libraries",
#           "value": 511233.0
#         },
#         {
#           "ward": 40,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 41,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 42,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 43,
#           "category": "Schools & Libraries",
#           "value": 25000.0
#         },
#         {
#           "ward": 44,
#           "category": "Schools & Libraries",
#           "value": 100000.0
#         },
#         {
#           "ward": 45,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 46,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 47,
#           "category": "Schools & Libraries",
#           "value": 15495.0
#         },
#         {
#           "ward": 48,
#           "category": "Schools & Libraries",
#           "value": 89999.0
#         },
#         {
#           "ward": 49,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 50,
#           "category": "Schools & Libraries",
#           "value": null
#         },
#         {
#           "ward": 1,
#           "category": "Security Cameras",
#           "value": 93137.0
#         },
#         {
#           "ward": 2,
#           "category": "Security Cameras",
#           "value": 435269.0
#         },
#         {
#           "ward": 3,
#           "category": "Security Cameras",
#           "value": 203677.0
#         },
#         {
#           "ward": 4,
#           "category": "Security Cameras",
#           "value": 397062.0
#         },
#         {
#           "ward": 5,
#           "category": "Security Cameras",
#           "value": 324557.0
#         },
#         {
#           "ward": 6,
#           "category": "Security Cameras",
#           "value": 74328.0
#         },
#         {
#           "ward": 7,
#           "category": "Security Cameras",
#           "value": 24776.0
#         },
#         {
#           "ward": 8,
#           "category": "Security Cameras",
#           "value": 165793.0
#         },
#         {
#           "ward": 9,
#           "category": "Security Cameras",
#           "value": 0.0
#         },
#         {
#           "ward": 10,
#           "category": "Security Cameras",
#           "value": 87933.0
#         },
#         {
#           "ward": 11,
#           "category": "Security Cameras",
#           "value": 368604.0
#         },
#         {
#           "ward": 12,
#           "category": "Security Cameras",
#           "value": 147622.0
#         },
#         {
#           "ward": 13,
#           "category": "Security Cameras",
#           "value": 1800.0
#         },
#         {
#           "ward": 14,
#           "category": "Security Cameras",
#           "value": 24776.0
#         },
#         {
#           "ward": 15,
#           "category": "Security Cameras",
#           "value": 0.0
#         },
#         {
#           "ward": 16,
#           "category": "Security Cameras",
#           "value": 0.0
#         },
#         {
#           "ward": 17,
#           "category": "Security Cameras",
#           "value": 30261.0
#         },
#         {
#           "ward": 18,
#           "category": "Security Cameras",
#           "value": 5485.0
#         },
#         {
#           "ward": 19,
#           "category": "Security Cameras",
#           "value": 163985.0
#         },
#         {
#           "ward": 20,
#           "category": "Security Cameras",
#           "value": 0.0
#         },
#         {
#           "ward": 21,
#           "category": "Security Cameras",
#           "value": 0.0
#         },
#         {
#           "ward": 22,
#           "category": "Security Cameras",
#           "value": 123880.0
#         },
#         {
#           "ward": 23,
#           "category": "Security Cameras",
#           "value": 206345.0
#         },
#         {
#           "ward": 24,
#           "category": "Security Cameras",
#           "value": 368104.0
#         },
#         {
#           "ward": 25,
#           "category": "Security Cameras",
#           "value": 266633.0
#         },
#         {
#           "ward": 26,
#           "category": "Security Cameras",
#           "value": 100904.0
#         },
#         {
#           "ward": 27,
#           "category": "Security Cameras",
#           "value": 524707.0
#         },
#         {
#           "ward": 28,
#           "category": "Security Cameras",
#           "value": 10600.0
#         },
#         {
#           "ward": 29,
#           "category": "Security Cameras",
#           "value": 104904.0
#         },
#         {
#           "ward": 30,
#           "category": "Security Cameras",
#           "value": 26576.0
#         },
#         {
#           "ward": 31,
#           "category": "Security Cameras",
#           "value": 288775.0
#         },
#         {
#           "ward": 32,
#           "category": "Security Cameras",
#           "value": 123680.0
#         },
#         {
#           "ward": 33,
#           "category": "Security Cameras",
#           "value": 67426.0
#         },
#         {
#           "ward": 34,
#           "category": "Security Cameras",
#           "value": 0.0
#         },
#         {
#           "ward": 35,
#           "category": "Security Cameras",
#           "value": 281039.0
#         },
#         {
#           "ward": 36,
#           "category": "Security Cameras",
#           "value": 24776.0
#         },
#         {
#           "ward": 37,
#           "category": "Security Cameras",
#           "value": 49552.0
#         },
#         {
#           "ward": 38,
#           "category": "Security Cameras",
#           "value": 24776.0
#         },
#         {
#           "ward": 39,
#           "category": "Security Cameras",
#           "value": 159427.0
#         },
#         {
#           "ward": 40,
#           "category": "Security Cameras",
#           "value": 236389.0
#         },
#         {
#           "ward": 41,
#           "category": "Security Cameras",
#           "value": 60523.0
#         },
#         {
#           "ward": 42,
#           "category": "Security Cameras",
#           "value": 1314740.0
#         },
#         {
#           "ward": 43,
#           "category": "Security Cameras",
#           "value": 421188.0
#         },
#         {
#           "ward": 44,
#           "category": "Security Cameras",
#           "value": 136305.0
#         },
#         {
#           "ward": 45,
#           "category": "Security Cameras",
#           "value": 169377.0
#         },
#         {
#           "ward": 46,
#           "category": "Security Cameras",
#           "value": 127380.0
#         },
#         {
#           "ward": 47,
#           "category": "Security Cameras",
#           "value": 0.0
#         },
#         {
#           "ward": 48,
#           "category": "Security Cameras",
#           "value": 420672.0
#         },
#         {
#           "ward": 49,
#           "category": "Security Cameras",
#           "value": 54820.0
#         },
#         {
#           "ward": 50,
#           "category": "Security Cameras",
#           "value": 0.0
#         },
#         {
#           "ward": 1,
#           "category": "Streets & Transportation",
#           "value": 5263015.0
#         },
#         {
#           "ward": 2,
#           "category": "Streets & Transportation",
#           "value": 5265202.0
#         },
#         {
#           "ward": 3,
#           "category": "Streets & Transportation",
#           "value": 6579885.0
#         },
#         {
#           "ward": 4,
#           "category": "Streets & Transportation",
#           "value": 5888819.0
#         },
#         {
#           "ward": 5,
#           "category": "Streets & Transportation",
#           "value": 3623267.0
#         },
#         {
#           "ward": 6,
#           "category": "Streets & Transportation",
#           "value": 6173289.0
#         },
#         {
#           "ward": 7,
#           "category": "Streets & Transportation",
#           "value": 6291832.0
#         },
#         {
#           "ward": 8,
#           "category": "Streets & Transportation",
#           "value": 5310553.0
#         },
#         {
#           "ward": 9,
#           "category": "Streets & Transportation",
#           "value": 7132454.0
#         },
#         {
#           "ward": 10,
#           "category": "Streets & Transportation",
#           "value": 6970824.0
#         },
#         {
#           "ward": 11,
#           "category": "Streets & Transportation",
#           "value": 5483427.0
#         },
#         {
#           "ward": 12,
#           "category": "Streets & Transportation",
#           "value": 6244757.0
#         },
#         {
#           "ward": 13,
#           "category": "Streets & Transportation",
#           "value": 5723433.0
#         },
#         {
#           "ward": 14,
#           "category": "Streets & Transportation",
#           "value": 7102329.0
#         },
#         {
#           "ward": 15,
#           "category": "Streets & Transportation",
#           "value": 5748375.0
#         },
#         {
#           "ward": 16,
#           "category": "Streets & Transportation",
#           "value": 6797335.0
#         },
#         {
#           "ward": 17,
#           "category": "Streets & Transportation",
#           "value": 6814640.0
#         },
#         {
#           "ward": 18,
#           "category": "Streets & Transportation",
#           "value": 7107120.0
#         },
#         {
#           "ward": 19,
#           "category": "Streets & Transportation",
#           "value": 6750207.0
#         },
#         {
#           "ward": 20,
#           "category": "Streets & Transportation",
#           "value": 5198100.0
#         },
#         {
#           "ward": 21,
#           "category": "Streets & Transportation",
#           "value": 6864020.0
#         },
#         {
#           "ward": 22,
#           "category": "Streets & Transportation",
#           "value": 6357169.0
#         },
#         {
#           "ward": 23,
#           "category": "Streets & Transportation",
#           "value": 6291040.0
#         },
#         {
#           "ward": 24,
#           "category": "Streets & Transportation",
#           "value": 5569760.0
#         },
#         {
#           "ward": 25,
#           "category": "Streets & Transportation",
#           "value": 6015312.0
#         },
#         {
#           "ward": 26,
#           "category": "Streets & Transportation",
#           "value": 6695063.0
#         },
#         {
#           "ward": 27,
#           "category": "Streets & Transportation",
#           "value": 5261938.0
#         },
#         {
#           "ward": 28,
#           "category": "Streets & Transportation",
#           "value": 2831524.0
#         },
#         {
#           "ward": 29,
#           "category": "Streets & Transportation",
#           "value": 6583942.0
#         },
#         {
#           "ward": 30,
#           "category": "Streets & Transportation",
#           "value": 6219624.0
#         },
#         {
#           "ward": 31,
#           "category": "Streets & Transportation",
#           "value": 5924520.0
#         },
#         {
#           "ward": 32,
#           "category": "Streets & Transportation",
#           "value": 6212624.0
#         },
#         {
#           "ward": 33,
#           "category": "Streets & Transportation",
#           "value": 5758193.0
#         },
#         {
#           "ward": 34,
#           "category": "Streets & Transportation",
#           "value": 5750429.0
#         },
#         {
#           "ward": 35,
#           "category": "Streets & Transportation",
#           "value": 5175979.0
#         },
#         {
#           "ward": 36,
#           "category": "Streets & Transportation",
#           "value": 6877228.0
#         },
#         {
#           "ward": 37,
#           "category": "Streets & Transportation",
#           "value": 5360681.0
#         },
#         {
#           "ward": 38,
#           "category": "Streets & Transportation",
#           "value": 6255457.0
#         },
#         {
#           "ward": 39,
#           "category": "Streets & Transportation",
#           "value": 5528738.0
#         },
#         {
#           "ward": 40,
#           "category": "Streets & Transportation",
#           "value": 5758935.0
#         },
#         {
#           "ward": 41,
#           "category": "Streets & Transportation",
#           "value": 7014819.0
#         },
#         {
#           "ward": 42,
#           "category": "Streets & Transportation",
#           "value": 2824145.0
#         },
#         {
#           "ward": 43,
#           "category": "Streets & Transportation",
#           "value": 5112219.0
#         },
#         {
#           "ward": 44,
#           "category": "Streets & Transportation",
#           "value": 6001084.0
#         },
#         {
#           "ward": 45,
#           "category": "Streets & Transportation",
#           "value": 6959044.0
#         },
#         {
#           "ward": 46,
#           "category": "Streets & Transportation",
#           "value": 5302732.0
#         },
#         {
#           "ward": 47,
#           "category": "Streets & Transportation",
#           "value": 5651216.0
#         },
#         {
#           "ward": 48,
#           "category": "Streets & Transportation",
#           "value": 5039298.0
#         },
#         {
#           "ward": 49,
#           "category": "Streets & Transportation",
#           "value": 5101837.0
#         },
#         {
#           "ward": 50,
#           "category": "Streets & Transportation",
#           "value": 5328320.0
#         }
#       ]
#     }
#   }
# }
# alt.Chart(...)

# %%
## 3x money spent vs
